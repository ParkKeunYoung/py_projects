# %% [markdown]
# ## 절차
#
# 1. 연구목표 설정
# 2. 데이터 획득(수집)
#   - https://play.google.com/store/apps/details?id=com.nhn.android.webtoon&showAllReviews=true
#   - https://play.google.com/store/apps/details?id=net.daum.android.webtoon&showAllReviews=true
#   - selenium 이용
#   - 페이지로드되면,  END 를 작동시켜 밑 밑으로 내린다 -> 10번(임의설정), 3초간대기
#   - 리뷰를 수집해 온다
#    > 이름
#    > 별점
#    > 등록일
#    > 내용
#    > 도움이됬음
#
# 3. 데이터 준비(정제,변환,통합)
#    > 정규식으로 필터링 (욕설, 기타 표현에대한 정책)
#    > 파생변수 -> 형태소, 점수 지표를 이용한 계산, 사전에 없는 표현에 대한 유사어검사(확장성) 등
# 4. 데이터 탐색(시각화,통찰과정)
#    > 워드클라우드, 바차트, 히스토그램, 산포도
# 5. 생략
# 6. 시스템통합(사전의 재구축(선순환구조) 및 반영, 서비스)

# %%
from selenium import webdriver as wd
import urllib

# %%
target_urls = [
    'https://play.google.com/store/apps/details?id=com.nhn.android.webtoon&showAllReviews=true',
    'https://play.google.com/store/apps/details?id=net.daum.android.webtoon&showAllReviews=true'    
]

# %%
driver = wd.Chrome('../tool/chromedriver_75.0.3770.140.exe')

# %%
from selenium.webdriver.common.keys import Keys
def getData(app_name):
    # 타겟 사이트별 데이터 수집 작업
    # 스크롤바를 밑으로 내린다 (10번)
    for n in range(10):
        # selenium.webdriver.common.keys.Keys
        driver.find_element_by_tag_name('body').send_keys(Keys.END)
        # ajax 통해서 리뷰가 로드될것이다
        time.sleep(3)
        #break
    
    reviews = driver.find_elements_by_css_selector('.W4P4ne>div:nth-child(2)>div>div')
    # 전체 리뷰수
    print( len(reviews) )
    tmp = list()
    try:
        for div in reviews:
            # 리뷰를 하나씩 꺼내서
            name    = div.find_element_by_class_name('X43Kjb')            
            star    = div.find_element_by_css_selector('.pf5lIe>div')
            regi    = div.find_element_by_class_name('p2TkOb')
            content = div.find_element_by_css_selector('.UD7Dzf>span')
            good    = div.find_element_by_class_name('jUL89d.y92BAb')
            dic     = {
                'name':name.text,
                'star':star.get_attribute('aria-label'),
                'regi':regi.text,
                'content':content.text,
                'good':good.text,
                'app_name':app_name
            }
            tmp.append( dic )
    except Exception as e:
        print('실제로는 데이터가 없으나 있는것으로 처리되서 커트')
    return tmp
        
    
    
    # 수집하고자 하는 내용들을 완벽하게 순서대로 세트를 유지하고, class명이 모두 동일
    # 여기서는 개별적으로 구해서 순서대로 처리    
    # 후기가 있어서 수치가 틀어진다 -> 보정이 필요
    # 이름   
    #names    = driver.find_elements_by_class_name('X43Kjb')
    # 별점 
    #stars    = driver.find_elements_by_css_selector('.pf5lIe>div')
    # 등록일
    #regis    = driver.find_elements_by_class_name('p2TkOb')
    # 내용  
    #contents = driver.find_elements_by_css_selector('.UD7Dzf>span')
    # 도움이됬음 
    #goods    = driver.find_elements_by_class_name('jUL89d.y92BAb')
    #print( len(names),len(stars),len(regis),len(contents),len(goods)  )

# %%
import time
outputs   = list()
app_names = ['네이버웹툰','다음웹툰']
for idx, target_url in enumerate(target_urls):    
    driver.get( target_url )
    outputs.extend( getData( app_names[idx] ) )
    time.sleep(4)
    #break
# Out:
# 201
# 실제로는 데이터가 없으나 있는것으로 처리되서 커트
# 120

# %%
len(outputs)
# Out:
# 320

# %%
outputs[-1:]
# Out:
# [{'name': '강지우',
#   'star': '별표 5개 만점에 1개를 받았습니다.',
#   'regi': '2019년 8월 7일',
#   'content': '로그인이 안돼요 카카오계정으로 로그인하라는데 카카오계정으로 로그인하기 버튼도 없고 뭘 하라는건지',
#   'good': '',
#   'app_name': '다음웹툰'}]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame.from_dict( outputs )
df.head(2)
# Out:
#   app_name                                            content good name  \
# 0    네이버웹툰  쿠키 왜 안주세요 몇번째야 진짜 무료쿠키~ 이러면서 안주는게 한두번인가 내가 가입을...    1   솜담
# 1    네이버웹툰  저기요... 갑작히 잘 되던게 왜 안 됩니까? 와이파이 빵빵한데 네트워크 연결상태를...    2   왈왈
#
#            regi                  star
# 0  2019년 8월 17일  별표 5개 만점에 1개를 받았습니다.
# 1  2019년 8월 20일  별표 5개 만점에 1개를 받았습니다.

# %%
# star에서 점수만 추출
sample = '별표 5개 만점에 3개를 받았습니다.'
import re

# %%
p = re.compile( '\d+' )

# %%
p.findall( sample )[1]
# Out:
# '3'

# %%
# star 값들을 실제 점수로만 변경한다
df['star'] = df['star'].apply( lambda x: p.findall( x )[1]  )

# %%
df.dtypes
# Out:
# app_name    object
# content     object
# good        object
# name        object
# regi        object
# star        object
# dtype: object

# %%
# regi에서 날자를 YYYY-mm-dd 형태를 날짜 포멧팅으로 처리
# step 1. 년도, 월, 일 값들을 일단 뽑아낸다
# "2019년 8월 16일" => (\d+).+(\d+).+(\d+).
p        = re.compile( '(\d+)\w\s(\d+)\w\s(\d+)\w' )
sample   = "2019년 8월 16일" 
#date_raw = p.search( sample ).groups()
# 2019-8-16
p.sub( '\g<1>-\g<2>-\g<3>', sample )
# Out:
# '2019-8-16'

# %%
import datetime

# %%
datetime.datetime.strptime( '2019-8-16', '%Y-%m-%d' ).date()
# Out:
# datetime.date(2019, 8, 16)

# %%
# df에 regi 항목에 데이터를 datetime.date(2019, 8, 16) 타입으로 치환하시오
df['regi'] = df['regi'].apply( lambda x: 
                  datetime.datetime.strptime( p.sub( '\g<1>-\g<2>-\g<3>', x ) 
                                              , '%Y-%m-%d' ).date()  )

# %%
df.head(2)
# Out:
#   app_name                                            content good name  \
# 0    네이버웹툰  쿠키 왜 안주세요 몇번째야 진짜 무료쿠키~ 이러면서 안주는게 한두번인가 내가 가입을...    1   솜담
# 1    네이버웹툰  저기요... 갑작히 잘 되던게 왜 안 됩니까? 와이파이 빵빵한데 네트워크 연결상태를...    2   왈왈
#
#          regi star
# 0  2019-08-17    1
# 1  2019-08-20    1

# %%
# content에서 형태소 분석을 위한 영어 제거 혹은 대체?
df['content']
# Out:
# 0      쿠키 왜 안주세요 몇번째야 진짜 무료쿠키~ 이러면서 안주는게 한두번인가 내가 가입을...
# 1      저기요... 갑작히 잘 되던게 왜 안 됩니까? 와이파이 빵빵한데 네트워크 연결상태를...
# 2      "개를 낳았다"를 즐겨보고 있는데 엄청 재밌드라고요 그런데 개를 낳았다를보고 다른걸...
# 3      한 두 번도 아니고 와이파이, 데이터 둘 다 네이버웹툰만 켜면 제일을 왜 못합니까?...
# 4      아니;;장난하시냐고요--여러분 이거요기요 첫주문웬만하면하지마세요.쿠키130개?절대안...
# 5      자기의 취향에 걸맞는 것도 찾기가 쉽고 또한 어느것이 도 인기가 도 많은지 바로바로...
# 6      아니 왜 무료쿠키 안줘요? 앱깔고 회원가입하면 쿠키 9개 준다길래 앱깔고 회원가입도...
# 7      안녕하세요. 제가 할거가 없어서 찾고 있었는데 딱 이게 발견 했습니다. 그래서 한번...
# 8      요즘 자꾸 모자이크칸이 많이뜨고 이미지가 안나오네요. 크롬으로 네이버직좁 들어가서 ...
# 9      진짜 진짜 재밌게 보고 있어요 !! 💗 근데 와이파이 없이 볼수는 없나요 ? ㅜ 고...
# 10     쿠키 첫주문 이벤트 아직까지 안주더라고요.. 그리고 어제부터 갑자기 다른 웹툰보려고...
# 11     저기요 돼지만화는 언제 자르실건지.....? 그거 보면 진심 화나요..... 조선팔...
# 12     네이버 웹툰은 컷마다 볼 수 있는 댓글과 보기편한 점이 있어서 좋지만 다른 새로운 ...
# 13     결제는 네이버 어플에서 바로하게하고 미리볼려면 다른 어플(네이버웹툰어플)을 깔아야한...
# 14     제가 계정을 만들려고 아이디 비밀번호 만들고 전화번호도 쳤고 인증번호가 안오는것 같...
# 15     저만 그런건지는 모르겠는데 웹툰 밑으로 스크롤해서 보다가 중간에 만화 장면이 나타나...
# 16     저 의견사항에서 얘기 했는데 답장이 하도 안와서 여기서 말합니다 제 오해 일 수 있...
# 17     물론 아주 편리한 앱입니다 하지만 하나하나 이렇게 부모님 인증에 상관없는 거의 모든...
# 18     와....이거 무료쿠키 받을려고 다운로드 했는데 쿠키를 안줌.. 그거 다운로드하고 ...
# 19     하; 정말 이제는 못 참겠네 욕을 실컷 쳐먹는 낙하산 추정 만화 돼지만화는 놔두고 ...
# 20     최고에요!!! 정말 좋은거 같아요! 누가 이거 만듬?!? 와....최고다~ 만든사람...
# 21     컷툰을 볼때 현재 컷이 몇페이지인지 알려주는 프로그레스 바를 위에 배치시키거나 사용...
# 22     돼지만화 같은 건 계속연재 하는데 왜 하늘쌤이나 에스프레소 같은건 왜 완결내냐 0....
# 23     어음 네이버웹툰 85개보는 독자로써 추천드릴 웹툰 10개는 1. 소녀의세계 2. 여...
# 24     다 좋은데,,, 로그인 하려고 아이디 찾기 들어가서 다 정확하게 입력했는데도 인증번...
# 25     웹툰은 좋은데 최근 업데이트된 타인지옥이라는 웹툰에 대해 문의드리겠습니다. 저는 귀...
# 26     베스트 도전 새로고침 버튼좀 만들어 주시면 안될까요? 그리고 도전도 앱에서 볼 수 ...
# 27     외부 사이트에서 링크로 앱으로 넘어올때 최신버전으로 업데이트 하라는 문구만 뜸(현재...
# 28     어차피 리뷰 달아봤자 메일이나 서비스센터,홈페이지에서 문의하라고 할거 아니까 일단 ...
# 29     이거 왜 요기요 첫 주문 쿠키 130개 안주죠? 13일이 지났는데도 안주고 이용문의...
#                              ...
# 290    와 저번엔 결제 되게 간편하고 좋았는데 바뀐건가요???저번처럼 쉽게 되질 않아요. ...
# 291             저이거 완전 재밌게 봤어용!!!네이버 웹툰이랑 달라서 더재밌었던것 같네요
# 292    구버전 쓰다 강제로 업뎃하게 됐는데, 거슬려서 못 쓰겠다. 쓸데없이 화면전화 모션이...
# 293    별 한개도 아깝습니다. 자잘한문제들..보기 불편한 웹툰 분류방식.. 개발자님 쫌 고...
# 294    댓글에 싫어요 기능 좀 추가해주세요. 무조건 좋아요만 많이 받은 댓글이 베댓이 되니...
# 295    다음은 프롤로그나 1화 봐서 캐시 주는건 괜찮은데 이용권을 사놨다가 쓰는건 없는건가...
# 296    ㄹㅇ 불편해 죽겠네 그전엔 카카오페이랑 연동안돼있어서 그런지 결제가 더 간편했는데 ...
# 297    업데이트 될수록 하나하나 찾아 들어가야 볼 수 있게 해놓았네요. 광고도 좋고 추천도...
# 298    혹시 좋아요 남긴거 해제하는 건 있나요? 저는 별로 찬성하지못하는 댓이있어서 밑에 ...
# 299    네이버웹툰이랑 페이스북 네이버 다 잘들어가지는데 다음웹툰만 들어가려하면 네트워크 연...
# 300                                      자덩 내려가기 기능 개꾸울~
# 301    앱을 실행시킬때마다 서비스 연결이 원활하지 않다는 메세지가 뜨면서 자꾸 꺼집니다. ...
# 302    다음 장사하기 싫어요? 200원 결제하는데 카카오페이 체크카드 빠꾸먹고 오류 오질나...
# 303    네이버도 카카오도 만14세이상이면 결제 다 할수있는데 왜 다음만 부모님동의를 받아야...
# 304    다 좋아요! 다 좋은데 성인 / 일반 이렇게 나눴으면 좋겠어요! 19웹툰 화면 걸려...
# 305    제발 댓글 싫어요 기능도 넣어주세요ㅜㅜㅜ 위로 올라와서 눈에 보이는 몇몇 베댓들 때...
# 306    웹툰관련된 공지사항은 관리자가 없는것같다. 문제가 생긴거면 공지좀 띄워주지ㅡㅡ어플에...
# 307                                             너무 재미있어요
# 308    다음 예전에는 완결된것들 정주행 할 수 있어서 그 재미에 많이 이용했는데 지금은 완...
# 309    웹에서 업로드 확인 못하게 해서 앱 설치 강제하는 인성 실화냐? 게다가 하는 일도 ...
# 310    아니 저만 그런지 모르겠는데요.분명 와이파이도 빵빵한데 웹툰 스크롤을 내리다보면 인...
# 311    실명 확인에서 왜 국내 전화만 가능한가요? 혹시 가능하시다면 국외 전화번호도 추가해...
# 312    좋은 작품이 많아서 종종 유료결제도 하며 보고있습니다 그런데 구매가 아닌 대여만 있...
# 313                                             브금이 안들려요
# 314    업데이트좀 그만해라진짜 그나마다음웹툰도 몇개남은거땜에 간신히보는데 관리이따구로해서 ...
# 315                                             ㅋㅋㅋㅋㅋㅋ조음
# 316    봤던 웹툰을 다시 보는 경우가 있는데 이전 위치가 저장되어서 불편합니다 끝까지 보고...
# 317    업데이트 아니면 사용불가래서 업데이트하는데 파일 다운도 안받아지네;; 너무 쓰레기같...
# 318    기다무 웹툰 보려고 무료는 다 보고 기다리는데 안돼서요...그래서 뭐..실명확인?필...
# 319    로그인이 안돼요 카카오계정으로 로그인하라는데 카카오계정으로 로그인하기 버튼도 없고 ...
# Name: content, Length: 320, dtype: object

# %%
# 백업
df.to_csv( './data/app_review_mid.xls', encoding='utf-8'  )

# %%
# 명사, 형용사 기준으로 하고, 동사는 확장성/가능성을 두고 체크
# 형태소 분석을 하기 전에 사전에 포함되어 있지 않는 유형의 문자들을 제거
# 1. 영어, 숫자 제거 <-> 한글과 특수기호, 화이트스페이스, 추출
tmp = df['content'].copy()

# %%
for doc in tmp:
    print( doc )
# Out:
# 쿠키 왜 안주세요 몇번째야 진짜 무료쿠키~ 이러면서 안주는게 한두번인가 내가 가입을 얼마나 많이했는데 방금 알바가입 머시했거든요? 10개 빨리주세요;; 진짜 나말고도 많더만 이정도면 네이버 이거 고객기만이지 장난하나;;;; 그리고 작가님들 다 좋거든요? 근데 왜 자꾸 하위권짜르세요 장난하나 작가님들 작품이 장난이에요? 이상한 만화는 안 짜르고 스토리 탄탄에 작화 좋은데 하위권 다 짤라;;;
# 저기요... 갑작히 잘 되던게 왜 안 됩니까? 와이파이 빵빵한데 네트워크 연결상태를 확인하라고 하고;; 삭제 하고 다시 로그인 할려고 하면 이용약관에 동의 하라고 하고 진짜 화나서 욕이 나올려고 하네요;;
# "개를 낳았다"를 즐겨보고 있는데 엄청 재밌드라고요 그런데 개를 낳았다를보고 다른걸 한번도 본적이 없었어요 그런데 개를 낳았다 끝까지 봐서 다음화 나올때까지 다른걸 봤는데 재밌어서지금은 여러가지를 보고 있어요 전 제일 좋아하는 3가지가 있어요 1위 개를 낳았다 2위 유미의 세포들 3위 날 가져요 넘나 재밌어요ㅠㅠ 전 이 앱을 깔고 후회한적이 없어요ㅠ 전 그래서 별 5개를 드립니다!!
# 한 두 번도 아니고 와이파이, 데이터 둘 다 네이버웹툰만 켜면 제일을 왜 못합니까? 데이터 충분하고 카톡 잘됩니다. 지금 별점도 데이터로 남기는데 웹툰 이미지 파일만 로딩이 안됩니다. 캐시 삭제까지 해봤습니다^^;
# 아니;;장난하시냐고요--여러분 이거요기요 첫주문웬만하면하지마세요.쿠키130개?절대안줌 내가장담함.이용문의에도 글을몇번이나올렸는데 안줌 이글을읽는 네이버관계자분들 제발좀 쿠키좀주시죠; 이거지금 10일이상넘음; 이정도면 네이버진짜일안하는수준
# 자기의 취향에 걸맞는 것도 찾기가 쉽고 또한 어느것이 도 인기가 도 많은지 바로바로 알수 가 있어서 좋아용. 그런데 쿠키는 좀 몇개를 좀 없앴으면 좋겠어요. 그리고 쓰는 방법도 잘 모르겠고 이무튼 이런저런것들을 좀 수정해주세요.
# 아니 왜 무료쿠키 안줘요? 앱깔고 회원가입하면 쿠키 9개 준다길래 앱깔고 회원가입도 성공했는데 주지도 않고 다시 이 앱 들어가서 봤는데 받기완료도 안뜨고 갑자기 연결되지도 않고... 와씨 한 3분있다가 들어가니까 아예 그 내용자체가 사라져있네
# 안녕하세요. 제가 할거가 없어서 찾고 있었는데 딱 이게 발견 했습니다. 그래서 한번 들어가 봤는데 너무 만화가 제미있고 너무 마음이 듭니다. 아프로도 더 발전에서 업데이트 하면 좋겠어요. ^0^
# 요즘 자꾸 모자이크칸이 많이뜨고 이미지가 안나오네요. 크롬으로 네이버직좁 들어가서 보고있는데 좀 고쳐주세요. V50입니다. 데이터 사용중이며 5g아닌lte로 사용중입니다. 와이파이 환경에서도 같습니다.
# 진짜 진짜 재밌게 보고 있어요 !! 💗 근데 와이파이 없이 볼수는 없나요 ? ㅜ 고쳐주시면 감사합니다 ~ 웹툰 정말 좋아요 //
# 쿠키 첫주문 이벤트 아직까지 안주더라고요.. 그리고 어제부터 갑자기 다른 웹툰보려고 아래로 내리면 자꾸 꺼져요.. 해결 좀 부탁드립니다..
# 저기요 돼지만화는 언제 자르실건지.....? 그거 보면 진심 화나요..... 조선팔도 최강아이돌을 자르지 말고 돼지만화를 자르시지ㅡㅡ 솔직히 사용자들 의견도 좀 들어주새요 돼지만화는 재미도 없고 악플도 많은데 조팔아는 악플 하나도 없고 그거보려고 일주일을 기다리게되는 만화에요
# 네이버 웹툰은 컷마다 볼 수 있는 댓글과 보기편한 점이 있어서 좋지만 다른 새로운 만화는 몇편을 봐야 내용을 이해할 수 있기 때문에 조금 힘들때가 많다. 이런 문제 해결은 줄거리칸을 추가하면 새로운 만화에 좀 더 다가가기 쉬워지고 숨어있는 글들을 볼 수 있게 되는 장점이 될 것이다. 또한 순위도 추가해주었으면 좋겠다. 사이트에는 있는데 앱에는 없으니 안타깝다. 순위권에 있는 만화를 보게 되는 홍보효과도 있으니 순위가 있으면 장점이 더 늘것이다. 요새는 인터넷이 아닌 휴대폰을 통해 손가락하나의 터치만으로 쉽게 접근가능한 방법을 더 선...
# 전체 리뷰
# 결제는 네이버 어플에서 바로하게하고 미리볼려면 다른 어플(네이버웹툰어플)을 깔아야한다니...결제 전에 미리 보려면 웹툰어플을 깔아야 한다고 공지라도 해주시죠..참..꺼림직하네여..
# 제가 계정을 만들려고 아이디 비밀번호 만들고 전화번호도 쳤고 인증번호가 안오는것 같아서 여러번 누르고 아이디 새로 만들고 해봤는데 메시지 보니까 이미 와있던거 같았어요 그래서 인증번호 쳤는데 안 만들어지고 아예 딴걸로 새거 만들고 인증번호 받으려는데 인증번호가 안와요 왜 이런건가요? 왜이런지 아는사람 아무나 알려주세여ㅠ
# 저만 그런건지는 모르겠는데 웹툰 밑으로 스크롤해서 보다가 중간에 만화 장면이 나타나지가 않고 계속 기다려도 다음장면이 뜨지가 않아요...
# 저 의견사항에서 얘기 했는데 답장이 하도 안와서 여기서 말합니다 제 오해 일 수 있는데 이해해주세요 제가 쿠키오븐에서 30개를 받아서 2개를 써서 28개가 남았었는데 몇 일 지나더니 사라졌어요 쓴적이 없는데도 28개가 사라졌거든요 제 오해가 아니라면 복구해주시길 바라겠습니다 암튼 잘보고는 있어요 감사합니다 답변 남겨주시길 바랄게요
# 물론 아주 편리한 앱입니다 하지만 하나하나 이렇게 부모님 인증에 상관없는 거의 모든활동을 부모님 인증하라하는건 정말 이해할수 없군요 그냥 연령제한있는 앱도 아니고 앱깔면 쿠키준다는데 그거마저 부모님인증을 아주 세세하게 걸쳐야 한다는것이 정말..고쳐주셨으면 합니다!
# 와....이거 무료쿠키 받을려고 다운로드 했는데 쿠키를 안줌.. 그거 다운로드하고 그 앱도 들어가 봤는데도 그럼.. 20번은 넘게 안됨 아... 이거 웹툰만 재밌지 기능은 구림.. 쿠키샵좀 고쳐줘요 네이버!
# 하; 정말 이제는 못 참겠네 욕을 실컷 쳐먹는 낙하산 추정 만화 돼지만화는 놔두고 다른 멀쩡한 만화 압박해서 잘라버립니까? 네이버도 돈슨 따라가는건가ㅡㅡ
# 최고에요!!! 정말 좋은거 같아요! 누가 이거 만듬?!? 와....최고다~ 만든사람 돈주고 싶다... 최고다!!
# 컷툰을 볼때 현재 컷이 몇페이지인지 알려주는 프로그레스 바를 위에 배치시키거나 사용자가 바꿀 수 있게 해주세요. 댓글보려고 하거나 다음화로 가려다가 컷을 옮기는 경우가 종종있네요. 신기능 추가하는건 정말 감사합니다.
# 돼지만화 같은 건 계속연재 하는데 왜 하늘쌤이나 에스프레소 같은건 왜 완결내냐 0.000000001%라도 양심 있으면 돼지만화 완결내고 협박 하지마라(증거:하늘쌤 댓에 네이버가 협박 했으면 당근흔들어 달라했는데 yg코믹스 블로그에서 후기처음에 당근이 흔들고있음) 와 딴 리뷰 보니까 돼지만화나 협박 이런건 댓 안달아주고 딴문제점 만 댓다네 이 날강두 같은 xx들
# 어음 네이버웹툰 85개보는 독자로써 추천드릴 웹툰 10개는 1. 소녀의세계 2. 여신강림 3. 랜덤채팅의 그녀 4. 유미의 세포들 5. 타인은 지옥이다 6. 연애혁명 7. 스위트홈 8. 프리드로우 9. 검은인간 10. 스피릿핑거스 입니다ㅏ 꼭 보세요 강추합니다
# 다 좋은데,,, 로그인 하려고 아이디 찾기 들어가서 다 정확하게 입력했는데도 인증번호가 뜨지 않아서 로그인을 못하고 있어요ㅠ 좀 고쳐주세요...
# 웹툰은 좋은데 최근 업데이트된 타인지옥이라는 웹툰에 대해 문의드리겠습니다. 저는 귀신이든 무서운 것에 대한 트라우마가 깊게 남아있습니다. 때문에 이 웹툰에 대한 썸네일만 봐도 두렵고 무섭고 잊혀지지가않습니다. 웹툰의 내용에 따라 썸네일을 그린건 알겠지만 저 썸네일에 위해 불쾌한 사람이 수두룩합니다. 웹툰 차단 기능 등 해결 방법을 마련해주세요. 저 썸네일이 무서워서 다른 웹툰을 보지 못하겠습니다.
# 베스트 도전 새로고침 버튼좀 만들어 주시면 안될까요? 그리고 도전도 앱에서 볼 수 있게좀 해주시면 고맙겠네요
# 외부 사이트에서 링크로 앱으로 넘어올때 최신버전으로 업데이트 하라는 문구만 뜸(현재 업데이트 완료)
# 어차피 리뷰 달아봤자 메일이나 서비스센터,홈페이지에서 문의하라고 할거 아니까 일단 까고 시작하겠습니다. 생각이 없어서 그런건가요 아님 사용자를 최대한 엿먹일려고 그런건가요? 왜 압박을 넣어서 웹툰을 내려요? 더 오래된 만화보다 순위와 별점은 높은데 왜 새로 시작한 중위권 웹툰은 다 강제로 완결 내버리는지 모르겠네요 한두번이면 그러려니 할건데... 그리고 댓글은 솔직히 관리 안하지요? 관리를 한다면 이렇게 개판이진 않을건데 이정도로 개판이면 차라리 레진이나 카카오 가서 돈주고 보지 옛날부터 사람들이 지적하는게 댓글 관리인데 나아지질 ...
# 전체 리뷰
# 이거 왜 요기요 첫 주문 쿠키 130개 안주죠? 13일이 지났는데도 안주고 이용문의에 몇번이나 연락해도 130개 안주시고;; 빨리 주시면 좋겠네요.
# 진짜 네이버 웹툰덕분에 웹툰에 빠져들게 됬습니다....ㅎ 재밌는 웹툰 많으니까 꼭! 깔아보세요!!
# 회원탈퇴후 1일뒤 다른계정만들려고 하고 제 전화번호를 넣고 인증번호 받기 버튼을 눌렀습니다 근데 인증번호가 오질않아요 진짜 이것 좀 고쳐주세요 너무 불편해 죽겠어요
# 진짜 최강자전 어떻게 좀 해주셈 네이버 웹툰에 연애물이 비중이 제일 높은데도 연애물이라서 그림체가 좋아서 아무리 참신한 소재 재미있어도 그림채 좋아서 로맨스라서 상대한테 짐 실제로는 뻔한 스토리 차라리 징르별로 해주셈
# 네이버 웹툰앱 정말 편하고 유용해요. 근데 네이버로 웹툰볼때 완결웹툰 위에 쿠키표시가 있어서 유료 인지 무료인지 구분이 잘되는데, 네이버 '웹툰앱' 에서는 완결웹툰 위에 쿠키표시가 없네요. 유료인지 무료인지 알수 있게 ♡웹툰앱에서도 완결웹툰 쿠키표시가 있었으면 좋겠어요.♡ 다음 업데이트 때 참고해 주세요. 감사합니다.
# 안녕하세요 네이버 웹툰을 아주 잘 사용하고 있는 닝겐인데욥!! 제가 애니를 좋아해서 한참 빠져있다가 볼게 없어서 이 앱을 깔았는데!!!!!! 아니 정말 제가 레알루다가 좋아하는 BL웹튠 here you are 이 있는거에요옹!!!!!진짜 이거 정주행 하고 일요일만 기다리고 있어요88 tmi가 길었네요ㅜㅜ 암튼 이 앱 정말 잘 쓰고 있습니다 더 좋은 모습으로 업데이트 되면 좋겠어요ㅜㅜ
# 그 앨리스에게 판타지는 없다 볼수있게 해주시면 안될까요? 그리고 쿠키는 출석 같은걸로 지급하고 가격을 올리는게 더 나을것 같아요..이중 하나만 반영되면 별 5개는 부족할 정도로 좋을것 같아요(개인적으로)
# 저는 웹에서 보는 이용잔데요.. 앱은 깔고 싶지 않았거든요? 내가 돈내고 쿠키사서 미리 읽겠다는데 왜 앱을 깔아야만 볼수있는지 이해못하겠는데요.. 왜 꼭 그래야되는지 알려주세요. 회차는 이미 결제가 됐고 앱을 깔지 않으면 볼수가 없어서 일단 깔긴하는데 회차 다 보고 삭제할거고요.. 이런식이면 앞으론 유료결제 안해야지..
# 아니 돈으로 쿠키를 못사서 무료로 쿠키굽는걸 하고 있었는데요 평소엔 네이버가 쿠키 잘주고 이랬는데 계속 안줘요 똑같이 하라는데로 했는데 주질 않아요 갑자기 이러면 어떡해요 사기꾼도 아니면서
# 네이버 웹툰을 거의 대부분 챙겨보고 있는 이용잡니다. 다 좋은데 저만 그런지는 잘 모르겠지만 가끔씩 원래 보던 웹툰인 걸 깜빡하거나 웹툰 표지가 눈에 띄지 않아서 제가 보는 웹툰을 보고 싶을 때 제때 못 보는 경우가 있습니다. 웹툰 표지에 조그마하게 관심웹툰 등록 여부를 표시하는 아이콘이 있으면 자기가 보고 있는 웹툰임을 확인하기도 쉽고 관심웹툰 기능을 활성화하는 데도 도움이 될 것 같습니다.
# 안녕하세요 네이버웹툰 보고있는 사람입니다 제가 웹툰을 보다가 갑자기 유료로 봐야하는 웹툰을 무료로 볼수있게 되었어요 이거 버그인가요 버그라면 고쳐주세요
# 아니ㅡㅡ처음으로 쿠키 사가지고 웹툰 좀 미리보기 하려고 하는데 무슨 앱까지 깔아야되나요ㅡㅡ 쿠키 샀으면 됬지 저장공간도 없는데ㅡㅡ앱 안깔아도 잘보고있었는데..짜증나네요
# 아니 내가 알바콜 최초로 회원가입했는데 왜 안주냐고요 안줄거면 처음부터 무료쿠기기능을 만들지를 말던거 밑에 최초로 알바생 가입하면 준다고해서 알바생 가입했는데 왜 안줘요 사람 놀리는 것도 아니고
# 아니 ㅋㅋㅋ 앱이 안열어 진데는데 도대체 뭐죠 ?ㅋㅋㅋㅋㅋㅋ 정말 불편하네요;;;
# 왜일까 진짜 웹툰시장 내가알기론 네이버가 1위일텐데 머기업이 앞에서 잘해야지 레진이나 다음에 압박감 느끼고 양산형웹툰 막 뽑아내는거임? 웹툰 많아지는걸로 피해는없는데 스토리 뻔한 애니메이션 그림체 인기라곤 1도 없는 씹덕 웹툰은 미친듯이 뽑아내면서 기존에 있던 하위권 웹툰들 막 잘라내는거임? 진짜 이거에 네이버한테 크게 실망했다 아무리 다음웹툰에 비해 네이버웹툰이 시청자 연령대가 낮은건 맞는데 웹툰들에 압박넣어서 강제연재종료시키는건 선넘었지 ㅋㅋ; 처음에 인기 좀 후달리는 웹툰들 끝맺음 조차 이상하게 끝내고 이제 시작인거같은데 완결...
# 전체 리뷰
# 보통 앱이 있어도 네이버로 직접 검색 들어가서 보는편인데 이런 앱이 있다해서 들어가는것도 아니지만 웹툰을 볼때 이런 앱이 필요해서 불편하네요. 앱이 필요한 만화도 있고 , 필요없는 만화도 있고.
# ?!?!?!쿠키가 1주일 지나니 없어지네요 이점 조금만고쳐주시면 별 다섯개드리겠습니다 다른점은 다 좋아요
# 작가가 강제로 갇혀있나? 1갇혀있으면 당근이 웹툰에 나옴 2진짜면 비키니 라는 단어가 웹툰에 나옴 어느 웹툰에서ㅡ 그리고 강제 종결이나 하지마ㅡㅡㅡㅡㅡ
# 이미지 로딩속도 개선한답시고 그리드 프로그램 깔아버리는거에 깜짝 놀랐습니다. 무심코 동의 눌렀다가 앱 삭제했네요 장난치나; 이런건 시도조차 하지 마셔야죠. 대다수 사용자가 그리드 존재조차 모를텐데 이쁘게 포장해서 동의 받으면 다인줄 아나.
# 쿠키 지급에 대한 문제가 조금 있었습니다. 그 해결방안이 구체적으로 되어있어서 조금 번거로웠지만 잘 해결 되었습니다. 감사합니다.
# 유튜브고 뭐고 다른거는 다 되는데 웹툰 로딩이 안되네요;; 어제까지만 해도 잘 됐는데 이게 뭔지 후;
# 그래도 편하게 잘보고 있습니다 다른분들 리뷰 읽어봤는데 몇몇 오류 부분들은 좀 개선했으면 좋겠다는거에 동의합니다
# 재미있는 것도 있고 감동적인것(등등등)도 있고 해서 골라 볼수있고 봤던건 찾지안고 MY를 클릭하여 보던것도 바로 볼수있어서 좋다
# 저기 ㅠㅠ 다 좋은뎅...카카오톡으로 로그인도 할슨있음 좋겠어요ㅠㅠ 네이버 아이디,네이버 비밀번호가 없어서 로그인을 못해요ㅠㅜ
# 도전만화나 베도 등 그렇게 올라온 웹툰 개 재밌는데 낙하산 웹툰좀 어떻게 해봐요;;;;; 노잼인데 낙하산으로 올라와서;;;;이건 민폐죠 웹툰작가 준비하거나 미대생 들이 걸 보고 속상해 하잖아요;;;;;
# 쿠키 결제하면 앱으로밖에 볼 수 없는 거 진짜 불편해요. 앱보다 인터넷이 편해서 인터넷으로 보고싶은데 참... 앱에 관심웹툰 먼저보기 기능 인터넷처럼 추가하면 좋을거같아요.
# 컷 툰에서 컷수 나오는 거 이번에 새로 생긴거 같던데 설정에서 on/off 할수 있게 만들어 주세요ㅠㅠ 그거 컷 툰 볼때마다 거슬립니다...
# 네이버 웹툰 신작 인기 없으면 30화에 딱 끊고 완결내는거 너무 싫어요;;,,,,..누군가에게는 힘이 됄 수 있는 웹툰인데..그 점을 좀 고쳐주세요
# 다른거는 다 좋은데 왜 완결이 되면 캡쳐를 못하는지 의문인데요, 솔직히 완결이 난다해도 아직 쿠키제로 변하지 않았으면 캡쳐가 됐으면 좋겠네요. 그거 말고는 다 좋습니다!
# 업데이트 하기 바로 전까지만 해도 괜찮았는데 업데이트 하자마자 컷툰 보려고만 하면 튕기네요.. 왜이렇죠? 제가 보고 있던 컷툰이 3개정도 있었는데 일반 스크롤웹툰은 그래도 괜찮은데 컷툰 보려고만 하면 너무 심하게 튕기네요;; 웹툰을 더 편하게 보기 위해서 업데이트를 한 건데 컷툰은 아예 볼 수도 없게 튕기게 해 놓으시면 어떡하나요... 폰 바꾼지 2달됐고 용량도 40기가 넘게 남았습니다. 업데이트 직전, 불가 몇십분 전만 해도 안 튕기고 볼 수 있었던 컷툰이 업데이트 하자마자 튕긴다는건 제 폰 문제는 절대 아닌것 같습니다. 제 글 ...
# 전체 리뷰
# 컷툰 스크롤 편하긴 한데요 ㅠㅠ 댓글 읽으러 들어갈때 잘못눌려서 이상한곳으로 넘어갈때가 있어요 스크롤 위에다 달아주시면 더 편해질것 같아요 ㅠㅠ
# 갑자기 와이파이상태에서 웹툰 로딩이 느려져요.... 5분정도 기다리니까 4컷정도 나오네요..... 빨리 고쳐주세요
# 아니 미성년자는 무료 쿠키 어떻게 받으라는거죠! 첫주문,보험 가입,영화구매 등 저희 미성년자들 이 못하는 것만 있네요. 무료 쿠키 미성년자도 쉽게 받을 수 있도록 해주세요
# 아니 쿠키가없어졌어요 쿠키가부족해서 뭔앱다운로드하고 회원가입기다렸단말이죠 회원가입을했습니다 최초가입이라해서 그것도보고 한건대 쿠키8개가안오져? 다시해보려고했더니이미했대요 난쿠키를받지도않았는데ㅋ 쿠키이시스템개같아요 공짜면다무시하는듯
# 저 쿠키를 받아야 하는데 안 되네요. 제가 요기요에서 회원가입하고,시켜 먹었는데 쿠키 130개가 안 들어오네요. 그리고 좋은 웹툰은 많은데 장기 연재하면 완결 쪽으로 가서 쫌 짜증나요.완결 쪽으로 안 가게 해 주세요. 그리고 쿠키는 어떡하죠? 130개 빨리 받게 해 주세요. 진짜 이런 것들만 고치면 진짜 좋을 것 같아요.
# 타인은 지옥이다 썸네일좀 바꿔라 그림체도 ㅂㄹ인데 매일 박아놨네 웹툰 보려고 어플 설치했지 기분나쁘려고 설치한줄 아나 웹툰차단기능이라도 넣던가 드라마고 뭐고 컴플레인은 많은데 수정을 안하냐 일좀 해
# 다 좋은데 다른 노력하는 무고한 사람들을 위해 돼지만화대신 다른만화를 연재할 수 있도록 해주세요 다른사람들은 베도같은 곳에서 꾸준히 노력한 결과로 올라온건데 돼지만화는 어캐 올라온지 모르겠네요 그리고 돼지 만화 하나의 구도와 그림채 그리고 항상 같은 결말때문에 네이버 직원들을 욕하는 댓도 늘어 다른 웹툰에도 영향을 끼치니 불편해요ㅜㅜ
# 아니 다 좋은데 솔직히 연제하던 웹툰 인기없다고 중간에 완결내려버리는거는 아닌것같아요. 보는사람으로서는 기분나쁘네요. 한두번도아니고. 앞으로 이런일 없었으면 좋겠네요.
# 골라서 보는 재미가 있고,여신강림이 제일 재밌는겄같아요.추천해욤ㅍ!!
# 안녕하세요. 저는 네이버웹툰을 자주 즐겨보는 초등학교 학생입니다. 제가 웹툰을 많이 보는 편인데요, 쿠키를 구매할 때 제가 하기 쉬운 앱설치하고 쿠기 2개 받기, 그런거 더 많이 올려주였으면 해요. 저도 초등학생인지라 신규가입 회원가입 보험 이런거는 나이도 어려서 못하잖아요. 더구나 저처럼 어린사람들도 다음 화 보려고 쿠키 구울 때 할 수 있는게 없어서 좀 그래요. 보험, 가입 이런 거 말고 앱설치하고 쿠키 2개 더 받기 이런 거 더 많이 올려주셨으면 합니다.
# 앱은 이용하기 편하고 웹툰들도 재밌습니다! 다만 대여기능이 조금 불편한게 한번 미리보기회차를 결제한 후 다음주가 되면 그 회차는 다시 유료로 전환되어버리는데 전내용이 기억이 잘 안나서 바로전편을 다시 본 후 새로운 회차를 이어서 보고싶은 경우에는 조금 아쉽습니다ㅜㅜ 대여일을 하루이틀정도 늘려주시거나 다음웹툰처럼 아예 영구대여하는 식은 어떨까요? 매주 쭉 결제하면서 보고싶은데 같은회차를 두번 결제하는 것이 아까워 늘 고민하게 되네요ㅜㅜ
# 앱 깔면 쿠키준다해서 깔았는데 들어온 쿠키는 없고 와이파이도 잘 되는데 앱이 안들어가지는데여 ;;
# 개cyka같은 일상툰 되도 않는거 올리고 돈주지말고 제발 좀 똑바로 된거좀 살려라 하늘쌤은 피곤해 왜 죽였냐 진짜 생각없냐 업 그따구로 쌓지마라 나중에 한번에 터진다
# 다 좋고 괜찮은데 베도 웹툰 좀만 더 등용하고(딴 사이트에서 좋은건 다 데리고 가자너) 휴재 웹툰 전용 칸도 만들어 주시면 안되나요? 휴재작들이 완결 칸으로 가니까 조금불편해요
# 인기없는 웹툰 급종결시키는거 너무싫네요...게다가 그것도 제가 다 좋아하는 것들이라뇨...이거 어떻게 못하나요...
# 이 어플덕분에 네이버에 직접 않들어가도 되고 시간 절약이 되는것 같아서 좋습니다 웹툰보는 사람들은 이 어플을 굉장히 많이 사용할것입니다 이 어플은 잘 만든 엄청난 어플이어서 별5개를 드립니다.
# 지금 웹툰 자체가 안떠요. 무슨 일인지 오류인지 깔았다 지워도 안되네요
# 정말 하루하루 웹툰 기다리고 보는 맛에 살아갑니다. 정말 재밌네요.
# 다 좋은데요 돼지만화를 연재 종료 해주시면 감사하겠습니다 그럼 별점 5점 드릴게요 돼지만화가 네이버 웹툰 평판 다 깍아먹고있는거 알고 계시죠? 너무 제목과 안맞는 소재를 매번 가지고 오시는 돼지작가님은 정말 그림에 소질이 없고 내용도 신박하지 않은것 같네요 그리고 내용마다 '개'라는 것을 많이 이용 하시는 작가님 때문에 너무 기분이 안좋아요 제발 돼지만화 연재종료해주세요
# 장난 해요? 아니 내가 좋아하는 웹툰들만 다 연종 시키고.지금 필요 없는 돼지만화나 연재 시키고 요즘 네이버 일 안해요? 어이 없네?
# 진짜 불편한거 한개 있음. 이건뭐 몇년이 지나도 바뀔생각조차 안하는게 그저 신기함. pc말고 모바일로 볼때 이 만화는 무슨요일 만화다라는 표시가 없어서 불편함. 특히 신작나오면 이거 무슨요일 만화인가 하고 찾아봄
# 왜 돼지만화같은 쓰레기같은웹툰들은 안없애고 다른 좋은웹툰들을 삭제하니 네이버야? 아 낙하산이구나 ㅇㅋ
# '골든 체인지'라는 갓.띵.작. 이 있는데여 작가님 편찮으셔서 휴재를 좀 길게 4개월동안 했는데 갑자기 완결 작품으로 넣어버리네요;; 그리고 제가 본 휴재했는데 완결에 넣어버린 웹툰들는 다 안 돌아왔는데.. 설.마. '골든 체인지'도 이렇게 안 돌아오는건 아니죠?ㅎ 제발 이번년도 안에만 돌아왔으면 좋겠네용..^ㅎ^
# 컷툰 볼 때 좌우 터치하면 넘어가게 바뀐 것 같은데 좀 불편하네요. 사람마다 다를 수 있으니 이 기능 선택해서 껐다 켤 수 있으면 좋겠어요.
# 최소한 완결하고 적어도 1년뒤에 쿠키화 해야하는거 아닙니까 무슨 4개월도 안되는걸 쿠키화하면 어쩌라는겁니까
# 무료쿠키 얻을려고 앱도 깔고 회원가입도 했는데 주기는 커녕 연결끊겼다면서 안되네요..안씁니다
# 쿠키 공짜받기로 게임을 깔고 실행했는데 안 줘서 앱을 나갔다가 들어왔는데 쿠키받기가 안 뜨고 사라져있네요
# 와 진짜 최악. 웹툰들은 다 재밌긴한데 쿠키 얻을려고 쿠키오븐에서 뭐 설치하고 최초 실행 같은거 했는데 쿠키 안주고 네크워크가 연결이 안됬다나 뭐래나 .. 뭐 실행. 설치만 하면 평소엔 잘 됬던 쿠키 오븐이 안들어가지고.. 쿠키는 못 받고.. 문의 했는데도 계속 그래서. 지웠다 깔기도 해보고 별의 별짓을 다했는데 안돼서 아직 미자라 현질하면 부모님께 혼나서 현질도 못하는 중인데 무료쿠키에서 좀 설치하고 얻을려 했더니 망할.. 안되고 쿠키를 얻으라는건지 말라는건지.. 증말 모르다.. 웹툰이 재밌어서 아직 이용하고 있지.. 웹툰도 별 ...
# 전체 리뷰
# 갤럭시 S7 엣지 7월 1일 보안패치 후 읽는 도중에 강제종료되는 현상이 있네요 캐시/데이터 삭제해도 안되고 재설치 해도 안됩니다 확인바랍니다
# 아니 요기요 130개를 얻었는데 왜 시간제한이 있음? 개빡;;;
# 좋은데 쿠키 좀 안사라지게 해주세요...자꾸 쿠키10개 모아도 일주일돼면 사라지니깐 할게 없음...부탁드립니다...
# s8+에서 노트9로 옴겨왔습니다. s8+ 부터 지금 기기인 노트9까지 와파에서 자꾸 모자이크화면만 나오고 웹툰이 나오질 않습니다. 다른 댓글이나 이런건 나오면서요. 같은 장소에서 다른 안드로이드 패드는 잘나오는데 말이죠... 웹툰 어플 재설치는 몇번씩 해봤는데 해결되지 않네요.. 그러고보니 2호선 전철쪽에서 다른 사람들은 보는데 데이터를 켜도 저는 안되고.... 뭐가문제일까요?
# 안녕하세요 2년째 웹툰을 좋아하고 보고 따라그리는 소녀 양초코라고 합니당! 처음으로 웹툰을 보게 되었을 때 친구가 여신강림이랑 연애혁명이라 는 웹툰을 보라고해서 봤는 데요 정말 재밌는 장면이 만더라고요! 웹툰 처음보는 분들! 여신강림이랑 연애혁명을 꼭! 보세용!
# 아니 쿠키 받기 너무힘들어요 진짜 진심 짜증남 이벤트도 할려니 복잡한게 계속 튀어나옴
# cokeplay앱 설치하고 가입하면 쿠키9개 준다고 했는데 지금받을수있는쿠키만 줄어들고 쿠키 들어온건없쭘...
# 앱에 특정 장르 (ex 스릴러) 표지 안보는 기능이 있으면 좋겠어요. 밑에 있는 웹툰 보려다가 스릴러 표지를 봤더니 심장이 내려앉네요. 설정 창에 노약자, 어린이, 임산부를 위한 기능이 생기면 좋겠습니다.
# 보통 웹툰이 11시쯤에 올라오는데 왜 그시간에는 왜 알림이 뜰 수 없는것인지 아무리 쿠키오분이지만 그래도 어떻게 대부분이 가입하고 구입하라는것임? 쿠키 사고 싶지 않아서 오븐에 가는건데 미리보기를 보고 싶어도 볼 수 가 없잖아요 그리고 대여를 하지말고 그냥 계속 두면 안됨? 쿠키 써서 어렵게 결제했는데 3일뒤에 대여 만료되어있다고 하고 또 어떤건 나이걸려서 못한다고 하고 왜 이런겁니까? 차라리 쿠키 돈 주고 사는게 더 낫겠다는 생각이 들 정도네요 개발자님 답글 확인좀 하시면 안될까요? 수정 좀 해주세요 업데이트 하지 마시구 모바일 ...
# 전체 리뷰
# 매일 재밌게 볼수있어서 너무 좋습니당 ! 감사해요 !
# 옆으로 슬라이드 해서 보는 웹툰이요^^ 이번 업데이트로 밑에 페이지 바가 생겨서 글씨를 완전 가려요
# 아니 다 좋긴한데 돼지만화 이런거는 왜 연제하는거죠? 빨리 연종하면 안되나요?
# 이거 갤럭시 노트 10에는 호환되지 않는 건가요 웹툰 컷들이 전부 오류가 떠서 하나도 볼 수 없네요
# 정말 좋아용 편리하고 재미있게 보고 근데 시작할때 로그인을 한다던가 그럴때 쿠키 10개만 줘도 저는 너무 좋을꺼같아용 10개만 주셔도 이 어플은 너무 좋은 어플일꺼같아요!
# 아니 무료쿠키 왜 안줘요? 냐가 안내사항이랑 사용방법 다 읽고 다 해서 말씀드리는데 왜 쿠키 안주는거죠? 3개정도 햇는데 쿠키가 안들어와서 미리 보기 못하고있네요 진짜 궁금한건데 왜안주는거에요?
# 완전 짱! 웹툰 다 재밌어요!!!!! 유튭보다 이거하는 시간이 더많음용!♡
# 접속자 많다고 로그인 안시켜주는건 뭐죠~~~~~ 로그인좀 시켜주세요~~~~~~♡♡♡♡
# 외부링크를 통해 웹툰을 열람하려고 하면 업데이트만 요구하고 실행되지 않음
# 요새 베도에는 정말 재미있고 좋은 작품이 많은데 신작으로 올라오는건 다 너무 그림체도 내용도 다 거기서 거기네요 수준이 너무 떨어지는 것 같아요 좀 인기 많고 좋은 작품으로 올려주시면 안되는 걸까요..? 답장 부탁드려요
# 공포장르 웹툰의 썸네일 가리는 기능좀 주세요. 무서워서 요일별 리스트에서 스크롤을 못내리겠음... 상위권에 공포물이 있는 요일은 그 요일 자체릉 보기 싫어짐
# 제가 쿠키를 받으려고 블레이드 앤 매직을 깥고 20레벨까지 케릭터를 확실하게 키웠습니다 그런데 시간이 많이 지나도 쿠키를 주지않아 쿠키오븐에 들어갔더니 브레이드 앤 매직으로 쿠키를 받는 부분이 사라져 있더군요 그래서 이걸로 쿠키받는게 끝났나 해서 블래이드 앤 매직을 지웠더니 쿠키오븐에 다시 이걸로 쿠키받는 부분이 다시 생겨났습니다 뭐지 해가지고 다시 깔았더니 또다시 그 부분이 사라져 있었습니다 네이버가 이걸로 속였다고는 생각안하지만 이 문제가 더이상 일어나지 않았으면 좋겠으니 이 부분을 고쳐주시기를 부탁드립니다
# 다른거 다 좋은데 저만그런건진 모르겠지만 최근에 웹툰보려고하면 내용이 중간에 로딩이안되는경우가 많아요.. 와이파이빵빵한데도 그렇고 심지어 모바일데이터에서도.. 개선좀 부탁드려요 보다가 내용로딩안된부분나오면 솔직히 좀 짜증나요..
# 혁박 작작하세요 하늘쌤은 힘들어 웹툰이 갑자기 이상하게 끝났는데 돈이 있으면 쓰고 없으면 버리시는 건가요
# 잘보고 있었는데요. 완결작들이 거의 다 쿠키가 필요하더라고요.
# 제발요 크크 저는 중국말을 너무 열심히 합니다 그리고 제가 한번 꼭 만나고 싶어요 뻥이에요
# 갤럭시 노트8을 사용중입니다 업데이트 전엔 안그랬는데 최근 업데이트 후에 웹툰을 보던 중간에 카톡 인터넷 등을 하고나서(홈버튼으로 웹툰은 내려놋호) 다시 앱을 들어가면 처음 켜지는것 처럼 메인화면으로 들어가집니다 예전에는 제가 보고있던 페이지로 이어서 들어가졌는데 이제는 아예 처름 키는것처럼 켜지네요 이거 왜 이러나요
# 안녕하세요?이 웹툰을 즐겨보고있는 게됴 (채빔)입니다!너무 재미있어요 한개한개를 봐도 너무 웃긴데 쿠키 때문에 일주일을 기달려야한다는게 너뮤 힘들어요ㅜㅜ그 점만 고쳐주시면 될거같네요 ㅎㅎ 전 대리만족해서 별 5개 쏘고 갑니덩ㅎㅎ
# 5g 로딩이 안됨,,, 5g 쓰는데 잘보다가.갑자기 로딩이 안되서 볼수가 없어요
# 네이버... 요새 일하는 거야 마는거야... 쿠키 작품은 왜이리 많고! 예전 대작 다시 데려와서 운영하는거... 진짜 보기 시름... 진짜 왜그러는지 좀.... 안 알려주면 짜증나 뒤질 것 같음...
# 옛날에 웹툰이 무엇인지 몰라 한먼 친구에게 물어봤는데 친구가 그 중에 네이버 웹툰이 좋하고 하더라구요.그래서 스토어에 쳐봤더니 네이버 웹툰이 딱 나오더라 고요. 그래서 설치 했어요. 넘~~~~재밌는 웹툰
# 웹툰을 정말 좋아하고 많이 보는 사람 중 한 명입니다 본론부터 말하자면 쿠키가 안 들어왔어요 무료 쿠키 이벤트에서 바이브 앱을 깔았는데 안 들어왔네요
# 아니 네트워크 연결 완전 됐는데 연결성태 확인 하라네요;;고쳐 좀 주세요
# 네이버웹툰 앱에 들어가서 MY에 들어가서 내 쿠키에 들어가기위해 내 쿠키를 클릭할때마다 계속 튕깁니다. 빨리 고쳐주십시오.
# 안녕하세요 네이버 웹툰을 잘 사용하고있는 유저 입니다 제가 초등학생이다보니 쿠키가 필요할때 무료 쿠키에 들어가보면 시간이 제한이 있고 또한 어린이들이 못하는 미션이 있습니다 제발제발 무료쿠키에 시간제한또는 초등학생이 이용할수있을 정도의 미션으로 만들어 주시면 감사하겟습니다 그리고 쿠키를 더 많이 얻을수있고 쉽게 쿠키를 얻을수있게 해주시면 감사할거 같습니다 웹툰을보면 쿠키가 필요한것도 있고 안필요한것도 있지만 쿠키가 2개가 있어야 가능하는데 쿠키를 낼때 2개에서 1개로 줄여주시거나 쿠키를 살때 더 쉽게 얻고 즐거운 웹툰을 보게 해주시...
# 전체 리뷰
# 다 좋은데 무료쿠키에서 미성년지가 할 수 있는 굉고를 더 넣아주셨으면 합니다.
# 와이파이 잘 터지고 있는데 로딩이 전반적으로 너무 느리고 간혹 보다가 중간에 로딩안되는 컷도 많네요..
# 아니 내가 웹툰을볼려고 12시까지 기다렸는데왜 볼수가없지?
# 좋긴 좋은데 무료쿠키를 얻을려고 하는데로 했는데 쿠키를 주지 않네요...
# 음...이전에 시리즈라는 앱을 사용했데. 그건 돈(쿠키) 이 있어야 했습니다. 그랬는데 네이버 웹툰은 요일마다 새로운 컷을 돈을 내지않아도 되니까 편리했습니다!
# 제발제발 자신이 쓴 댓글 정도는 찾을 수 있었으면 좋겠네요
# 현백 회원가입 쿠키받기에 참여했는데 밑에 상세내용 다 읽어봤고 회원가입까지 하라는대로 잘 했는데 쿠키가 계속 안들어오고있네요. 어떻게된건가요?
# 지금 쿠키 결제했는데 자꾸 에러뜨네요.. 빨리 복구좀 해주세요
# 아니..쿠키오븐에서 하라는걸 해도 왜 쿠키가 지급이 되지않는거죠? 지금 장난하나요?
# 무료 쿠키 유효기간 없애주세요.. 130개중에 8개인가 썻는데 없어졌어요ㅠㅠ
# 완결한 웹툰들 언제든 다시보게 해주세요ㅠㅠ잠금되있어서 보고싶은걸 못봐요 잠금이 않되있으면 언제든지 다시 볼수있잖아요. 잠금안하고 다시보기 할수있게 해주세요 부탁있니다.
# 와...검색하고 보는 재미는 있는ㄷㅔ에...나만의 웹툰?그리는거 있음 감사하겠습니다아~!
# 다 좋은데 가끔 웹툰을 보다가 웹툰 컷이나 화면이 깨져 나올때도 있고 나중에 와이파이안될때 영상으로 웹툰 찍어놔서 볼려고 찍고 영상을 확인해봤는데 검은 화면만 나오네요. 제 폰이나 영상을 찍는 앱 문제일수도있지만 네이버 웹툰앱이 문제가 살짝 되는게 있을수도있어 올립니다.
# 나쁘진않지만 그렇다고 편리하지도 않습ㄴ다 특히 보다가 다음편으로 넘어가고싶을때 그 상태바가 정말 별로에요 누르려고하면 없어지고;; 또 직관적이지 못해서 화면에서 찾고싶은 웹툰을 거의 찾을수가없고 검색으로 찾아야한다는 점입니다 가장 문제라고 생각되는 점은 네이버웹툰 현재방식으로는 신인작가의 웹툰은 상위로 올라오기 힘든방식이고 그래서인지 타플랫폼에 비해서 신선함이과 작품성이 떨어지는 작품이 많아지는거 같습니다 막말로 수준이 떨어져서 제 나이또래들은 웹툰 거의 안보더라구요 신경 좀 써주세요
# 무료쿠키 알바콜 깔아서 회원가입하고 페이코로 하라는거 까지하고 정보쓰라는거 다 쓰고 다 했는데 개인정보와 마케팅정보활용동의와 SNS광고동의만 받아쳐먹고 배째면 어쩌나요? 알바콜 무료쿠키 뜨자마자 12시에 바로 했는데 다 하고 다시 보니깐 아예 없어졌네요?
# 그리드 컴퓨팅 아직도 하고있었냐? 미리 리뷰 체크 안했으면 큰일 날뻔했네...
# 진짜 요일마다 기대되는 웹툰이 하나에서 세개정도있는것같아요! 너무너무 재미있고 기대되는 하루하루를 살아갑니다! 바로바로 네이버 웹툰 덕분이죠!
# 겟짤에서 내가 만든 짤이 총 몇개인지 알 수도 없을뿐더러 저장하면 화질이 살짝 구려짐...게다가 인정한 짤은 작성자가 삭제했음에도 불구하고 목록에 계속 있어서 그닥....다른건 다 괜찮은듯 웹툰 장르별로도 볼 수 있으면 취향껏 찾아보기 좋을듯한데 없음
# 좋아하는 웹툰을 볼 수 있어서 기분이 좋다~~
# 쿠키오븐에서 무료로 쿠키 주는건 좋은데 뭐 구매하기, 회원가입 이런것들만 많아서 미성년자가 쉽게 모을 수가 없어서 불편해요ㅠㅠ
# 웹툰보다 화면이 멈추며 메인화면으로 돌아가는데, 밑의 버튼 GUI도 작동이 안돼는거보니 램을 많이먹거나 충분히 쓰지 않아서인듯함. 예전엔 그러지 않았으나 요즘 그럼 발적화좀 수정해줬으면 LG Q7씀
# 아니 이건좀 아니잖아요? 왜 니이버에서 불리한 댓글만 지우는거죠? 그리고 하루3컷은 강제 종료 그리고 또 신규 웹툰 뽑는 기준이 뭔가요? 진짜 네이버 실망입니다
# 웹툰을 보려하는데 잘 안들어가지고 들어가져도 댓글을 볼 수가 없네요. 개선부탁드립니다.
# 다 좋아요!👍💞마음에 드는거 골라 볼 수도 있고 자기가 본 걸 저장해둘 수도 있어서 짱 좋음.
# 근데 유료보다 카카오페이지처럼 기.무 하면 안되나? 이상하고 아름다운 유료화되서 못보는데 너무 편까지 많음....ㅡㅡ
# 좋아요!좋은데 이벤트칸이 따로 있으면좋겠어요!
# 너무 좋네요^^ 깔아봤는데 재밌어서 계속 보고 있습니당!
# 재미있는 웹툰이 매일매일 나와서 너무 좋습니다!
# 어제 업대이트 했는데 그뒤로 어플이 아예 안열리네여 나도 웹툰 보게해줘
# 몇일전부터 와이파이로 웹툰을 들어가면 맨위에 3분의1만 뜨고 나머지는 다 체크무늬 로딩화면 밖에 안떠요.. 앱도 지웠다 깔고 전원도 껐다 켰는데 데이터로 밖에 볼 수 없네요 오류 수정 좀 해주세요ㅜ
# 너무 재미있는 웹툰이 한가득? 너무 재미있어요 많이 보세요!!!
# 오늘 갑자기 웹툰을 결제 해서 볼려했는데 쿠키가 갑자기 다 사라져있네요 이게 무슨 경우인가요 장난하십니까 ㅋㅋㅋㅋㅋㅋ 쿠키 돌려줄 생각이 없나보네 답장도 없네 좋은말로 할때 답변달아라 불 질러 뿌기전에
# 입시명문사립 정글고등학교도 재연재해주시면 안 돼나요?
# 돼지만화좀 퇴출시켜라!!! 완벽한 웹툰 퇴출시키지말고 네이버 망할것
# 교촌가입하고 쿠키 받으려고 하는데 진짜 가입하는거 너무 느리네요 가입이 지금도 가입이 안돼서 이렇게 올립니다.
# 외장메모리로 옮길수있게끔 만들어주세요 용량이 너무 커요
# 갤럭시 10 + 앱 접속이 안되고 강제종료 되네요ㅠ 어떤 오류죠?
# 지금 칼가는 소녀 쿠키주고 볼려는데 하얀 화면만 뜨네요.wifi문제인가 싶어 핸드폰도 다시시작하고,wifi도 계속 재연결 반복을 했습니다.뭐가 문제죠?
# 최신판에서만 지원되는 기능이라고 업데이트 하라고 해서 플레이스토어로 이동하면 업데이트가 안 되고.. 뭘까요.. 네이버...
# 진짜 최악입니다 무료쿠키 받을 수 있는 이벤트에 참여했는데 앱설치 이벤트같은경우에는 새로 설치한건데 이미 설치한 앱이라며 쿠키도 안 주고 이벤트는 없어져버리니까 고객으로서 누려야하는 것을 못 누리는것 같습니다 네이버웹툰 정말 실망입니다
# 다 좋긴한데 완결난 웹툰 몇개가 유료화인게 조금 아쉽네요ㅠㅠ 근데 재밌으니 별점은 5점입니당
# 요즘 중고등학생들 개나소나 다 계좌있고 카드 있어서 알아서 결제하는데 아직까지 미성년자는 법정대리인 동의가 있어야 결제할 수 있다니 시대가 어느땐데 너무 뒤쳐지는거 아닌가요.. 명색의 네이버라는 회사가
# 갤럭시 s10+사용중인데요 계속 강제종료현상이 나타나요 신작들만 키면그렇네요 신작킨다음에 다른 오래된것을 켜도 그렇고요
# 완전 재미있음. 설치 해봐!!
# 웹툰계의 정석. 댓글도 악플은 막아주는 센스. 근데 작품 선정을 좀 더 신중하게 해주셨음 좋겠다.
# 안녕하세요 연애하루전 이라는 웹툰(?) 작가 이름이 뭐에요 ?
# 미리보기 결재전에 이 앱이 필요하다는 걸 알려줘야 할거 아냐 결재한거라서 깔겠지만 ㅂ로 지우고 미리보기도 결재 안할렵니다
# 너무 좋습니다 다만 아쉬운점이 장르별로 분류되어있지 않다는점인데요. 장르별로 분류를 해놓는다면 보기가 더욱 편리하고 좋을것 같습니다
# 쿠키시스템에 관해서 말인데 무료로 주는 쿠키 받으면 며칠지나면 자동으로 소멸하는데 그것좀 어떻게 하면 안되나? 어제 받은 쿠키도 다 날아가잖아
# 쿠키오븐 참여해서 쿠키 3개 지급받아야 하는데 지급이 안됬어요. 제가 어떡해 해야하죠 너무 황당하네요
# 아니 이거 머니트리 회원가입 했는데 쿠키9개 안주시나요?
# 네이버 앱으로 웹툰 보던 사람인데 내가 내돈 주고 결제해서 다음화 보려니깐 다음화로 안 넘어가고 무조건 네이버웹툰 다운받게 링크창 열리네 내가 내 편의로 돈 주고 다음화 보겠다는데 은근슬쩍 지원 안 하는척하며 웹툰 다운받게 유도하지 마세요
# 아니 좀 ㅅ 학생들도 많이 이용하는데 쿠키 굽는걸 무슨 은행계좌신청 상품사는거 카드 회원가입 이딴거 밖에없습니까? 돈에만 환장하지말고 학생들이 할수있는 것좀 만들어주세요
# s10 사용자인데요. 요즘 웹툰 시작부분이나 끝부분 이미지 로딩이 잘 안되고 모자이크처럼 보이네요ㅜ
# 그...임시저장 기간...늘려주시면안돼나요..?ㅠ
# 너무 재미있어요 ㅠㅠ 다양한 웹툰이 종합적으로이루어져있고 요일별웹툰이라 한눈에 알아볼수있는듯해용
# 무료 쿠키 힌트 받고 테라 클래식 검색하고 같지만 또 다른 세계 라는 답을 적었는데 계속 틀렸다네요 왜 이러는건가요
# 공짜여서좋고 바로볼수있어서 좋아요!!
# 아니 회원가입을하는데 다돼어서 나왔는데 다시하라뇨? 그리고 번호도이제 안되고 좀 어떻게 해주세요
# '개를낳았다, 화장지워주는남자'추천
# 재미있고시간가는줄모르고 보는것같아요
# 컷툰이나 미리보기하려할 때 자꾸 팅깁니다. 빠른 수정 부탁드립니다.
# 너무 팅기는데 뭐 이런식으로 만들어놓았나요?
# 웹툰은좋은데내쿠키어쩔꺼임?나쿠키120개있었는데하루만에날라감....빨리고쳐주세요
# 제가 좋아하는 웹툰을 내이버에 귀찮게 안쳐도 재밌게 볼수있어서 좋은것같아요!!
# 다 좋아요 근데 겟짤에 검색하는거 만들어 주세요!
# 아니 웹툰을보고있는데 마지막에 와이파이 빵빵터지는 곳에서 마지막 그림이 안보여요 이거 개선좀
# 미리보기도 컷으로 짜를 수 있게 해주세요 아이폰은 캡쳐가 되는데 안드로이드는 안 되더라고요
# 하늘쌤은 피곤해 왜 중단시켰어어어 이 나쁜놈들아 ㅠㅠ 😭
# 이미 완결한 웹툰은볼 수 없어서 너무 아쉬워요 완결이 끝난 걸 보려면 쿠키를 사야해요 이점 이 매우 안타까워요 완결한 것 도 10화 이상은 볼수있게 해 주시면 안될까요?
# 쿠키 누락이 심해요~ 답답해서 원;;
# 네이버 웹툰 3년 째 쓰고 있는 유저 입니다 !! 요즘에는 사소한 냐냐라고 재미있는 숏애니도 생겨서 웹툰 볼 맛이 나요 !! 강추드립니다아 ~ ♥♥
# 다른 건 다 좋은데 왜 무료쿠키가 안 들어오져... (알바콜...)
# 업데이트 후 컷툰은 아예 안열리네여;; 확인바랍니다
# 댓글도 제대로 안뜨고 결제 후에 만화가 아예 안뜨고 너무 불편하네요. 이래서 뭘 어찌 쓰란건지
# 업데이트 이후로 이미지 로딩중에 튕깁니다.
# 오류 생겨서 웹툰이 안나옴 이거 어떻게 할건데? 오류수정좀 똑바로 해라 운영자들아
# 오늘 갑자기 웹툰이 안보여요 컷툰만 되네요 데이터로 이용중이구요
# 다양하고 저에 마음데로 살수있고 쿠키 구워서 다른사람거 또 볼수있어서좋았어요!
# 왜 트레이싱한 작품안내려요? 네이버 돼지만화처럼 화양연화도 낙하산이에요? 다음은 수준 높은줄알았는데아니었네요ㅋㅋㅋㅋ 다음웹툰측에서 왜 제제안해요?? 진짜최대의문ㅋ
# 댓글에 좋아요와 싫어요를 표시하는것에서 한번 표시했을때 변경이 불가능한것을 가능으로 만들어주셨으면 좋겠습니다 잘못 표시했을때 취소가 안되서 불편합니다
# 원래 대댓글 있던 자리에 싫어요가 생겨서 대댓글 보려고 누른게 싫어요를 눌러버리는 경우가 많아요ㅋㅋㅋ큐ㅠㅠ 잘못 눌러도 취소할 수 있으면 좋겠네요
# 앱을 다운받고 신규회원가입다 했는데 했다고 표시되지도않고 캐시가 들어오지도 않았습니다 다음 웹툰은 다 좋고 편리한데 이런점이 너무 불편합니다
# 아니 결제를 하려고 해도 무슨 결제수단이든 인증다해도 마지막에 웹툰앱에서 결제완료를 눌러야 최종결제가 되는데 결제비밀번호 입력하고 ars 인증하고 넘어와도 웹툰앱에서 그냥 하얀화면만 떠서 결제를 할수가 없음. 돈벌기 싫어요?
# 대부분 좋아요. 기능도 좋구요. 기다무가 성인인증을 해야만 하는건 좀 그래도요. 일단 무엇보다 중요한게요, 제가 앱 평가 전 다른분들 리뷰를 봤거든요? 왜 화양연화 트레이싱건과 관련된 리뷰에는 답변을 달지 않으시는건가요? 개인적으로 재밌게 보고있는 작품이라 더 궁금합니다. 그 건에 대해 답변하지 않으신다는것은 사실이라는 뜻인건가요? 화양연화를 연재하고 계신 나잔님께선 애매한 해명글만을 올린 후 그대로 침묵하며 다른 수많은 독자분들께 악플과 트레이싱을 해명하라는 압박을 받고 있는것을 알고있습니다. 그런데 왜 이 사건에 대해 다음에서는...
# 전체 리뷰
# 무료로 보는 이벤트때문에 정말좋은데 가끔마다 한개가 정립이안되면 못봐서;; 이런거는 고쳐주셨으면 합니다
# 웹툰 댓글보면 답글부분에 싫어요가 갑자기 생겨나서 의도치않게 사람들 댓글에 싫어요 누르고있는데 너무 불편하니까 다음 업데이트때 그전으로 돌려주세요
# 싫어요 버튼 예전 부터 사람들이 많이 요구했던건데 싫어요 생겨서 너무 조아요
# 오류인지 리뷰달아도 안달려요ㅜㅜ 제가 캐시이벤트로 H.point 앱깔고 신규회원가입까지 다 했는데 캐시가 안 들어왔어요
# 좋은 웹툰 많아서 좋은데 특정 장르 웹툰들의 댓글이 너무 더럽네요..; 댓글 안볼수 있는 기능을 추가해주셨으면 합니다!
# 화양연화의 나잔 작가 왜 받아줬는지 모르겠네요.. 그 작가 예전에 트레이싱 불법으로 사용했고 증거도 있는데, 네이버에서 안 받아준것도 그 이유라고 얘기 많이 하는데 다음웹툰 뭐해요? 진짜
# 미리보기를 하려고 캐쉬를 구했는데 미리보기 화 를 고를수가 없어요 이미 본 19화 뿐이고 24화가 있는데 구매를 못해요 선택도 안돼고
# V50 사용자입니다. 전체화면으로 읽을때 하단바를 숨길수없어 매우 불편합니다. 전체화면보기옵션만들기가어려우면 네이버웹툰처럼 하단바 숨길수있도록 하단바에 숨기기 버튼 생성되게라도 해주세요
# 웹툰에 들어가고 그 작품에 들어가면 다른사람들은 공지가 뜬다는데 저는 공지가 안뜨고 알림이 안와요
# 재미있는게 많아서 좋아요!!!!!
# 재밌는 웹툰도 많고 좋은데 혹시 자동스크롤 기능 없어졌나요?ㅠ 예전에 유용하게 쓰던 기능인데 쓸 수가 없어요 ㅠㅠㅠ
# 다음아이디로 로그인하려니 카카오통합했다고 통합아이디를 입력하라 그러고 그래서 아이디를 카카오걸로 입력하려니 다음 아이디에서 수정이 안되네요... 이럴거면 통합안했죠....
# 어제부터 로그인이 되지않고 있어 유료보기를 못하고 있습니다. 어플 삭제 후 다시 깔아도 안되네요
# 업데이트 하고나서 my웹툰에 찜한작품 기다무작품 표시가 없어지고 최근본작품으로 나와서 불편해요 최근본게 한번봤는데 큰 의미가없지 않나요? 개선해주세요
# 재밌는 웹툰들이 많아서 보는 재미가 더 더해지는거 같아요
# 최근 업뎃이후 자동 화면잠금 된후 웹툰을 보려하면 네트워크에 연결 되어있음에도 네트워크 연결을 확인하라는 창이 뜹니다
# 제가 캐시 머니트리 회원가입하면 캐시준다고해서 머니트리 회원가입을 했는데 캐시가 안들어오네요..ㅠ
# 태블릿이라 원래 폰이랑 동일한 계정으로 쓰려고 카카오 계정 직접입력하면 자꾸 오류만 뜨네요
# 웹툰 캡쳐를 허고 싶은데 보안정책 때문에 안되네요.. 캡쳐 기능이 있었음 좋겠어요...ㅠㅠ
# 로그인이 안되네요...
# 폰과 테블릿에서 내가 본 작품 회차가 공유되지 않습니다. 아이디로 로그인했는데 내가 뭘 봤었는지가 공유가 안되면 로그인의 이유가 뭐가남나요. 로그온의 기능이 캐시 결제와 사용만을 위함입니까?
# 예전에도 잘 봤는데 지금 나오는 웹툰들도 좋은 작품들이 많네요 언제나 흥하길 바랍니다 ㅎㅎ
# 다음 웹툰의 장점 중 하나… 미리보기를 결제하면 무료분으로 풀릴 때까지 볼 수 있다…ㅠㅠ 이건 진짜 좋은듯
# 웹툰 책 구매사이트를 웹툰화면에 나오게 해주면 좋을것같아요
# 트레이싱 작가도 빨아주는 다음 클라스. 그러니 네이버에 매번 밀리는거.
# 잘 사용하고 있습니다만 한가지 문제가 있습니다. 찜한작품 리스트가 계속 초기화돼요. 작품 하나하나 찾아서 다시 찜해도 다음날쯤에 작품 하나를 남기고 다 사라져요. 해결해주세요...
# 광고보고 캐시 들어왔나?하고봤는데 캐시가 없어요....ㅠㅠ그래서 나갔다 들어왔는데도 캐시가 들어오지 않았어요...
# 웹툰 보고 캐시 받는거에서 다 보아서 참여했다고 뜸에도 불구하고 총 1000캐시중 200캐시 밖에 안 들어왔네요... 캐시 주고 오류 고쳐주시기 바랍니다
# 어플이 깔끔하고 쓰기 좋아요 근데 어플 실행 후 폰화면을 잠시 껐다키거나 어플실행 후 홈화면으로 나갔다오는 등 어플화면을 잠시라도 끄거나 전환하면 다음 화 보는 버튼을 누를 때 오류가나서 어플을 아예 껏다가 다시 켜야지만 볼 수 있어요. 지속적으로 이런 현상이 발생합니다 ㅠ 어쩌다한번 아니고 계속이요 ㅠ 이부분만 수정해서 업뎃해주시면 조금 더 쾌적하게 사용할 수 있을 것 같아요 수고하세요
# 로그인이 되질 않네요 로그인이 되더라도 연동이 안되구요
# 아니 웬 업뎃을 개떡같이 했어요??기무는 볼 수가 없어요..내가 본 웹툰 목록도 기무랑 연재 웹툰이랑 같이 있고..기무 이용권 남은 예정일은 언제인지 모르겠고..진짜 진심으로 업뎃 이전으로 돌리고 싶네요..ㅠㅠ
# 다 좋은데 완결말고 연재부분도 장르별로 나눠져있는게 있으면 좋겠습니다!!
# 기다무로 보고있는데 제일 최근에 봤던 거 다음 회차들은 이용권 사용이 안되고 그 전 봤던 회차들만 이용권 사용할 수 있는 건 뭔가요..ㅋㅋㅋㅋㅋㅋ 유료웹툰 무료로 볼 수 있게한 건 감사하지만 갑자기 보고 있는데 이용권으로 다음 회차는 안된다는 건 아니지않나요
# 필터에 무료체크가 왜없나요
# 처음에는 좋다고 생각을 했지만 트레이싱을 한 작가를 올려놓은게 별로네요 그 작가는 사과도 없고 계속 덮어지길 발하는 것 같네요
# 와이파이나 데이터가 다 잘연결되어잇는데 한화한화 볼때마다 네트워크가 불안정하다니 뭐라니 화나서므볼수가없ㅇ네오
# 왜 캐시를 힘들게 얻었는데 왜 1일마다 소멸을 해요?!
# 웹툰 최신 버전인데 1000캐시 이벤트참여했는데 550캐시 만 받았네요 ㅠ
# 연재가 될 때 미리보기를 돈주고 구매를 했었는데 완결되니까 또 구매를 해야지 볼 수 있더라고요...
# 화면넘김이 부드럽고 좋습니다. 다음웹툰 화이팅 좋은 작품만 선별해주세요~ 잘보고있어용~~
# 그... 기다무웹툰 창이 사라진거같아서... 어디있는거죠....? 원래는 MY웹툰 누르면 찜한 작품 옆에 있던걸로 기억하는데...
# 정말 볼거리가 많고 기능도 예전보다 훨씬 좋았졌는데 단지 완결하고 유료화된 웹툰에 소장기능이 없어서 너무 아쉽습니다 어떻게 안될까요?
# 어플관리 진짜못하네 와이파이 환경인데 왜자꾸 만화가 안뜨는거고 새로고침만뜨는데 이러니깐 네이버랑 비교된다는소리듣지 이런글남겨봤자 보지도않고 본다하더라도 고쳐지는건 없고 형식적인답만하겠지
# 예전에는 야간모드가 있었던 것 같은데 이제 없나요? 있었으면 좋겠는데 다시 만들어주세요
# 잘쓰겠습니다. 다음 상병 화이팅
# 웹툰 캡쳐 못해요?
# 카카오계정으로 로그인이 안돼
# 왜 저는 1000캐시 이벤트가 안보이죠??
# 매일 매일 즐겁게 보고 있어요
# 재밌는 웹툰들너무 많아요~~~만족함니다.
# 내가 보던 기다리면 무료란만 있던게 사라지니까 너무 불편해요 알림 놓치면 다시 찾아서 봐야하고....
# 왜 자꾸 아이디랑 비번맞는데 없다고 로그인이 안되요??비번 몇번을 바꿔도
# 업로드마크는 왜 19금처럼 해놔갖고는ㅋㅋ 아무생각없이 그냥 다른 웹툰회사 따라서 만든어플...
# 더블모니터 업데이트하셧네요 수고하셧습이당 ㅎㅎㅎ
# 저만 기다무 칸?없어졌나요...
# 현재 먹통중 공지나 조치 바랍니다 ㅜㅜ
# 로그인 했는데 왜 자꾸 안할걸로 되어
# 웹툰이 다 넘 잼있어요! 꼭 보세요!
# 리그부터 정식웹툰까지 전부 댓글이 안보이는데 저만그런가요?ㅠ
# 좋았는데 기다무 웹툰 칸이 사라져서 불편해요 ㅜㅜㅜㅜ 다시 만들어주세요
# 웹툰리그 댓글내용이 안보여요 ..
# 업데이트 후 더 불편해졌네요. 기다무는 왜 없앤는지..
# 다음웹툰을 재밌게 사용하고 있는 유저입니댜~!재밌는 웹툰이 너무 많아요!!개발자님 힘내세요! 추천하는 웹툰으로는....그놈의 스캔들, 포 더 프린세스 등등.....이 있습니닷!재밌게 봐주세여~(광고가 아닌 그저 의견일 뿐입니다...제발 오해하지 말아주세요...ㅠ) 개발자님과 다른 모든 작가님들 파이팅~♥ 응원힐게얌!!
# 전체적인 인터페이스나 이용자의 편의성을 생각한 서비스 등은 잘 되어 있습니다. 다만 별점 3점을 드린 이유는 첫째, 웹툰 정렬 시스템이 없어 오로지 제목과 그림체만으로 볼 웹툰을 정해야합니다. 장르, 인기도, 평점 등의 가시적 자료가 명시되어 있지 않아 불편함이 있습니다. 둘째, 웹툰 스크롤 최하단에 베스트댓글 두 가지가 보이는데, ON/OFF 기능이 있었으면 좋겠습니다. 보기 거북한 댓글이나 논쟁이 일어날만한 댓글을 보게될때마다 해당 웹툰의 전반적인 독자 수준을 평준화하게 되고 더 크게는 다음 웹툰의 이미지까지 저평가하게 됩니다....
# 전체 리뷰
# 다 좋은데 결제할 때 신용카드만 쓸 수 있어서 불편하네요. 체크카드로도 결제할 수 있게 만들어 주셨으면 좋겠어요. 카카오 통해서 말구요.
# 다름이 아니라 어디다 문의해야할지 모르겠는데 여기다가 문의할게요 그 '소녀신선'이라는 웹툰이 있는데 작가님이 6개월이 지나도 아무런 소식,공지가 없으셔서 무슨일 있나 싶어서요...ㅠㅠㅠ혹시 알려주실수 있나요? ㅠㅠ
# 다음웹툰 예전부터 재밌고 즐겨보는 작품들도 꽤많아서 결제도 자좌하면서 보고있어요. ㅇ근데 요즘엔 다음웹툰 이용하기가 불편해서 별로 쓰고싶지 않게되요. 결제 과정이 너무 복잡하고 어려워요 왜 여러화를 선택해서 결제못하고 하나하나 따로 결제해야하나요? 그리고 카카오페이지나 네이버웹툰처럼 간편비밀번호로 바로 결제되는게 아니라 또 공인인증서랑 핸드폰 인증이랑해서 복잡해서 이제 결제안하고싶어요. 제발 유료화해서 돈을 벌고싶은거라면 다른 웹툰 사이트 결제루틴을 보면서 쫌 배우셨으면 좋겠어요. 이런식이면 결제는 커녕 다음웹툰자체가 불편하게 느껴...
# 전체 리뷰
# 이 댓글 담당하시는 분에게 그런 권리가 있는지 모르겠지만, 꼭 어플 기획자분께 이 내용을 전달해주시면 좋겠네요. 예전에는 다음 신작이란 신작은 모두 볼만큼 애정했었어요. 그런데 구성이 바뀐 후로는 정말 눈이 안가네요. 제목이 왼쪽에 있고, 썸네일이 오른쪽에 있는데. 보통 사람은 본능적으로 글자보다는 그림에 눈이먼저 가죠. 그런데 한국사람은 왼쪽에서 오른쪽으로 쓰고 읽기때문에, 그림에 눈이 갔다가 다시 왼쪽으로 제목을 본다는게 굉장히 부자연스러워서 잘 안들어와요. 제발 썸네일을 왼쪽에 두고 제목을 오른쪽으로 바꿔보세요. 처음에는 이 ...
# 전체 리뷰
# 아래 두 분 의견을 보고 앱 리뷰 난생 처음 남겨봅니다. 민주님 말씀에 동의합니다. 태엽님 말씀도요. 민주님 말씀대로 저 또한 시각적 우선순위가 적절한지 확실히 납득하긴 힘듭니다만, 태엽님 말씀처럼 개성도 무시할 부분은 아니라고 봅니다. 단지 태엽님께서 아래 '민주님 의견을 무시하라'는 마지막 문장은 아니라고 봅니다. 민주님 말씀에는 전부 다 갈아엎을걸 전제로 다시 UXUI를 구성해봄이 어떤지 제안한 것이기 때문에 태엽님이 말씀하신 좌측의 요일부분에 대한 문제는 다른방식으로 해결될 문제입니다. 다음웹툰측에서도 다양한 고민 후에 현재...
# 전체 리뷰
# 다음 웹툰 이용자로서 안타까운 점이 있어요. 다음웹툰의 특징인 스포일러 댓글을 가려주는 것은 굉장히 좋다고 생각합니다. 하지만 때로는 어이없는, 누가봐도 아닌 댓글들까지 포함시키지만 큰 문제는 없다고 생각합니다. 그런데 진짜 별로인 부분은 웹툰의 댓글이 음란한 영상을 보게 끔 유도하는 듯한 댓글들을 예전부터 꾸준히 봐왔지만 이번엔 그 댓글이 베스트 댓글까지 올라온 것을 보고 정말 댓글 관리를 하나도 하지 않는다고 느끼고 불쾌감을 초래한다고 생각하여 글을 남깁니다. 꼭 개선해주세요.
# 웹툰을 보면 주는캐쉬가 계속 안받아져요...
# 최고입니다. 항상 사용할 때 마다 기획 및 디자인팀에 감탄하며 사용합니다. 업데이트 이후로 정말 심플 모던해졌네요. 다른 웹툰 플랫폼도 본받았음 좋겠어요. 다만 소소하게 웹툰 한편, 두편씩만 결제를 하고 싶어도 최소충전금액 제한 때문에 본의아니게 훨씬 더 많은 금액을 충전해야 하는 점이 아쉬워요. 추가로 댓글의 좋아요 및 싫어요 취소 기능도 있으면 좋을것같아요. 실수로 눌린걸 취소할 수 없는게 좀 답답하더라구요. 어쨌거나 잘 사용하고 있습니다.
# 웹툰을 보면서 스크롤을 내리다가 바닥까지 아래로 내리면 아에 어플이 꺼집니다. 이거왜이러나요 한편볼때마다 바탕화면으로 가네요 거기다가 최신앱으로 업그레이드했는데 계속 업그레이드하라고 뜨구요
# 부분부분 유료화가 되어 있는 것 같은데 정주행하려니 전체를 무료로 볼 수 있는 건 하나도 없네요. 네이버 웹툰은 완결된 작품도 왠만하면 거의 무료로 볼수 있는데.. 다음웹툰은 사실상 무료가 사라진게 아쉽습니다. 혹시나 들어와 봤는데 역시나라.. 그냥 지우고 다시 네이버로 넘어갑니다.
# 다음웹툰만의 특이한 인터페이스 같은 것들이 매력적인 것 같아요. 아랫분이 썸네일 오른쪽에다 하라고 했는데 솔직히 그건 별 상관 없는 것 같아요.. 왼쪽에 월화수목금토일이 있기 때문에 썸네일을 왼쪽에 놔버리면 너무 왼쪽으로 무게가 치우친 듯한 느낌이 들 것 같네요.. 그냥 지금이 훨씬 시각적으로 편한 것 같아요. 아랫분 말은 그냥 무시하세요
# 핸드폰은 제명의가 아니지만 카드는 제명의에요. 네이버에서는 핸드폰 본인인증같은거 안하고 카드로 결제가능했는데 다음은 왜 하라고...? 다 유료로 전환시켜놓고 결제방식의 범주를 좁게 해놓으니까 뭘 볼수가 없어요;; 빠른 수정 부탁드립니다
# 로그인이안됩니다
# 네이버처럼 완결되서 유료인 웹툰은 리스트에서 미리 유료라고 표시가 되어 있었으면 좋겠어요. 요즘 새로 완결 됐다고 뜬 웹툰 들어가면 순 이용권으로 보라는 것뿐입니다. 그 작품들도 결국은 유료 웹툰 아닙니까? 미리 유료 표시 해줬으면 좋겠어요. 한두개도 아니고.. 들어가는 수고 덜게요.
# ...좋아요재밌는게많아서좋아요 근데? 왜다른인기많이없는건 안걸면서 홍×나레드×톰같은 인기많은거는 이미나온건데도 거시죠? 솔직히 이미나온건 좀 보여줍시다 네? 보다가 중간에 끈키(?)면 기분 더럽잖아요? 그니까 이미나온건 보여줍시다 그거빼면 다좋아요
# 좋은 만화를 담을,, 플랫폼이 기본조차 안갖췄네요.. 무슨 생각으로 어플을 만들고,, 플랫폼을 운영하는지^^ 자신들의 생각과 지식이 옳다고 생각하지만 말고,, 사용자의 입장에서 세 번 더 생각하세요,, 이러니 네이버에게 영원히 2인자..^^*
# 다음웹툰 앱은 참 가독성도 별론데 자질구레한게 ㅆㅎㅌㅊ예요.. 혹시 네이버 웹툰앱 안쓰세요? 대체 웹툰 캡쳐하는데 아래반토막은 왜 짤리게 만들고 버벅대고 결제창은 2개인데 그중에 하나는 천원이하 하면 결제도 안되고...... 무엇보다 다음!!씩이나 되는 사이트의 웹툰앱 디자인이 저래도 되는건가요.... 앱이 별로니까 웹툰마저 찾아보기가 싫음.... 그냥.. 네이버 앱 디자인 보고 적당히 따라하세요.... 제가 다음웹툰에 애정하는게 많아서 하는소리예요ㅜ
# 아.... 만화가들이 아무리 열심히해도 플랫폼이 이러면 그냥 그거 안보고말지.... 너무 한거 아니야? 난 아이폰 쓰다 넘어왔는데 아이폰도 강제로 업뎃 시킬지... 비싼돈 주고 쓰는 내 기계가 타의적으로 강제성을 받게되니까 다들 이런 거부반응 아닌가 싶은데.. 처음쓰는 내 리뷰가 짜증나서 쓰는 이런 리뷰일줄이야...
# 다른 거 다 좋아요. 웹툰들도 너무 좋은 작품 많고 개인적으로 편하게 쓰는데요. 오늘 무료캐시를 받으려고 머니트리를 깔아서 회원가입을 했는데 캐시가 들어오지 않았는데 해결 좀 부탁드리겠습니다.
# 재미있고 잘 사용하고있지만 결제가 안되는게 아쉽네요..앱으로 안되면 데스크탑을 이용한 결제라도 됬으면 좋겠는데 한국카드만 입력이 가능하다고 나오고..ㅎ한국카드 살면서 써본적이 없는데..그것만 아니면 다 좋습니다
# 와 저번엔 결제 되게 간편하고 좋았는데 바뀐건가요???저번처럼 쉽게 되질 않아요. 업데이트하셔서 그런가 모르겠지만 진짜 불편하네요. 계좌결제 가능하게 해주세요. 아니면 결제 안해요.
# 저이거 완전 재밌게 봤어용!!!네이버 웹툰이랑 달라서 더재밌었던것 같네요
# 구버전 쓰다 강제로 업뎃하게 됐는데, 거슬려서 못 쓰겠다. 쓸데없이 화면전화 모션이 화려하고, 따로 끌 수 없는 설정도 없고. 그냥 보고있는데 자동보기니 그밖의 아이콘들이 거슬리게 자꾸뜬다.
# 별 한개도 아깝습니다. 자잘한문제들..보기 불편한 웹툰 분류방식.. 개발자님 쫌 고쳐야겠다는 생각이 안드나요?? 아니면 만들어놓고 관심이없어서 살펴보지도 않는건가요?? 본인의 일에 열정이 있다면 절대 이렇게 내버려두지 않을것같습니다. 왜 항상 네이버웹툰에 밀리는지 진지하게 고민해보세요.. 솔직히 웹툰 분류방식으로인한 가독성 '최악'입니다.
# 댓글에 싫어요 기능 좀 추가해주세요. 무조건 좋아요만 많이 받은 댓글이 베댓이 되니까 싫어요도 많이 받을 수 있는 편향된 베댓이 많이 보이네요. 이런식으로 베스트된 댓글때문에 눈살이 찌푸려져요.
# 다음은 프롤로그나 1화 봐서 캐시 주는건 괜찮은데 이용권을 사놨다가 쓰는건 없는건가요? 캐시 바로바로 보기엔 나중에 기무이용권으로 못 보는 화들에 쓰고 싶은데.....이용권을 바로바로 사서쓰는게 아니라 모아두었다가 필요할 때 쓸 수 있었으면 좋겠어요
# ㄹㅇ 불편해 죽겠네 그전엔 카카오페이랑 연동안돼있어서 그런지 결제가 더 간편했는데 이건 이제 뭐 결제하려면 공인인증서도 따로 필요하고 아주 귀찮아죽겠음.... 다음웹툰 쿠폰같은걸 무료아니어도 좋고 돈주고 사서라도 구해볼려했는데 이젠 그런거 존재하지도 않고 어쩌란 말이냐 왤캐 그지같이 바꿔놓음?
# 업데이트 될수록 하나하나 찾아 들어가야 볼 수 있게 해놓았네요. 광고도 좋고 추천도 좋은데 제발 사용자 편의를 고려해주세요.. 1. 찜한 작품 체크해서 한번에 지우던 기능이 툰 하나하나 '-'버튼을 눌러 한땀한땀 수작업으로 지워야 함 2. 기다무도 이용권들- 추천 작품과 리스트를 섞어놓아서 정작 보고싶은 건 스크롤 내려야하고, 리스트 수정도 안됨
# 혹시 좋아요 남긴거 해제하는 건 있나요? 저는 별로 찬성하지못하는 댓이있어서 밑에 답글볼려고 클릭했는데 모르고 좋아요를 눌러버렸어요ㅠㅠ 다시 클릭해도 이미 의견을 표시했다고 뜨고... 좋아요 해제하는 방법이 없다면 만들어주시면 좋겠어요ㅠㅠ
# 네이버웹툰이랑 페이스북 네이버 다 잘들어가지는데 다음웹툰만 들어가려하면 네트워크 연결 확인하라 뜨네요 와이파이 데이터 빵빵하게 터지고 그럼에도 다음웹툰만 안들어가지네요
# 자덩 내려가기 기능 개꾸울~
# 앱을 실행시킬때마다 서비스 연결이 원활하지 않다는 메세지가 뜨면서 자꾸 꺼집니다. 한두번도아니고 업데이트를해도 이러는데 대체 뭐가 문젠지 모르겠네요
# 다음 장사하기 싫어요? 200원 결제하는데 카카오페이 체크카드 빠꾸먹고 오류 오질나게 떠서 카드번호 입력도 안 되고 입력해도 결제로 안 넘어가고 내가 진짜 1000원 결제하자고 공인인증서까지 내야 돼요? 국정원 입사 심사야? 장사하고싶으면 좀 쉽게 갑시다 제발.
# 네이버도 카카오도 만14세이상이면 결제 다 할수있는데 왜 다음만 부모님동의를 받아야 되죠? 내가 성인물본다는것도 아니고 내돈 주고 내가 웹툰보겠다는데 왜 동의가 필요한지;;
# 다 좋아요! 다 좋은데 성인 / 일반 이렇게 나눴으면 좋겠어요! 19웹툰 화면 걸려있는거 보기 싫은데 자꾸 보이고 요일 웹툰에 성인 있는거 보기 싫어요. 성인 따로 했으면 좋겠어요. 그리고 리그 1부 2부 pc버전엔 없는데 모바일 버전에도 추가했으면 좋겠습니다!
# 제발 댓글 싫어요 기능도 넣어주세요ㅜㅜㅜ 위로 올라와서 눈에 보이는 몇몇 베댓들 때문에 댓글창에서 싸움나는 거 너무 보기 싫어요...
# 웹툰관련된 공지사항은 관리자가 없는것같다. 문제가 생긴거면 공지좀 띄워주지ㅡㅡ어플에는 잘보이지도 않아요.
# 너무 재미있어요
# 다음 예전에는 완결된것들 정주행 할 수 있어서 그 재미에 많이 이용했는데 지금은 완결만 되면 바로 유료결제되고, 이젠 연재중인 것 중 일부 화도 유료결제해야 하네요.. 명작들 많았는데 아쉽네요
# 웹에서 업로드 확인 못하게 해서 앱 설치 강제하는 인성 실화냐? 게다가 하는 일도 없으면서 뭣땜에 용량을 이렇게 많이 쳐먹는지;;; 이러니까 네이버한테 맨날 털리지 ㅉㅉ
# 아니 저만 그런지 모르겠는데요.분명 와이파이도 빵빵한데 웹툰 스크롤을 내리다보면 인터넷이 연결이 안됬을때처럼 되나요.웹툰을거의못보겠어요.
# 실명 확인에서 왜 국내 전화만 가능한가요? 혹시 가능하시다면 국외 전화번호도 추가해주실 수 없는지...
# 좋은 작품이 많아서 종종 유료결제도 하며 보고있습니다 그런데 구매가 아닌 대여만 있는점이 아쉬워요 좀더 돈 주고서라도 아예 구매가 있었으면 좋겠습니다. 종이 책보단 모바일로 보는게 좋아서요
# 브금이 안들려요
# 업데이트좀 그만해라진짜 그나마다음웹툰도 몇개남은거땜에 간신히보는데 관리이따구로해서 더보기싫어진다 니네는그냥 업데이트말고 현상태유지만하면 기본은유지하는거야 뭐하려고좀하지마 쓸데없고능력도없어
# ㅋㅋㅋㅋㅋㅋ조음
# 봤던 웹툰을 다시 보는 경우가 있는데 이전 위치가 저장되어서 불편합니다 끝까지 보고 다음화 버튼을 누른 케이스에서는 처음부터 보여주는게 좋지 않을까요? 정주행 모드가 있는건 알지만 조금 사용성이 달라요!
# 업데이트 아니면 사용불가래서 업데이트하는데 파일 다운도 안받아지네;; 너무 쓰레기같아서 리뷰 안남기는 사람도 리뷰남기게하는 대단한 앱입니다! 다들 별점 1점 주고 가주세요~
# 기다무 웹툰 보려고 무료는 다 보고 기다리는데 안돼서요...그래서 뭐..실명확인?필요하대서 했는데...만14세미만..이러면 어떡해해요? 버고싶어도 못보는거잖아요.. 그리고 평가?별점주기?거기 답변은 다 똑같드만...
# 로그인이 안돼요 카카오계정으로 로그인하라는데 카카오계정으로 로그인하기 버튼도 없고 뭘 하라는건지

# %%
p = re.compile( '[a-zA-Z0-9]+' )

# %%
m = p.sub( ' ', tmp[0] )

# %%
m
# Out:
# '쿠키 왜 안주세요 몇번째야 진짜 무료쿠키~ 이러면서 안주는게 한두번인가 내가 가입을 얼마나 많이했는데 방금 알바가입 머시했거든요?  개 빨리주세요;; 진짜 나말고도 많더만 이정도면 네이버 이거 고객기만이지 장난하나;;;; 그리고 작가님들 다 좋거든요? 근데 왜 자꾸 하위권짜르세요 장난하나 작가님들 작품이 장난이에요? 이상한 만화는 안 짜르고 스토리 탄탄에 작화 좋은데 하위권 다 짤라;;;'

# %%
# 전체적용
df['content'] = df['content'].apply( lambda x: p.sub( ' ', x ) )

# %%
# 컬럼 하나 추가
# star 컬럼을 참조하여 
# 긍정 : 별점기준 4 or 5       star > 3
# 부정 : 별점기준 1 or 2 or 3  star <= 3
# setiment : 'pos' or 'neg'

# %%
df['star'][:5]
# Out:
# 0    1
# 1    1
# 2    5
# 3    1
# 4    1
# Name: star, dtype: object

# %%
df['star'].dtype
# Out:
# dtype('O')

# %%
df['star'] = df['star'].astype(int)

# %%
df['star'].dtype
# Out:
# dtype('int32')

# %%
df.dtypes
# Out:
# app_name    object
# content     object
# good        object
# name        object
# regi        object
# star         int32
# dtype: object

# %%
def checkPosNeg( x ):
    if x>3:return 'pos'
    return 'neg'

# %%
#vx>3 and 'pos' or 'neg'

# %%
df['star'].apply( lambda x: x>3 and 'pos' or 'neg' )[:2]
# Out:
# 0    neg
# 1    neg
# Name: star, dtype: object

# %%
df['setiment'] = df['star'].apply( checkPosNeg )

# %%
df['setiment'][:2]
# Out:
# 0    neg
# 1    neg
# Name: setiment, dtype: object

# %%
# 마스크 인자로 조건이 참이녀석 NaN  or  대체
df['star'].mask( df['star'] > 3, 'pos' )[:5]
# Out:
# 0      1
# 1      1
# 2    pos
# 3      1
# 4      1
# Name: star, dtype: object

# %%
df.head(2)
# Out:
#   app_name                                            content good name  \
# 0    네이버웹툰  쿠키 왜 안주세요 몇번째야 진짜 무료쿠키~ 이러면서 안주는게 한두번인가 내가 가입을...    1   솜담
# 1    네이버웹툰  저기요... 갑작히 잘 되던게 왜 안 됩니까? 와이파이 빵빵한데 네트워크 연결상태를...    2   왈왈
#
#          regi  star setiment
# 0  2019-08-17     1      neg
# 1  2019-08-20     1      neg

# %%
# 조건이 거짓인 데이터를 찾아서 Nan or  대체
df['star'].where( df['star'] > 3, 'neg' )[:5]
# Out:
# 0    neg
# 1    neg
# 2      5
# 3    neg
# 4    neg
# Name: star, dtype: object

# %%
df.head(2)
# Out:
#   app_name                                            content good name  \
# 0    네이버웹툰  쿠키 왜 안주세요 몇번째야 진짜 무료쿠키~ 이러면서 안주는게 한두번인가 내가 가입을...    1   솜담
# 1    네이버웹툰  저기요... 갑작히 잘 되던게 왜 안 됩니까? 와이파이 빵빵한데 네트워크 연결상태를...    2   왈왈
#
#          regi  star setiment
# 0  2019-08-17     1      neg
# 1  2019-08-20     1      neg

# %%
# 트위터 형태소 분석기를 이용하여 품사를 포함한 분해 함수를 이용하여 
# 새로운 컬럼 classifier라는 항목에 리뷰를 형태소로 분해한 내용으로 채운다.

# %%
from konlpy.tag import Okt
pos_tagger = Okt()

# %%
tmp0 = pos_tagger.pos( df['content'][0] )
len(tmp0)
# Out:
# 90

# %%
# 형태소 분석시 정규화및 어근화 처리를 수행했다 <- 선택은 옵션
tmp1 = pos_tagger.pos( df['content'][0], norm=True, stem=True )
len( tmp1 )
# Out:
# 90

# %%
tmp1[:4]
# Out:
# [('쿠키', 'Noun'), ('왜', 'Noun'), ('알다', 'Verb'), ('몇번', 'Noun')]

# %%
# 대상을 좁힌다 => 명사 : Noun, 형용사 : Adjective, 동사(예비):Verb
# 위의것들만 남기고 제거
tags = [ 'Noun', 'Adjective', 'Verb' ]
# for word, tag in tmp1:
#     if tag in tags:
#         print( word, tag )
#[ ( word, tag ) for word, tag in tmp1 if tag in tags ]

[ tag for tag in tmp1 if tag[1] in tags ]
# Out:
# [('쿠키', 'Noun'),
#  ('왜', 'Noun'),
#  ('알다', 'Verb'),
#  ('몇번', 'Noun'),
#  ('진짜', 'Noun'),
#  ('무료', 'Noun'),
#  ('쿠키', 'Noun'),
#  ('이르다', 'Verb'),
#  ('알다', 'Verb'),
#  ('번인', 'Noun'),
#  ('내', 'Noun'),
#  ('가입', 'Noun'),
#  ('얼마나', 'Noun'),
#  ('하다', 'Verb'),
#  ('방금', 'Noun'),
#  ('알바', 'Noun'),
#  ('가입', 'Noun'),
#  ('머시', 'Noun'),
#  ('하다', 'Verb'),
#  ('개', 'Noun'),
#  ('줄다', 'Verb'),
#  ('진짜', 'Noun'),
#  ('나', 'Noun'),
#  ('많다', 'Adjective'),
#  ('정도', 'Noun'),
#  ('네이버', 'Noun'),
#  ('거', 'Noun'),
#  ('고객', 'Noun'),
#  ('기만', 'Noun'),
#  ('장난', 'Noun'),
#  ('하나', 'Noun'),
#  ('작가', 'Noun'),
#  ('들다', 'Verb'),
#  ('좋다', 'Adjective'),
#  ('왜', 'Noun'),
#  ('자꾸', 'Noun'),
#  ('하위', 'Noun'),
#  ('짜르', 'Noun'),
#  ('세', 'Noun'),
#  ('장난', 'Noun'),
#  ('하나', 'Noun'),
#  ('작가', 'Noun'),
#  ('들다', 'Verb'),
#  ('작품', 'Noun'),
#  ('장난', 'Noun'),
#  ('이상하다', 'Adjective'),
#  ('만화', 'Noun'),
#  ('안', 'Noun'),
#  ('짜르', 'Noun'),
#  ('스토리', 'Noun'),
#  ('탄탄', 'Noun'),
#  ('작화', 'Noun'),
#  ('좋다', 'Adjective'),
#  ('하위', 'Noun'),
#  ('짤', 'Noun')]

# %%
[ tag 
  for tag in pos_tagger.pos( df['content'][0], norm=True, stem=True ) 
  if tag[1] in tags ][:2]
# Out:
# [('쿠키', 'Noun'), ('왜', 'Noun')]

# %%
df['content'].apply( lambda x: [ tag 
  for tag in pos_tagger.pos( x, norm=True, stem=True ) 
  if tag[1] in tags ] )
# Out:
# 0      [(쿠키, Noun), (왜, Noun), (알다, Verb), (몇번, Noun)...
# 1      [(저기, Noun), (갑, Noun), (작다, Adjective), (자다, ...
# 2      [(개, Noun), (낳다, Verb), (를, Noun), (즐기다, Verb)...
# 3      [(하다, Verb), (두, Noun), (번, Noun), (아니다, Adjec...
# 4      [(아니다, Adjective), (장난, Noun), (하다, Verb), (고요...
# 5      [(자기, Noun), (취향, Noun), (걸, Noun), (맞다, Verb)...
# 6      [(아니다, Adjective), (왜, Noun), (무료, Noun), (쿠키,...
# 7      [(안녕하다, Adjective), (제, Noun), (하다, Verb), (없다...
# 8      [(요즘, Noun), (자꾸, Noun), (모자이크, Noun), (칸, Nou...
# 9      [(진짜, Noun), (진짜, Noun), (재밌다, Adjective), (보고...
# 10     [(쿠키, Noun), (주문, Noun), (이벤트, Noun), (알다, Ver...
# 11     [(저기, Noun), (돼지, Noun), (만화, Noun), (언제, Noun...
# 12     [(네이버, Noun), (웹툰, Noun), (컷, Noun), (볼, Noun)...
# 13     [(결제, Noun), (네이버, Noun), (어플, Noun), (바로, Nou...
# 14     [(제, Noun), (계정, Noun), (만들다, Verb), (아이디, Nou...
# 15     [(그렇다, Adjective), (모르다, Verb), (웹툰, Noun), (밑...
# 16     [(저, Noun), (의견, Noun), (사항, Noun), (얘기, Noun)...
# 17     [(아주, Noun), (편리하다, Adjective), (앱, Noun), (이다...
# 18     [(오다, Verb), (거, Noun), (무료, Noun), (쿠키, Noun)...
# 19     [(정말, Noun), (이제, Noun), (못, Noun), (참다, Verb)...
# 20     [(최고, Noun), (정말, Noun), (좋다, Adjective), (거, ...
# 21     [(컷툰, Noun), (볼때, Noun), (현재, Noun), (컷, Noun)...
# 22     [(돼지, Noun), (만화, Noun), (같다, Adjective), (건, ...
# 23     [(어음, Noun), (네이버웹툰, Noun), (개보, Noun), (독자, N...
# 24     [(좋다, Adjective), (로그인, Noun), (하다, Verb), (아이...
# 25     [(웹툰, Noun), (좋다, Adjective), (최근, Noun), (업데이...
# 26     [(베스트, Noun), (도전, Noun), (새로고침, Noun), (버튼, N...
# 27     [(외부, Noun), (사이트, Noun), (링크, Noun), (앱, Noun...
# 28     [(어차피, Noun), (리뷰, Noun), (달, Noun), (보다, Verb...
# 29     [(거, Noun), (왜, Noun), (요기, Noun), (첫, Noun), ...
#                              ...
# 290    [(오다, Verb), (저번, Noun), (결제, Noun), (간편하다, Ad...
# 291    [(거, Noun), (완전, Noun), (재밌다, Adjective), (보다,...
# 292    [(버전, Noun), (쓰다, Verb), (강제, Noun), (업뎃하, Nou...
# 293    [(별, Noun), (개도, Noun), (아깝다, Adjective), (자잘하...
# 294    [(댓글, Noun), (싫다, Adjective), (기능, Noun), (좀, ...
# 295    [(다음, Noun), (프롤로그, Noun), (화, Noun), (보다, Ver...
# 296    [(불편하다, Adjective), (죽겠네, Noun), (전, Noun), (카...
# 297    [(업데이트, Noun), (되다, Verb), (하나, Noun), (하나, No...
# 298    [(혹시, Noun), (좋다, Adjective), (남기다, Verb), (해제...
# 299    [(네이버웹툰, Noun), (페이스북, Noun), (네이버, Noun), (들어...
# 300    [(자덩, Noun), (내려가다, Verb), (기능, Noun), (개, Nou...
# 301    [(앱, Noun), (실행, Noun), (시키다, Verb), (때, Noun)...
# 302    [(다음, Noun), (장사, Noun), (하다, Verb), (싫다, Adje...
# 303    [(네이버, Noun), (카카오, Noun), (만, Noun), (이상, Nou...
# 304    [(좋다, Adjective), (좋다, Adjective), (성인, Noun),...
# 305    [(제발, Noun), (댓글, Noun), (싫다, Adjective), (기능,...
# 306    [(웹툰, Noun), (관련, Noun), (되다, Verb), (사항, Noun...
# 307                                  [(재미있다, Adjective)]
# 308    [(다음, Noun), (예전, Noun), (완결, Noun), (되다, Verb...
# 309    [(웹, Noun), (업로드, Noun), (확인, Noun), (하다, Verb...
# 310    [(아니다, Adjective), (그렇다, Adjective), (모르다, Ver...
# 311    [(실명, Noun), (확인, Noun), (왜, Noun), (국내, Noun)...
# 312    [(좋다, Adjective), (작품, Noun), (많다, Adjective),...
# 313                             [(브금, Noun), (들다, Verb)]
# 314    [(업데이트, Noun), (좀, Noun), (그만하다, Adjective), (...
# 315                                         [(조음, Noun)]
# 316    [(보다, Verb), (웹툰, Noun), (다시, Noun), (보다, Verb...
# 317    [(업데이트, Noun), (아니다, Adjective), (사용, Noun), (...
# 318    [(기, Noun), (무, Noun), (웹툰, Noun), (보다, Verb),...
# 319    [(로그인, Noun), (돼다, Verb), (카카오, Noun), (계정, No...
# Name: content, Length: 320, dtype: object

# %%
df['classifier']=df['content'].apply( lambda x: [ tag 
  for tag in pos_tagger.pos( x, norm=True, stem=True ) 
  if tag[1] in tags ] )

# %%
df['classifier'][:2]
# Out:
# 0    [(쿠키, Noun), (왜, Noun), (알다, Verb), (몇번, Noun)...
# 1    [(저기, Noun), (갑, Noun), (작다, Adjective), (자다, ...
# Name: classifier, dtype: object

# %%
df.head(2)
# Out:
#   app_name                                            content good name  \
# 0    네이버웹툰  쿠키 왜 안주세요 몇번째야 진짜 무료쿠키~ 이러면서 안주는게 한두번인가 내가 가입을...    1   솜담
# 1    네이버웹툰  저기요... 갑작히 잘 되던게 왜 안 됩니까? 와이파이 빵빵한데 네트워크 연결상태를...    2   왈왈
#
#          regi  star setiment  \
# 0  2019-08-17     1      neg
# 1  2019-08-20     1      neg
#
#                                           classifier
# 0  [(쿠키, Noun), (왜, Noun), (알다, Verb), (몇번, Noun)...
# 1  [(저기, Noun), (갑, Noun), (작다, Adjective), (자다, ...

# %%
import json

# %%
# 감정사전, 대략 7만여개의 데이터에 긍정/부정지수값이 세팅된 사전
with open('./data/SentiWord_info.json', encoding='utf-8') as f:
    score_dic = json.load( f )

# %%
score_dic
# Out:
# [{'word': '(-;', 'word_root': '(', 'polarity': '1'},
#  {'word': '(;_;)', 'word_root': '(;_;)', 'polarity': '-1'},
#  {'word': '(^^)', 'word_root': '(^^)', 'polarity': '1'},
#  {'word': '(^-^)', 'word_root': '(^-^)', 'polarity': '1'},
#  {'word': '(^^*', 'word_root': '(', 'polarity': '1'},
#  {'word': '(^_^)', 'word_root': '(^_^)', 'polarity': '1'},
#  {'word': '(^_^;', 'word_root': '(', 'polarity': '-1'},
#  {'word': '(^o^)', 'word_root': '(^o^)', 'polarity': '1'},
#  {'word': '(-_-)', 'word_root': '(-_-)', 'polarity': '-1'},
#  {'word': '(T_T)', 'word_root': '(T_T)', 'polarity': '-1'},
#  {'word': '(ㅡㅡ)', 'word_root': '(', 'polarity': '-1'},
#  {'word': ')-:', 'word_root': ')', 'polarity': '-1'},
#  {'word': '*^^*', 'word_root': '*', 'polarity': '1'},
#  {'word': '/^o^\\', 'word_root': '/', 'polarity': '1'},
#  {'word': ':(', 'word_root': ':', 'polarity': '1'},
#  {'word': ":'-(", 'word_root': ':', 'polarity': '1'},
#  {'word': ':-(', 'word_root': ':', 'polarity': '1'},
#  {'word': ':)', 'word_root': ':', 'polarity': '-1'},
#  {'word': ':-)', 'word_root': ':', 'polarity': '1'},
#  {'word': ':/', 'word_root': ':', 'polarity': '-1'},
#  {'word': ':|', 'word_root': ':', 'polarity': '1'},
#  {'word': ':D', 'word_root': ':', 'polarity': '-1'},
#  {'word': ':-D', 'word_root': ':', 'polarity': '-1'},
#  {'word': ':p', 'word_root': ':', 'polarity': '0'},
#  {'word': ':-P', 'word_root': ':', 'polarity': '-1'},
#  {'word': ';', 'word_root': ';', 'polarity': '1'},
#  {'word': ';)', 'word_root': ';', 'polarity': '1'},
#  {'word': ';-)', 'word_root': ';', 'polarity': '1'},
#  {'word': ';ㅅ;', 'word_root': ';', 'polarity': '-1'},
#  {'word': '^///^', 'word_root': '^', 'polarity': '1'},
#  {'word': '^^', 'word_root': '^^', 'polarity': '1'},
#  {'word': '^^//', 'word_root': '^^', 'polarity': '1'},
#  {'word': '^-^;', 'word_root': '^-^;', 'polarity': '-1'},
#  {'word': '^-^;;', 'word_root': '^-^;;', 'polarity': '-1'},
#  {'word': '^-^;;;;;', 'word_root': '^-^;;;;;', 'polarity': '-1'},
#  {'word': '-_-^', 'word_root': '-_-', 'polarity': '-1'},
#  {'word': '<3', 'word_root': '<', 'polarity': '1'},
#  {'word': '=)', 'word_root': '=', 'polarity': '1'},
#  {'word': '8-)', 'word_root': '8', 'polarity': '0'},
#  {'word': 'B-)', 'word_root': 'B', 'polarity': '0'},
#  {'word': 'XD', 'word_root': 'XD', 'polarity': '1'},
#  {'word': 'ㄱㅅ', 'word_root': 'ㄱ', 'polarity': '1'},
#  {'word': 'ㄱㅇㄷ', 'word_root': 'ㄱ', 'polarity': '1'},
#  {'word': '가격이 싸다', 'word_root': '가격 싸', 'polarity': '1'},
#  {'word': '가까스로', 'word_root': '가까스로', 'polarity': '0'},
#  {'word': '가까이 사귀어', 'word_root': '가까이 사귀', 'polarity': '1'},
#  {'word': '가까이하다', 'word_root': '가까이', 'polarity': '1'},
#  {'word': '가꾸러뜨리다', 'word_root': '가꾸러뜨리', 'polarity': '-1'},
#  {'word': '가꾸러트리다', 'word_root': '가꾸러트리', 'polarity': '-1'},
#  {'word': '가난', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난뱅이', 'word_root': '가난뱅이', 'polarity': '-2'},
#  {'word': '가난살이', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난살이하다', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난설음', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난에', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난에 쪼들려서', 'word_root': '가난 쪼들리', 'polarity': '-2'},
#  {'word': '가난하게', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난하고', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난하고 어렵다', 'word_root': '가난 어렵', 'polarity': '-2'},
#  {'word': '가난하고 천한', 'word_root': '가난 천한', 'polarity': '-2'},
#  {'word': '가난하다', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난하여', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난한', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가난한 데다가', 'word_root': '가난 데', 'polarity': '-2'},
#  {'word': '가난한 사람을', 'word_root': '가난 사람', 'polarity': '-2'},
#  {'word': '가난히', 'word_root': '가난', 'polarity': '-2'},
#  {'word': '가년스럽다', 'word_root': '가년', 'polarity': '-2'},
#  {'word': '가념하다', 'word_root': '가념하', 'polarity': '-1'},
#  {'word': '가녕스럽다', 'word_root': '가', 'polarity': '-2'},
#  {'word': '가누기 어려워하다', 'word_root': '가누 어려워하', 'polarity': '-1'},
#  {'word': '가누지 못하고', 'word_root': '가누 못하', 'polarity': '-2'},
#  {'word': '가누지 못하다', 'word_root': '가누 못하', 'polarity': '-2'},
#  {'word': '가누지 못할', 'word_root': '가누 못하', 'polarity': '-2'},
#  {'word': '가누지 못할 정도로', 'word_root': '가누 못하 정도', 'polarity': '-2'},
#  {'word': '가누지 못함', 'word_root': '가누 못하', 'polarity': '-2'},
#  {'word': '가눌 수 없게', 'word_root': '가누 수 없', 'polarity': '-2'},
#  {'word': '가눌 수 없을', 'word_root': '가누 수 없', 'polarity': '-2'},
#  {'word': '가눌 수 없이', 'word_root': '가누 수 없이', 'polarity': '-2'},
#  {'word': '가능성이 늘어나다', 'word_root': '가능성 늘어나', 'polarity': '2'},
#  {'word': '가능성이 있다고', 'word_root': '가능성 있', 'polarity': '2'},
#  {'word': '가능하다', 'word_root': '가능', 'polarity': '2'},
#  {'word': '가닐가닐하다', 'word_root': '가닐가닐', 'polarity': '-1'},
#  {'word': '가다듬어', 'word_root': '가다듬', 'polarity': '1'},
#  {'word': '가다듬어 수습하는', 'word_root': '가다듬 수습', 'polarity': '1'},
#  {'word': '가다듬어 수습하다', 'word_root': '가다듬 수습', 'polarity': '1'},
#  {'word': '가다듬어 정하다', 'word_root': '가다듬 정하', 'polarity': '1'},
#  {'word': '가당찮다', 'word_root': '가당찮', 'polarity': '-2'},
#  {'word': '가당찮이', 'word_root': '가', 'polarity': '-2'},
#  {'word': '가당히', 'word_root': '가', 'polarity': '1'},
#  {'word': '가두거나', 'word_root': '가두', 'polarity': '-1'},
#  {'word': '가두거나 해치거나', 'word_root': '가두 해치', 'polarity': '-2'},
#  {'word': '가드올려', 'word_root': '가드', 'polarity': '-1'},
#  {'word': '가뜬하게', 'word_root': '가뜬', 'polarity': '1'},
#  {'word': '가라앉다', 'word_root': '가라앉', 'polarity': '0'},
#  {'word': '가라앉지 않은', 'word_root': '가라앉 않', 'polarity': '0'},
#  {'word': '가라앉혀 바로잡다', 'word_root': '가라앉히 바로잡', 'polarity': '1'},
#  {'word': '가래', 'word_root': '가래', 'polarity': '-1'},
#  {'word': '가래 따위가', 'word_root': '가래 따위', 'polarity': '-1'},
#  {'word': '가래가', 'word_root': '가래', 'polarity': '-1'},
#  {'word': '가래가 섞인', 'word_root': '가래 섞이', 'polarity': '-1'},
#  {'word': '가량맞고', 'word_root': '가량', 'polarity': '-1'},
#  {'word': '가량맞고 야살스러운', 'word_root': '가량 야살', 'polarity': '-1'},
#  {'word': '가량맞고 야살스러움', 'word_root': '가량 야살', 'polarity': '-1'},
#  {'word': '가려서 좋아하다', 'word_root': '가리 좋아하', 'polarity': '-1'},
#  {'word': '가려운', 'word_root': '가렵', 'polarity': '-1'},
#  {'word': '가려운 느낌이', 'word_root': '가렵 느낌', 'polarity': '-1'},
#  {'word': '가려운 증상을', 'word_root': '가렵 증상', 'polarity': '-1'},
#  {'word': '가련하게', 'word_root': '가련', 'polarity': '-1'},
#  {'word': '가련하게 여기다', 'word_root': '가련 여기', 'polarity': '-1'},
#  {'word': '가련하게 여김', 'word_root': '가련 여기', 'polarity': '-1'},
#  {'word': '가련한', 'word_root': '가련', 'polarity': '-1'},
#  {'word': '가련한 듯하다', 'word_root': '가련 듯하', 'polarity': '-1'},
#  {'word': '가렵고', 'word_root': '가렵', 'polarity': '-1'},
#  {'word': '가로막아서', 'word_root': '가로막', 'polarity': '-1'},
#  {'word': '가로채서', 'word_root': '가로', 'polarity': '-1'},
#  {'word': '가로채어', 'word_root': '가로', 'polarity': '-1'},
#  {'word': '가르치며', 'word_root': '가르치', 'polarity': '1'},
#  {'word': '가르침', 'word_root': '가르침', 'polarity': '1'},
#  {'word': '가르침을 받아', 'word_root': '가르침 받', 'polarity': '0'},
#  {'word': '가리지 못하다', 'word_root': '가리 못하', 'polarity': '-1'},
#  {'word': '가리지 않고', 'word_root': '가리 않', 'polarity': '0'},
#  {'word': '가마득하다', 'word_root': '가마득', 'polarity': '-1'},
#  {'word': '가만있지 못하고', 'word_root': '가만있 못하', 'polarity': '-1'},
#  {'word': '가망 없는', 'word_root': '가망 없', 'polarity': '-1'},
#  {'word': '가망이 없게', 'word_root': '가망 없', 'polarity': '-2'},
#  {'word': '가벼운 마음으로', 'word_root': '가벼운 마음', 'polarity': '1'},
#  {'word': '가벼운 말이나', 'word_root': '가벼운 말', 'polarity': '-1'},
#  {'word': '가벼운 상처', 'word_root': '가벼운 상처', 'polarity': '-1'},
#  {'word': '가벼운 슬픔', 'word_root': '가벼운 슬픔', 'polarity': '-1'},
#  {'word': '가벼운 행동으로', 'word_root': '가벼운 행동', 'polarity': '-1'},
#  {'word': '가볍게', 'word_root': '가볍', 'polarity': '-1'},
#  {'word': '가볍게 까부는', 'word_root': '가볍 까불', 'polarity': '-1'},
#  {'word': '가볍게 까불다', 'word_root': '가볍 까불', 'polarity': '-1'},
#  {'word': '가볍게 쑤시듯', 'word_root': '가볍 쑤시', 'polarity': '-1'},
#  {'word': '가볍게 웃다', 'word_root': '가볍 웃', 'polarity': '1'},
#  {'word': '가볍게 채신없이', 'word_root': '가볍 채신', 'polarity': '-1'},
#  {'word': '가볍게 행동하거나', 'word_root': '가볍 행동', 'polarity': '-1'},
#  {'word': '가볍게 행동하는', 'word_root': '가볍 행동', 'polarity': '-1'},
#  {'word': '가볍게 행동하다', 'word_root': '가볍 행동', 'polarity': '-1'},
#  {'word': '가볍고', 'word_root': '가볍', 'polarity': '1'},
#  {'word': '가볍고 보드랍게', 'word_root': '가볍 보드랍', 'polarity': '1'},
#  {'word': '가볍고 상쾌하다', 'word_root': '가볍 상쾌', 'polarity': '2'},
#  {'word': '가볍고 상쾌한', 'word_root': '가볍 상쾌', 'polarity': '2'},
#  {'word': '가볍고 시원하게', 'word_root': '가볍 시원', 'polarity': '2'},
#  {'word': '가볍고 편안하게', 'word_root': '가볍 편안', 'polarity': '2'},
#  {'word': '가볍고 환하게', 'word_root': '가볍 환하', 'polarity': '2'},
#  {'word': '가분가분', 'word_root': '가분가분', 'polarity': '1'},
#  {'word': '가분히', 'word_root': '가분', 'polarity': '1'},
#  {'word': '가뿐가뿐', 'word_root': '가뿐가뿐', 'polarity': '1'},
#  {'word': '가뿐가뿐하다', 'word_root': '가뿐가뿐', 'polarity': '1'},
#  {'word': '가뿐가뿐히', 'word_root': '가뿐가뿐', 'polarity': '1'},
#  {'word': '가뿐하게', 'word_root': '가뿐', 'polarity': '1'},
#  {'word': '가뿐하다', 'word_root': '가뿐', 'polarity': '1'},
#  {'word': '가뿐한', 'word_root': '가뿐', 'polarity': '1'},
#  {'word': '가뿐한 느낌', 'word_root': '가뿐 느낌', 'polarity': '1'},
#  {'word': '가뿐한 느낌이', 'word_root': '가뿐 느낌', 'polarity': '1'},
#  {'word': '가뿐히', 'word_root': '가', 'polarity': '1'},
#  {'word': '가쁘게', 'word_root': '가쁘', 'polarity': '-1'},
#  {'word': '가쁘게 쉬다', 'word_root': '가쁘 쉬', 'polarity': '-1'},
#  {'word': '가쁘고', 'word_root': '가쁘', 'polarity': '-1'},
#  {'word': '가쁘고 거칠게', 'word_root': '가쁘 거치', 'polarity': '-1'},
#  {'word': '가쁘고 급하게', 'word_root': '가쁘 급하', 'polarity': '-1'},
#  {'word': '가쁜', 'word_root': '가쁘', 'polarity': '-1'},
#  {'word': '가쁜 증상', 'word_root': '가쁘 증상', 'polarity': '-1'},
#  {'word': '가살스럽다', 'word_root': '가살', 'polarity': '-1'},
#  {'word': '가소롭게', 'word_root': '가소롭', 'polarity': '-1'},
#  {'word': '가소롭다', 'word_root': '가소롭', 'polarity': '-1'},
#  {'word': '가스 중독이나', 'word_root': '가스 중독', 'polarity': '-1'},
#  {'word': '가슴 아파하다', 'word_root': '가슴 아파하', 'polarity': '-2'},
#  {'word': '가슴 아파함', 'word_root': '가슴 아파하', 'polarity': '-2'},
#  {'word': '가슴 아프게', 'word_root': '가슴 아프', 'polarity': '-2'},
#  {'word': '가슴 아프고', 'word_root': '가슴 아프', 'polarity': '-2'},
#  {'word': '가슴 아프다', 'word_root': '가슴 아프', 'polarity': '-2'},
#  {'word': '가슴속에 근심이나', 'word_root': '가슴속 근심', 'polarity': '-2'},
#  {'word': '가슴앓이', 'word_root': '가슴앓이', 'polarity': '-2'},
#  {'word': '가슴앓이하다', 'word_root': '가슴앓이', 'polarity': '-2'},
#  {'word': '가슴이 갑갑할', 'word_root': '가슴 갑갑', 'polarity': '-2'},
#  {'word': '가슴이 괴롭거나', 'word_root': '가슴 괴롭', 'polarity': '-2'},
#  {'word': '가슴이 그득한', 'word_root': '가슴 그', 'polarity': '-2'},
#  {'word': '가슴이 답답하고', 'word_root': '가슴 답답', 'polarity': '-2'},
#  {'word': '가슴이 답답하다', 'word_root': '가슴 답답', 'polarity': '-2'},
#  {'word': '가슴이 답답하며', 'word_root': '가슴 답답', 'polarity': '-2'},
#  {'word': '가슴이 답답하여', 'word_root': '가슴 답답', 'polarity': '-1'},
#  {'word': '가슴이 답답한', 'word_root': '가슴 답답', 'polarity': '-1'},
#  {'word': '가슴이 답답해진다', 'word_root': '가슴 답답', 'polarity': '-1'},
#  {'word': '가슴이 아프다', 'word_root': '가슴 아프', 'polarity': '-2'},
#  {'word': '가슴이 아픈', 'word_root': '가슴 아프', 'polarity': '-2'},
#  {'word': '가슴이 울렁거리는', 'word_root': '가슴 울렁거리', 'polarity': '-2'},
#  {'word': '가슴이 울렁거리다', 'word_root': '가슴 울렁거리', 'polarity': '-2'},
#  {'word': '가슴이 찢어질', 'word_root': '가슴 찢어지', 'polarity': '-2'},
#  {'word': '가습이 답답하고', 'word_root': '가습 답답', 'polarity': '-1'},
#  {'word': '가엽다', 'word_root': '가엽', 'polarity': '-1'},
#  {'word': '가엾게', 'word_root': '가엾', 'polarity': '-1'},
#  {'word': '가엾게 여겨', 'word_root': '가엾 여기', 'polarity': '-1'},
#  {'word': '가엾게 여기다', 'word_root': '가엾 여기', 'polarity': '-1'},
#  {'word': '가엾고', 'word_root': '가엾', 'polarity': '-1'},
#  {'word': '가엾고 불쌍하다', 'word_root': '가엾 불쌍', 'polarity': '-2'},
#  {'word': '가엾고 불쌍하여', 'word_root': '가엾 불쌍', 'polarity': '-2'},
#  {'word': '가엾고 불쌍한', 'word_root': '가엾 불쌍', 'polarity': '-2'},
#  {'word': '가엾고 불쌍함', 'word_root': '가엾 불쌍', 'polarity': '-2'},
#  {'word': '가엾고 애처롭다', 'word_root': '가엾 애처롭', 'polarity': '-2'},
#  {'word': '가엾다', 'word_root': '가엾', 'polarity': '-1'},
#  {'word': '가운데에서 뛰어남', 'word_root': '가운데 뛰', 'polarity': '2'},
#  {'word': '가위눌리다', 'word_root': '가위눌리', 'polarity': '-1'},
#  {'word': '가음 아프고', 'word_root': '가 아프', 'polarity': '-2'},
#  {'word': '가장 거룩한', 'word_root': '가장 거룩', 'polarity': '2'},
#  {'word': '가장 뛰어나', 'word_root': '가장 뛰어나', 'polarity': '2'},
#  {'word': '가장 뛰어난', 'word_root': '가장 뛰어나', 'polarity': '2'},
#  {'word': '가장 올바르게', 'word_root': '가장 올바르', 'polarity': '2'},
#  {'word': '가장 좋은', 'word_root': '가장 좋', 'polarity': '2'},
#  {'word': '가장 중요한', 'word_root': '가장 중요', 'polarity': '1'},
#  {'word': '가증맞다', 'word_root': '가증', 'polarity': '-1'},
#  {'word': '가증스럽다', 'word_root': '가증', 'polarity': '-1'},
#  {'word': '가지런하게 하는', 'word_root': '가지런 하', 'polarity': '1'},
#  {'word': '가지런하게 하다', 'word_root': '가지런 하다', 'polarity': '1'},
#  {'word': '가지런하다', 'word_root': '가지런', 'polarity': '1'},
#  {'word': '가지런하지 아니하다', 'word_root': '가지런 아니하', 'polarity': '-1'},
#  {'word': '가지런하지 아니한', 'word_root': '가지런 아니하', 'polarity': '-1'},
#  {'word': '가짜', 'word_root': '가짜', 'polarity': '-2'},
#  {'word': '가책이 되어', 'word_root': '가책 되', 'polarity': '-1'},
#  {'word': '가치', 'word_root': '가치', 'polarity': '1'},
#  {'word': '가치 없는', 'word_root': '가치 없', 'polarity': '-2'},
#  {'word': '가치 있는', 'word_root': '가치 있', 'polarity': '2'},
#  {'word': '가치 있다', 'word_root': '가치 있', 'polarity': '2'},
#  {'word': '가치가', 'word_root': '가치', 'polarity': '1'},
#  {'word': '가치가 없다', 'word_root': '가치 없', 'polarity': '-2'},
#  {'word': '가치가 없을', 'word_root': '가치 없', 'polarity': '-2'},
#  {'word': '가치가 없이', 'word_root': '가치 없이', 'polarity': '-2'},
#  {'word': '가치가 있다', 'word_root': '가치 있', 'polarity': '2'},
#  {'word': '가치를 믿다', 'word_root': '가치 믿', 'polarity': '2'},
#  {'word': '가치를 인정하다', 'word_root': '가치 인정', 'polarity': '2'},
#  {'word': '가치보다 비싼', 'word_root': '가치 비싸', 'polarity': '-1'},
#  {'word': '가치없는', 'word_root': '가치', 'polarity': '-2'},
#  {'word': '가치있는', 'word_root': '가치', 'polarity': '1'},
#  {'word': '가치작거리는', 'word_root': '가치', 'polarity': '-1'},
#  {'word': '가치작거리는 모양', 'word_root': '가치 모양', 'polarity': '-1'},
#  {'word': '가치작거리는 소리', 'word_root': '가치 소리', 'polarity': '-1'},
#  {'word': '가탈스럽다', 'word_root': '가탈', 'polarity': '-1'},
#  {'word': '가혹하게', 'word_root': '가혹', 'polarity': '-2'},
#  {'word': '가혹하게 착취하여', 'word_root': '가혹 착취', 'polarity': '-2'},
#  {'word': '각근하지 못하여', 'word_root': '각근하 못하', 'polarity': '-1'},
#  {'word': '각별나다', 'word_root': '각별나', 'polarity': '1'},
#  {'word': '각별하다', 'word_root': '각별', 'polarity': '1'},
#  {'word': '간 장애', 'word_root': '간 장애', 'polarity': '-2'},
#  {'word': '간 질환의', 'word_root': '간 질환', 'polarity': '-1'},
#  {'word': '간드러진', 'word_root': '간드러지', 'polarity': '2'},
#  {'word': '간드러진 느낌이', 'word_root': '간드러지 느낌', 'polarity': '2'},
#  {'word': '간사스럽게', 'word_root': '간사', 'polarity': '-1'},
#  {'word': '간사스럽게 행동하는', 'word_root': '간사 행동', 'polarity': '-1'},
#  {'word': '간사스럽게 행동하다', 'word_root': '간사 행동', 'polarity': '-1'},
#  {'word': '간사하고', 'word_root': '간사', 'polarity': '-1'},
#  {'word': '간사하다', 'word_root': '간사', 'polarity': '-1'},
#  {'word': '간사한', 'word_root': '간사', 'polarity': '-1'},
#  {'word': '간사한 사람이나', 'word_root': '간사 사람', 'polarity': '-1'},
#  {'word': '간사한 짓을', 'word_root': '간사 짓', 'polarity': '-2'},
#  {'word': '간섭받고', 'word_root': '간섭', 'polarity': '-1'},
#  {'word': '간섭하거나', 'word_root': '간섭', 'polarity': '-1'},
#  {'word': '간섭하거나 방해하여', 'word_root': '간섭 방해', 'polarity': '-1'},
#  {'word': '간섭하고', 'word_root': '간섭', 'polarity': '-1'},
#  {'word': '간섭하다', 'word_root': '간섭', 'polarity': '-1'},
#  {'word': '간섭하여', 'word_root': '간섭', 'polarity': '-1'},
#  {'word': '간신히 짜내는', 'word_root': '간신히 짜내', 'polarity': '-1'},
#  {'word': '간절하다', 'word_root': '간절', 'polarity': '2'},
#  {'word': '간지러워서', 'word_root': '간지럽', 'polarity': '-1'},
#  {'word': '간지럽게', 'word_root': '간지럽', 'polarity': '-1'},
#  {'word': '간지럽고', 'word_root': '간지럽', 'polarity': '-1'},
#  {'word': '간지럽고 자릿한', 'word_root': '간지럽 자릿', 'polarity': '-1'},
#  {'word': '간직하다', 'word_root': '간직', 'polarity': '1'},
#  {'word': '간직하지 아니하고', 'word_root': '간직 아니하', 'polarity': '-1'},
#  {'word': '간질', 'word_root': '간질', 'polarity': '-1'},
#  {'word': '간질간질하다', 'word_root': '간질간질', 'polarity': '-1'},
#  {'word': '간질간질한', 'word_root': '간질', 'polarity': '-1'},
#  {'word': '간질간질한 느낌', 'word_root': '간질 느낌', 'polarity': '-1'},
#  {'word': '간편하거나', 'word_root': '간편', 'polarity': '2'},
#  {'word': '간편하다', 'word_root': '간편', 'polarity': '2'},
#  {'word': '갈강병균이', 'word_root': '갈강병', 'polarity': '-1'},
#  {'word': '갈라서다', 'word_root': '가르', 'polarity': '-1'},
#  {'word': '갈라지는 피부병', 'word_root': '갈라지 피부병', 'polarity': '-1'},
#  {'word': '갈색굳음병', 'word_root': '갈색', 'polarity': '-1'},
#  {'word': '갈증이 나고', 'word_root': '갈증 나', 'polarity': '-1'},
#  {'word': '갈증이 심하게', 'word_root': '갈증 심하', 'polarity': '-1'},
#  {'word': '갈팡질팡', 'word_root': '갈팡질팡', 'polarity': '-1'},
#  {'word': '갈팡질팡하다', 'word_root': '갈팡질팡', 'polarity': '-1'},
#  {'word': '갈팡질팡하며', 'word_root': '갈팡질팡', 'polarity': '-1'},
#  {'word': '갈피를 잡을 수 없다', 'word_root': '갈피 잡 수 없', 'polarity': '-1'},
#  {'word': '갈피를 잡지 못하고', 'word_root': '갈피 잡지 못하', 'polarity': '-1'},
#  {'word': '갈피를 잡지 못하고 이리저리 헤매는 모양',
#   'word_root': '갈피 잡지 못하 이리저리 헤매 모양',
#   'polarity': '-1'},
#  {'word': '갈피를 잡지 못하는', 'word_root': '갈피 잡지 못하', 'polarity': '-1'},
#  {'word': '갈피를 잡지 못하다', 'word_root': '갈피 잡지 못하', 'polarity': '-1'},
#  {'word': '감각이 둔하고', 'word_root': '감각 둔하', 'polarity': '-1'},
#  {'word': '감각이 마비되고', 'word_root': '감각 마비', 'polarity': '-1'},
#  {'word': '감각적이다', 'word_root': '감각적', 'polarity': '1'},
#  {'word': '감감히', 'word_root': '감감', 'polarity': '-1'},
#  {'word': '감개무량하다', 'word_root': '감개', 'polarity': '2'},
#  {'word': '감격', 'word_root': '감격', 'polarity': '2'},
#  {'word': '감격성', 'word_root': '감격성', 'polarity': '2'},
#  {'word': '감격스럽다', 'word_root': '감격', 'polarity': '2'},
#  {'word': '감격스레', 'word_root': '감격', 'polarity': '2'},
#  {'word': '감격이', 'word_root': '감격', 'polarity': '2'},
#  {'word': '감격적', 'word_root': '감격적', 'polarity': '2'},
#  {'word': '감격하다', 'word_root': '감격', 'polarity': '2'},
#  {'word': '감격하여', 'word_root': '감격', 'polarity': '2'},
#  {'word': '감금하여', 'word_root': '감금', 'polarity': '-2'},
#  {'word': '감기', 'word_root': '감기', 'polarity': '-1'},
#  {'word': '감기가', 'word_root': '감기', 'polarity': '-1'},
#  {'word': '감기가 들어', 'word_root': '감기 듣', 'polarity': '-1'},
#  {'word': '감기나', 'word_root': '감기', 'polarity': '-1'},
#  {'word': '감기나 천식', 'word_root': '감기 천식', 'polarity': '-1'},
#  {'word': '감기로', 'word_root': '감기', 'polarity': '-1'},
#  {'word': '감기로 인하여', 'word_root': '감기 인하', 'polarity': '-1'},
#  {'word': '감당하다', 'word_root': '감당', 'polarity': '1'},
#  {'word': '감동', 'word_root': '감동', 'polarity': '2'},
#  {'word': '감동시킬', 'word_root': '감동', 'polarity': '1'},
#  {'word': '감동시킬 만한', 'word_root': '감동 만하', 'polarity': '1'},
#  {'word': '감동을 받아', 'word_root': '감동 받', 'polarity': '2'},
#  {'word': '감동을 일으킬', 'word_root': '감동 일으키', 'polarity': '2'},
#  {'word': '감동을 주거나', 'word_root': '감동 주거', 'polarity': '2'},
#  {'word': '감동이', 'word_root': '감동', 'polarity': '2'},
#  {'word': '감동이 되는', 'word_root': '감동 되', 'polarity': '2'},
#  {'word': '감동이나', 'word_root': '감동', 'polarity': '2'},
#  {'word': '감동이나 고마움을', 'word_root': '감동 고마움', 'polarity': '2'},
#  {'word': '감동하는', 'word_root': '감동', 'polarity': '2'},
#  {'word': '감동하다', 'word_root': '감동', 'polarity': '2'},
#  {'word': '감동하여', 'word_root': '감동', 'polarity': '2'},
#  {'word': '감동함', 'word_root': '감동', 'polarity': '2'},
#  {'word': '감명되다', 'word_root': '감명', 'polarity': '2'},
#  {'word': '감명적', 'word_root': '감명', 'polarity': '2'},
#  {'word': '감명하다', 'word_root': '감명', 'polarity': '2'},
#  {'word': '감모', 'word_root': '감모', 'polarity': '1'},
#  {'word': '감미롭다', 'word_root': '감미롭', 'polarity': '2'},
#  {'word': '감병', 'word_root': '감병', 'polarity': '-1'},
#  {'word': '감복하다', 'word_root': '감복', 'polarity': '2'},
#  {'word': '감복하여', 'word_root': '감복', 'polarity': '2'},
#  {'word': '감사', 'word_root': '감사', 'polarity': '2'},
#  {'word': '감사를 표하다', 'word_root': '감사 표하', 'polarity': '2'},
#  {'word': '감사하는', 'word_root': '감사', 'polarity': '2'},
#  {'word': '감사하는 마음으로', 'word_root': '감사 마음', 'polarity': '2'},
#  {'word': '감사하다', 'word_root': '감사', 'polarity': '2'},
#  {'word': '감싸고', 'word_root': '감싸', 'polarity': '1'},
#  {'word': '감싸고 달래다', 'word_root': '감싸 달래', 'polarity': '0'},
#  {'word': '감옥', 'word_root': '감옥', 'polarity': '-1'},
#  {'word': '감옥에', 'word_root': '감옥', 'polarity': '-1'},
#  {'word': '감정 사납게', 'word_root': '감정 사납', 'polarity': '-1'},
#  {'word': '감정을 건드려', 'word_root': '감정 건드리', 'polarity': '-1'},
#  {'word': '감정의 불화', 'word_root': '감정 불화', 'polarity': '-2'},
#  {'word': '감정이 거칠어져', 'word_root': '감정 거칠어지', 'polarity': '-1'},
#  {'word': '감정이 북받쳐', 'word_root': '감정 북받치', 'polarity': '1'},
#  {'word': '감칠맛이 있을', 'word_root': '감칠맛 있', 'polarity': '2'},
#  {'word': '감탄', 'word_root': '감탄', 'polarity': '2'},
#  {'word': '감탄스러울', 'word_root': '감탄', 'polarity': '2'},
#  {'word': '감탄스러울 때', 'word_root': '감탄 때', 'polarity': '2'},
#  {'word': '감탄스럽다', 'word_root': '감탄', 'polarity': '2'},
#  {'word': '감탄적으로', 'word_root': '감탄', 'polarity': '2'},
#  {'word': '감탄하다', 'word_root': '감탄', 'polarity': '2'},
#  {'word': '감탄할', 'word_root': '감탄', 'polarity': '2'},
#  {'word': '감탄할 때', 'word_root': '감탄 때', 'polarity': '2'},
#  {'word': '감회가 새롭거나', 'word_root': '감회 새롭', 'polarity': '2'},
#  {'word': '감회에 젖음', 'word_root': '감회 젖', 'polarity': '2'},
#  {'word': '갑갑궁금하다', 'word_root': '갑갑궁금하', 'polarity': '-1'},
#  {'word': '갑갑하고 궁금하다', 'word_root': '갑갑 궁금', 'polarity': '-1'},
#  {'word': '갑갑하다', 'word_root': '갑갑', 'polarity': '-1'},
#  {'word': '갑갑한', 'word_root': '갑갑', 'polarity': '-1'},
#  {'word': '갑갑한 증상', 'word_root': '갑갑 증상', 'polarity': '-1'},
#  {'word': '갑갑할', 'word_root': '갑갑', 'polarity': '-1'},
#  {'word': '갑갑할 정도로', 'word_root': '갑갑 정도', 'polarity': '-1'},
#  {'word': '갑분띠', 'word_root': '갑', 'polarity': '-1'},
#  {'word': '갑분싸', 'word_root': '갑', 'polarity': '-1'},
#  {'word': '갑자기 게우는', 'word_root': '갑자기 게우', 'polarity': '-1'},
#  {'word': '갑자기 놀라거나', 'word_root': '갑자기 놀라', 'polarity': '-1'},
#  {'word': '갑자기 놀라서', 'word_root': '갑자기 놀라', 'polarity': '-1'},
#  {'word': '갑자기 무섭거나', 'word_root': '갑자기 무섭', 'polarity': '-1'},
#  {'word': '갑자기 분별없이', 'word_root': '갑자기 분별', 'polarity': '-1'},
#  {'word': '갑자기 서늘한', 'word_root': '갑자기 서늘', 'polarity': '-1'},
#  {'word': '갑자기 서늘한서늘한 느낌이', 'word_root': '갑자기 서늘 느낌', 'polarity': '-1'},
#  {'word': '갑자기 성을', 'word_root': '갑자기 성', 'polarity': '-1'},
#  {'word': '갑자기 소란스럽게', 'word_root': '갑자기 소란', 'polarity': '-1'},
#  {'word': '갑자기 소름이', 'word_root': '갑자기 소름', 'polarity': '-1'},
#  {'word': '갑자기 어지러워', 'word_root': '갑자기 어지럽', 'polarity': '-1'},
#  {'word': '갑작스러워 두렵거나', 'word_root': '갑작스럽 두렵', 'polarity': '-1'},
#  {'word': '갑작스럽게 화를', 'word_root': '갑작스럽 화', 'polarity': '-1'},
#  {'word': '값을 매길 수 없을 만큼', 'word_root': '값 매기 수 없 만큼', 'polarity': '2'},
#  {'word': '값진', 'word_root': '값지', 'polarity': '2'},
#  {'word': '강간죄', 'word_root': '강간죄', 'polarity': '-2'},
#  {'word': '강개무량', 'word_root': '강개', 'polarity': '-2'},
#  {'word': '강개무량하다', 'word_root': '강개', 'polarity': '-2'},
#  {'word': '강구하다', 'word_root': '강구', 'polarity': '0'},
#  {'word': '강도가', 'word_root': '강도', 'polarity': '-1'},
#  {'word': '강등하여', 'word_root': '강', 'polarity': '-1'},
#  {'word': '강렬하게', 'word_root': '강렬', 'polarity': '1'},
#  {'word': '강박', 'word_root': '강박', 'polarity': '-1'},
#  {'word': '강박하여', 'word_root': '강박', 'polarity': '-1'},
#  {'word': '강세', 'word_root': '강세', 'polarity': '1'},
#  {'word': '강인하다', 'word_root': '강인', 'polarity': '1'},
#  {'word': '강인한', 'word_root': '강인', 'polarity': '2'},
#  {'word': '강제로', 'word_root': '강제', 'polarity': '-1'},
#  {'word': '강제로 누르는', 'word_root': '강제 누르', 'polarity': '-1'},
#  {'word': '강제로 누르다', 'word_root': '강제 누르', 'polarity': '-2'},
#  {'word': '강제로 누름', 'word_root': '강제 누르', 'polarity': '-2'},
#  {'word': '강제로 빼앗는', 'word_root': '강제 빼앗', 'polarity': '-1'},
#  {'word': '강제로 빼앗다', 'word_root': '강제 빼앗', 'polarity': '-1'},
#  {'word': '강제로 빼앗아', 'word_root': '강제 빼앗', 'polarity': '-2'},
#  {'word': '강제로 빼앗음', 'word_root': '강제 빼앗', 'polarity': '-1'},
#  {'word': '강제로 요구하다', 'word_root': '강제 요구', 'polarity': '-1'},
#  {'word': '강제적으로', 'word_root': '강제적', 'polarity': '-2'},
#  {'word': '강추', 'word_root': '강추', 'polarity': '2'},
#  {'word': '강탈', 'word_root': '강탈', 'polarity': '-2'},
#  {'word': '강탈하다', 'word_root': '강탈', 'polarity': '-2'},
#  {'word': '강퇴', 'word_root': '강', 'polarity': '-1'},
#  {'word': '강하게', 'word_root': '강하', 'polarity': '1'},
#  {'word': '강하게 만들다', 'word_root': '강하 만들', 'polarity': '2'},
#  {'word': '강하게 하다', 'word_root': '강하 하다', 'polarity': '1'},
#  {'word': '강하고', 'word_root': '강하', 'polarity': '1'},
#  {'word': '강하고 야무지게', 'word_root': '강하 야무지', 'polarity': '2'},
#  {'word': '강하고 야무지다', 'word_root': '강하 야무지', 'polarity': '2'},
#  {'word': '강하고 튼튼하게', 'word_root': '강하 튼튼', 'polarity': '2'},
#  {'word': '강하다', 'word_root': '강하', 'polarity': '1'},
#  {'word': '강한 비판이나', 'word_root': '강 비판', 'polarity': '-2'},
#  {'word': '강한 충격을', 'word_root': '강 충격', 'polarity': '-1'},
#  {'word': '강화하다', 'word_root': '강화', 'polarity': '1'},
#  {'word': '갖지 아니하게', 'word_root': '갖 아니하', 'polarity': '-1'},
#  {'word': '갖추다', 'word_root': '갖추', 'polarity': '1'},
#  {'word': '갖추지 못한', 'word_root': '갖추 못하', 'polarity': '-1'},
#  {'word': '같잖다', 'word_root': '같잖', 'polarity': '-1'},
#  {'word': '같잖아서', 'word_root': '같잖', 'polarity': '-1'},
#  {'word': '같잖아서 우스운', 'word_root': '같잖 우습', 'polarity': '-1'},
#  {'word': '같잖은', 'word_root': '같잖', 'polarity': '-1'},
#  {'word': '같잖은 꼴로', 'word_root': '같잖 꼴', 'polarity': '-1'},
#  {'word': '갚지 않다', 'word_root': '갚 않', 'polarity': '-1'},
#  {'word': '개가 무섭거나', 'word_root': '개가 무섭', 'polarity': '-1'},
#  {'word': '개가 아프거나', 'word_root': '개가 아프', 'polarity': '-1'},
#  {'word': '개선', 'word_root': '개선', 'polarity': '2'},
#  {'word': '개선 방도를', 'word_root': '개선 방도', 'polarity': '2'},
#  {'word': '개선하고', 'word_root': '개선', 'polarity': '1'},
#  {'word': '개선하다', 'word_root': '개선', 'polarity': '2'},
#  {'word': '개선함', 'word_root': '개선', 'polarity': '2'},
#  {'word': '개성', 'word_root': '개성', 'polarity': '1'},
#  {'word': '개성있는', 'word_root': '개성', 'polarity': '1'},
#  {'word': '개성있다', 'word_root': '개성', 'polarity': '1'},
#  {'word': '개운치 않거나', 'word_root': '개운 않', 'polarity': '-1'},
#  {'word': '개운하게', 'word_root': '개운', 'polarity': '2'},
#  {'word': '개운하고', 'word_root': '개운', 'polarity': '2'},
#  {'word': '개운하고 시원한', 'word_root': '개운 시원', 'polarity': '2'},
#  {'word': '개운하고 홀가분해지다', 'word_root': '개운 홀가분', 'polarity': '2'},
#  {'word': '개운하다', 'word_root': '개운', 'polarity': '2'},
#  {'word': '개운하지 않고', 'word_root': '개운 않', 'polarity': '-1'},
#  {'word': '개으름을', 'word_root': '개으름', 'polarity': '-1'},
#  {'word': '개이득', 'word_root': '개', 'polarity': '2'},
#  {'word': '개짓하다', 'word_root': '개짓하', 'polarity': '-2'},
#  {'word': '개회하다', 'word_root': '개회', 'polarity': '0'},
#  {'word': '갠소', 'word_root': '개', 'polarity': '1'},
#  {'word': '갸륵한', 'word_root': '갸륵', 'polarity': '1'},
#  {'word': '갸륵한 데가', 'word_root': '갸륵 데', 'polarity': '1'},
#  {'word': '갸름하다', 'word_root': '갸름', 'polarity': '1'},
#  {'word': '거꾸러뜨리다', 'word_root': '거꾸러뜨리', 'polarity': '-1'},
#  {'word': '거꾸로 넘어지거나', 'word_root': '거꾸로 넘어지', 'polarity': '-1'},
#  {'word': '거두지 못한', 'word_root': '거두 못하', 'polarity': '-1'},
#  {'word': '거드럭거드럭', 'word_root': '거드럭거드럭', 'polarity': '-1'},
#  {'word': '거드럭거리다', 'word_root': '거드럭거리', 'polarity': '-1'},
#  {'word': '거들먹거들먹', 'word_root': '거', 'polarity': '-1'},
#  {'word': '거들먹거들먹하다', 'word_root': '거', 'polarity': '-1'},
#  {'word': '거들먹거리다', 'word_root': '거들먹거리', 'polarity': '-1'},
#  {'word': '거들먹대다', 'word_root': '거들먹대', 'polarity': '-1'},
#  {'word': '거들먹이다', 'word_root': '거들먹이', 'polarity': '-1'},
#  {'word': '거듭 따뜻이', 'word_root': '거들 따뜻이', 'polarity': '2'},
#  {'word': '거듭 죄를', 'word_root': '거들 죄', 'polarity': '-1'},
#  {'word': '거뜬하다', 'word_root': '거뜬', 'polarity': '2'},
#  {'word': '거래가 금지된', 'word_root': '거래 금지', 'polarity': '-1'},
#  {'word': '거룩한', 'word_root': '거룩', 'polarity': '2'},
#  {'word': '거룩한 모습', 'word_root': '거룩 모습', 'polarity': '2'},
#  {'word': '거룩한 사람', 'word_root': '거룩 사람', 'polarity': '2'},
#  {'word': '거리끼어', 'word_root': '거리끼', 'polarity': '-1'},
#  {'word': '거리낌 없이', 'word_root': '거리낌 없이', 'polarity': '1'},
#  {'word': '거만스럽게', 'word_root': '거만', 'polarity': '-2'},
#  {'word': '거만을', 'word_root': '거만', 'polarity': '-2'},
#  {'word': '거만을 떠는', 'word_root': '거만 떨', 'polarity': '-2'},
#  {'word': '거만을 떨다', 'word_root': '거만 떨', 'polarity': '-2'},
#  {'word': '거만하게', 'word_root': '거만', 'polarity': '-2'},
#  {'word': '거만하게 행동하는', 'word_root': '거만 행동', 'polarity': '-2'},
#  {'word': '거만하게 행동하다', 'word_root': '거만 행동', 'polarity': '-2'},
#  {'word': '거만하고', 'word_root': '거만', 'polarity': '-2'},
#  {'word': '거만하다', 'word_root': '거만', 'polarity': '-2'},
#  {'word': '거만한', 'word_root': '거만', 'polarity': '-1'},
#  {'word': '거만한 태도로', 'word_root': '거만 태도', 'polarity': '-2'},
#  {'word': '거무스름한 피고름이', 'word_root': '거무스름 피고름', 'polarity': '-1'},
#  {'word': '거볍게 까부는', 'word_root': '거볍 까불', 'polarity': '-1'},
#  {'word': '거볍게 성을', 'word_root': '거볍 성', 'polarity': '-1'},
#  {'word': '거볍게 채신없이', 'word_root': '거볍 채신', 'polarity': '-1'},
#  {'word': '거볍게 행동하거나', 'word_root': '거볍 행동', 'polarity': '-1'},
#  {'word': '거볍게 행동하는', 'word_root': '거볍 행동', 'polarity': '-1'},
#  {'word': '거볍게 행동하다', 'word_root': '거볍 행동', 'polarity': '-1'},
#  {'word': '거볍고 온화하게', 'word_root': '거볍 온화', 'polarity': '2'},
#  {'word': '거부감', 'word_root': '거부감', 'polarity': '-2'},
#  {'word': '거부감 없이', 'word_root': '거부감 없이', 'polarity': '2'},
#  {'word': '거부하거나', 'word_root': '거부', 'polarity': '-2'},
#  {'word': '거부하다', 'word_root': '거부', 'polarity': '-1'},
#  {'word': '거북스럽게', 'word_root': '거북', 'polarity': '-2'},
#  {'word': '거북스럽게 저는', 'word_root': '거북 저', 'polarity': '-2'},
#  {'word': '거북스럽게 절다', 'word_root': '거북 절', 'polarity': '-2'},
#  {'word': '거북하거나', 'word_root': '거북', 'polarity': '-2'},
#  {'word': '거북하거나 괴로움', 'word_root': '거북 괴로움', 'polarity': '-2'},
#  {'word': '거북하거나 괴롭다', 'word_root': '거북 괴롭', 'polarity': '-2'},
#  {'word': '거북하거나 더럽고', 'word_root': '거북 더럽', 'polarity': '-2'},
#  {'word': '거북하게', 'word_root': '거북', 'polarity': '-2'},
#  {'word': '거북하고', 'word_root': '거북', 'polarity': '-2'},
#  {'word': '거북하고 불편한', 'word_root': '거북 불편', 'polarity': '-2'},
#  {'word': '거북하고 주체스럽게', 'word_root': '거북 주체', 'polarity': '-2'},
#  {'word': '거북하다', 'word_root': '거북', 'polarity': '-2'},
#  {'word': '거북한', 'word_root': '거북', 'polarity': '-2'},
#  {'word': '거북한 모양', 'word_root': '거북 모양', 'polarity': '-2'},
#  {'word': '거북한 상태로', 'word_root': '거북 상태', 'polarity': '-2'},
#  {'word': '거북한 소리가', 'word_root': '거북 소리', 'polarity': '-2'},
#  {'word': '거북할', 'word_root': '거북', 'polarity': '-2'},
#  {'word': '거북할 만큼', 'word_root': '거북 만큼', 'polarity': '-2'},
#  {'word': '거세고', 'word_root': '거세', 'polarity': '-1'},
#  {'word': '거세고 급하다', 'word_root': '거세 급하', 'polarity': '-1'},
#  {'word': '거슬려', 'word_root': '거슬리', 'polarity': '-1'},
#  {'word': '거슬려 불쾌하다', 'word_root': '거슬리 불쾌', 'polarity': '-2'},
#  {'word': '거슬리거나', 'word_root': '거슬리', 'polarity': '-1'},
#  {'word': '거슬리거나 마음이', 'word_root': '거슬리 마음', 'polarity': '-1'},
#  {'word': '거슬리게', 'word_root': '거슬리', 'polarity': '-1'},
#  {'word': '거슬리게 싫다', 'word_root': '거슬리 싫', 'polarity': '-1'},
#  {'word': '거슬리는', 'word_root': '거슬리', 'polarity': '-1'},
#  {'word': '거슬리는 느낌이', 'word_root': '거슬리 느낌', 'polarity': '-1'},
#  {'word': '거슬리다', 'word_root': '거슬리', 'polarity': '-1'},
#  {'word': '거슬림이 없이', 'word_root': '거슬리 없이', 'polarity': '2'},
#  {'word': '거역하다', 'word_root': '거역', 'polarity': '-1'},
#  {'word': '거역함', 'word_root': '거역', 'polarity': '-1'},
#  {'word': '거의 없다', 'word_root': '거의 없', 'polarity': '-1'},
#  {'word': '거절하거나', 'word_root': '거절', 'polarity': '-2'},
#  {'word': '거절하거나 싫다는', 'word_root': '거절 싫', 'polarity': '-2'},
#  {'word': '거절하다', 'word_root': '거절', 'polarity': '-2'},
#  {'word': '거짓', 'word_root': '거짓', 'polarity': '-2'},
#  {'word': '거짓 없다', 'word_root': '거짓 없', 'polarity': '1'},
#  {'word': '거짓말', 'word_root': '거짓말', 'polarity': '-2'},
#  {'word': '거짓말을', 'word_root': '거짓말', 'polarity': '-1'},
#  {'word': '거짓없다', 'word_root': '거짓', 'polarity': '1'},
#  {'word': '거짓으로', 'word_root': '거짓', 'polarity': '-1'},
#  {'word': '거짓으로 감정이나', 'word_root': '거짓 감정', 'polarity': '-1'},
#  {'word': '거짓으로 꾸며서', 'word_root': '거짓 꾸미', 'polarity': '-1'},
#  {'word': '거짓으로 꾸미는', 'word_root': '거짓 꾸미', 'polarity': '-1'},
#  {'word': '거짓으로 꾸미다', 'word_root': '거짓 꾸미', 'polarity': '-1'},
#  {'word': '거짓으로 꾸민', 'word_root': '거짓 꾸미', 'polarity': '-1'},
#  {'word': '거짓으로 속이다', 'word_root': '거짓 속이', 'polarity': '-1'},
#  {'word': '거짓으로 속임', 'word_root': '거짓 속이', 'polarity': '-1'},
#  {'word': '거짓을 버리고', 'word_root': '거짓 버리', 'polarity': '2'},
#  {'word': '거짓이 없고', 'word_root': '거짓 없', 'polarity': '2'},
#  {'word': '거짓이 없다', 'word_root': '거짓 없', 'polarity': '2'},
#  {'word': '거짓이 없이', 'word_root': '거짓 없이', 'polarity': '2'},
#  {'word': '거짓이나', 'word_root': '거짓', 'polarity': '-1'},
#  {'word': '거추장스러워서', 'word_root': '그', 'polarity': '-1'},
#  {'word': '거추장스러워서 거슬리거나', 'word_root': '그 거슬리', 'polarity': '-1'},
#  {'word': '거추장스럽거나', 'word_root': '거추장스럽', 'polarity': '-1'},
#  {'word': '거추장스럽거나 성가시어', 'word_root': '거추장스럽 성가시', 'polarity': '-1'},
#  {'word': '거추장스럽게', 'word_root': '거추장스럽', 'polarity': '-1'},
#  {'word': '거추장스럽게 걸리거나', 'word_root': '거추장스럽 걸리', 'polarity': '-1'},
#  {'word': '거추장스럽다', 'word_root': '거추장스럽', 'polarity': '-1'},
#  {'word': '거추장스레', 'word_root': '그', 'polarity': '-1'},
#  {'word': '거치적거리는', 'word_root': '거치적거리', 'polarity': '-1'},
#  {'word': '거치적거리는 소리', 'word_root': '거치적거리 소리', 'polarity': '-1'},
#  {'word': '거치적거치적', 'word_root': '거치적', 'polarity': '-1'},
#  {'word': '거치적거치적하다', 'word_root': '거치적', 'polarity': '-1'},
#  {'word': '거친', 'word_root': '거치', 'polarity': '-2'},
#  {'word': '거친 데가', 'word_root': '거치 데', 'polarity': '-2'},
#  {'word': '거친 말로', 'word_root': '거치 말로', 'polarity': '-2'},
#  {'word': '거친 모양', 'word_root': '거치 모양', 'polarity': '-2'},
#  {'word': '거친 목소리로', 'word_root': '거치 목소리', 'polarity': '-2'},
#  {'word': '거친 성질이나', 'word_root': '거치 성질', 'polarity': '-2'},
#  {'word': '거친 소리가', 'word_root': '거치 소리', 'polarity': '-2'},
#  {'word': '거칠거나 사납게', 'word_root': '거치 사납', 'polarity': '-2'},
#  {'word': '거칠게', 'word_root': '거치', 'polarity': '-2'},
#  {'word': '거칠게 나는', 'word_root': '거치 나', 'polarity': '-2'},
#  {'word': '거칠게 된', 'word_root': '거치 되', 'polarity': '-1'},
#  {'word': '거칠게 말다툼하다', 'word_root': '거치 말다툼', 'polarity': '-2'},
#  {'word': '거칠게 말함', 'word_root': '거치 말하', 'polarity': '-2'},
#  {'word': '거칠게 몰아쉬는', 'word_root': '거치 몰아쉬', 'polarity': '-2'},
#  {'word': '거칠게 몰아쉬다', 'word_root': '거치 몰아쉬', 'polarity': '-2'},
#  {'word': '거칠게 소리가', 'word_root': '거치 소리', 'polarity': '-2'},
#  {'word': '거칠게 쉬는', 'word_root': '거치 쉬', 'polarity': '-2'},
#  {'word': '거칠게 울려', 'word_root': '거치 울리', 'polarity': '-2'},
#  {'word': '거칠게 일다', 'word_root': '거치 일', 'polarity': '-2'},
#  {'word': '거칠게 잇따라', 'word_root': '거치 잇따르', 'polarity': '-2'},
#  {'word': '거칠게 행동하는', 'word_root': '거치 행동', 'polarity': '-1'},
#  {'word': '거칠게 행동하다', 'word_root': '거치 행동', 'polarity': '-2'},
#  {'word': '거칠고', 'word_root': '거칠', 'polarity': '-2'},
#  {'word': '거칠고 가쁘게', 'word_root': '거칠 가쁘', 'polarity': '-2'},
#  {'word': '거칠고 격한', 'word_root': '거칠 격', 'polarity': '-2'},
#  {'word': '거칠고 깔끄럽게', 'word_root': '거칠 깔끄럽', 'polarity': '-2'},
#  {'word': '거칠고 껄끄럽게', 'word_root': '거칠 껄끄럽', 'polarity': '-2'},
#  {'word': '거칠고 나쁘다', 'word_root': '거칠 나쁘', 'polarity': '-2'},
#  {'word': '거칠고 무뚝뚝하다', 'word_root': '거칠 무뚝뚝', 'polarity': '-2'},
#  {'word': '거칠고 사나우며', 'word_root': '거칠 사납', 'polarity': '-2'},
#  {'word': '거칠고 세차다', 'word_root': '거칠 세차', 'polarity': '-2'},
#  {'word': '거칠고 심하다', 'word_root': '거칠 심하', 'polarity': '-2'},
#  {'word': '거칠고 험하게', 'word_root': '거칠 험하', 'polarity': '-2'},
#  {'word': '거칠고 험한', 'word_root': '거칠 험하', 'polarity': '-2'},
#  {'word': '거칠다', 'word_root': '거칠', 'polarity': '-2'},
#  {'word': '거칠면서', 'word_root': '거칠', 'polarity': '-2'},
#  {'word': '거칠면서 가쁘고', 'word_root': '거칠 가쁘', 'polarity': '-2'},
#  {'word': '거칠어져', 'word_root': '거칠어지', 'polarity': '-2'},
#  {'word': '거침새가 없고', 'word_root': '거침새 없', 'polarity': '2'},
#  {'word': '거침없이', 'word_root': '거침없이', 'polarity': '1'},
#  {'word': '거침이 없는', 'word_root': '거치 없', 'polarity': '1'},
#  {'word': '걱정', 'word_root': '걱정', 'polarity': '-2'},
#  {'word': '걱정 같은', 'word_root': '걱정 같', 'polarity': '-1'},
#  {'word': '걱정 따위로', 'word_root': '걱정 따위', 'polarity': '-1'},
#  {'word': '걱정 없이', 'word_root': '걱정 없이', 'polarity': '2'},
#  {'word': '걱정거리', 'word_root': '걱정거리', 'polarity': '-1'},
#  {'word': '걱정과', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정과 근심', 'word_root': '걱정 근심', 'polarity': '-1'},
#  {'word': '걱정되거나', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정스러워서', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정스럽거나', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정스럽거나 조바심이', 'word_root': '걱정 조바심', 'polarity': '-1'},
#  {'word': '걱정스럽다', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정으로', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정을', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정이', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정이 되거나', 'word_root': '걱정 되', 'polarity': '-1'},
#  {'word': '걱정이 되는', 'word_root': '걱정 되', 'polarity': '-1'},
#  {'word': '걱정이 되어', 'word_root': '걱정 되', 'polarity': '-1'},
#  {'word': '걱정이 없고', 'word_root': '걱정 없', 'polarity': '2'},
#  {'word': '걱정이 없는', 'word_root': '걱정 없', 'polarity': '1'},
#  {'word': '걱정이나', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정이나 근심', 'word_root': '걱정 근심', 'polarity': '-1'},
#  {'word': '걱정이나 근심에', 'word_root': '걱정 근심', 'polarity': '-1'},
#  {'word': '걱정이나 언짢은', 'word_root': '걱정 언짢', 'polarity': '-2'},
#  {'word': '걱정인 해를', 'word_root': '걱정 해', 'polarity': '-1'},
#  {'word': '걱정하기는', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정하기는 하나', 'word_root': '걱정 하나', 'polarity': '-1'},
#  {'word': '걱정하는', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '걱정하는 게', 'word_root': '걱정 게', 'polarity': '-1'},
#  {'word': '걱정하다', 'word_root': '걱정', 'polarity': '-1'},
#  {'word': '건강에 긍정적인', 'word_root': '건강 긍정적', 'polarity': '1'},
#  {'word': '건강에 좋은', 'word_root': '건강 좋', 'polarity': '2'},
#  {'word': '건강에 해로운', 'word_root': '건강 해롭', 'polarity': '-2'},
#  {'word': '건강하고', 'word_root': '건강', 'polarity': '2'},
#  {'word': '건강하고 온전하다', 'word_root': '건강 온전', 'polarity': '2'},
#  {'word': '건강하고 온전한', 'word_root': '건강 온전', 'polarity': '2'},
#  {'word': '건강하다', 'word_root': '건강', 'polarity': '2'},
#  {'word': '건강하여', 'word_root': '건강', 'polarity': '2'},
#  {'word': '건강하여 아름다운', 'word_root': '건강 아름답', 'polarity': '2'},
#  {'word': '건강하지 못하다', 'word_root': '건강 못하', 'polarity': '-1'},
#  {'word': '건강한', 'word_root': '건강', 'polarity': '2'},
#  {'word': '건달처럼', 'word_root': '건달', 'polarity': '-1'},
#  {'word': '건둥건둥', 'word_root': '건둥건둥', 'polarity': '1'},
#  {'word': '건둥건둥하다', 'word_root': '건둥건둥', 'polarity': '1'},
#  {'word': '건둥반둥하다', 'word_root': '건둥반둥하', 'polarity': '-1'},
#  {'word': '건드려 귀찮게', 'word_root': '건드리 귀찮', 'polarity': '-1'},
#  {'word': '건들거리고', 'word_root': '건들거리', 'polarity': '-1'},
#  {'word': '건들거리고 벙글거리며', 'word_root': '건들거리 벙글거리', 'polarity': '-1'},
#  {'word': '건들건들', 'word_root': '건들건들', 'polarity': '-1'},
#  {'word': '건들건들 지내다', 'word_root': '건들건들 지내', 'polarity': '-1'},
#  {'word': '건들대다', 'word_root': '건들대', 'polarity': '-1'},
#  {'word': '건망증이', 'word_root': '건망증', 'polarity': '-1'},
#  {'word': '건망증이 심하며', 'word_root': '건망증 심', 'polarity': '-1'},
#  {'word': '건방져', 'word_root': '건방지', 'polarity': '-2'},
#  {'word': '건방지게', 'word_root': '건방지', 'polarity': '-2'},
#  {'word': '건방지게 행동하다', 'word_root': '건방지 행동', 'polarity': '-2'},
#  {'word': '건방지네', 'word_root': '건방지', 'polarity': '-2'},
#  {'word': '건방지다', 'word_root': '건방지', 'polarity': '-2'},
#  {'word': '건방지며', 'word_root': '건방지', 'polarity': '-2'},
#  {'word': '건방진', 'word_root': '건방지', 'polarity': '-1'},
#  {'word': '건방짐', 'word_root': '건방', 'polarity': '-2'},
#  {'word': '건성 기침', 'word_root': '건성 기침', 'polarity': '-1'},
#  {'word': '건성으로', 'word_root': '건성', 'polarity': '-1'},
#  {'word': '건성으로 묻다', 'word_root': '건성 묻', 'polarity': '-1'},
#  {'word': '건장하다', 'word_root': '건장', 'polarity': '2'},
#  {'word': '건장한', 'word_root': '건장', 'polarity': '2'},
#  {'word': '건장한 모양', 'word_root': '건장 모양', 'polarity': '2'},
#  {'word': '건전하고', 'word_root': '건전', 'polarity': '2'},
#  {'word': '건전하고 착실한', 'word_root': '건전 착실', 'polarity': '2'},
#  {'word': '건전하지 못하고', 'word_root': '건전 못하', 'polarity': '-1'},
#  {'word': '건전하지 못한', 'word_root': '건전 못하', 'polarity': '-1'},
#  {'word': '건전하지 아니하게', 'word_root': '건전 아니하', 'polarity': '-1'},
#  {'word': '건전한', 'word_root': '건전', 'polarity': '2'},
#  {'word': '건전함', 'word_root': '건전', 'polarity': '2'},
#  {'word': '건정히', 'word_root': '것', 'polarity': '2'},
#  {'word': '걷지 못하고', 'word_root': '걷 못하', 'polarity': '-1'},
#  {'word': '걷지 못하는', 'word_root': '걷 못하', 'polarity': '-1'},
#  {'word': '걸리거나', 'word_root': '걸리', 'polarity': '-1'},
#  {'word': '걸리거나 막히는', 'word_root': '걸리 막히', 'polarity': '-1'},
#  {'word': '걸리다', 'word_root': '걸리', 'polarity': '-1'},
#  {'word': '걸리적대다', 'word_root': '걸리적대', 'polarity': '-1'},
#  {'word': '걸핏하면', 'word_root': '걸핏하면', 'polarity': '-1'},
#  {'word': '검사에 불합격한', 'word_root': '검사 불합격', 'polarity': '-2'},
#  {'word': '검소하다', 'word_root': '검소', 'polarity': '1'},
#  {'word': '검소한', 'word_root': '검소', 'polarity': '2'},
#  {'word': '검은 티끌이라는', 'word_root': '검 티끌', 'polarity': '-1'},
#  {'word': '검질기게 구는', 'word_root': '검질기 굴', 'polarity': '-1'},
#  {'word': '검질기게 굴다', 'word_root': '검질기 굴', 'polarity': '-1'},
#  {'word': '겁', 'word_root': '겁', 'polarity': '-1'},
#  {'word': '겁나게', 'word_root': '겁나', 'polarity': '-1'},
#  {'word': '겁나게 하기', 'word_root': '겁나 하', 'polarity': '-1'},
#  {'word': '겁나다', 'word_root': '겁나', 'polarity': '-1'},
#  {'word': '겁내다', 'word_root': '겁내', 'polarity': '-1'},
#  {'word': '겁에', 'word_root': '겁', 'polarity': '-1'},
#  {'word': '겁에 지리다', 'word_root': '겁 지', 'polarity': '-2'},
#  {'word': '겁에 질려', 'word_root': '겁 질리', 'polarity': '-2'},
#  {'word': '겁에 질려서', 'word_root': '겁 질리', 'polarity': '-2'},
#  {'word': '겁에 질리거나', 'word_root': '겁 질리', 'polarity': '-2'},
#  {'word': '겁을', 'word_root': '겁', 'polarity': '-1'},
#  {'word': '겁을 내거나', 'word_root': '겁 내', 'polarity': '-1'},
#  {'word': '겁을 내다', 'word_root': '겁 내달', 'polarity': '-1'},
#  {'word': '겁을 먹거나', 'word_root': '겁 먹', 'polarity': '-1'},
#  {'word': '겁을 먹어', 'word_root': '겁 먹', 'polarity': '-1'},
#  {'word': '겁을 주며', 'word_root': '겁 주', 'polarity': '-1'},
#  {'word': '겁이 나거나', 'word_root': '겁 나', 'polarity': '-1'},
#  {'word': '겁이 나서', 'word_root': '겁 나서', 'polarity': '-1'},
#  {'word': '겁이 많고', 'word_root': '겁 많', 'polarity': '-2'},
#  {'word': '겁이 많다', 'word_root': '겁 많', 'polarity': '-2'},
#  {'word': '겁이 많아', 'word_root': '겁 많', 'polarity': '-2'},
#  {'word': '겁이 많은', 'word_root': '겁 많', 'polarity': '-2'},
#  {'word': '겁이 많음', 'word_root': '겁 많', 'polarity': '-2'},
#  {'word': '겁자기 부서지거나', 'word_root': '겁 부서지', 'polarity': '-1'},
#  {'word': '겁쟁이', 'word_root': '겁쟁이', 'polarity': '-2'},
#  {'word': '것같이 아프다', 'word_root': '것 아프', 'polarity': '-1'},
#  {'word': '것보다 낫다', 'word_root': '것 낫', 'polarity': '2'},
#  {'word': '것을 샘하여', 'word_root': '것 샘', 'polarity': '-1'},
#  {'word': '것을 짓밟다', 'word_root': '것 짓밟', 'polarity': '-1'},
#  {'word': '것이 거북하거나', 'word_root': '것 거북', 'polarity': '-1'},
#  {'word': '것이 깨끗하고', 'word_root': '것 깨끗하', 'polarity': '2'},
#  {'word': '것이 해결되어', 'word_root': '것 해결', 'polarity': '2'},
#  {'word': '겉만 그럴듯한', 'word_root': '겉 그럴듯하', 'polarity': '-1'},
#  {'word': '겉면이 매끄럽고', 'word_root': '겉면 매끄럽', 'polarity': '1'},
#  {'word': '겉모양의 아름다움과', 'word_root': '겉모양 아름다움', 'polarity': '1'},
#  {'word': '겉치레', 'word_root': '겉치레', 'polarity': '-1'},
#  {'word': '게걸스럽게', 'word_root': '게걸', 'polarity': '-2'},
#  {'word': '게걸스럽게 돌아다니는', 'word_root': '게걸 돌아다니', 'polarity': '-2'},
#  {'word': '게걸스럽게 돌아다니다', 'word_root': '게걸 돌아다니', 'polarity': '-2'},
#  {'word': '게우는', 'word_root': '게우', 'polarity': '-1'},
#  {'word': '게우는 소리', 'word_root': '게우 소리', 'polarity': '-1'},
#  {'word': '게우는 소리가', 'word_root': '게우 소리', 'polarity': '-1'},
#  {'word': '게울', 'word_root': '것', 'polarity': '-1'},
#  {'word': '게울 듯이', 'word_root': '것 듯이', 'polarity': '-1'},
#  {'word': '게워', 'word_root': '게우', 'polarity': '-1'},
#  {'word': '게워 내는', 'word_root': '게우 내', 'polarity': '-1'},
#  {'word': '게워 내다', 'word_root': '게우 내달', 'polarity': '-1'},
#  {'word': '게으르거나', 'word_root': '게으르', 'polarity': '-1'},
#  {'word': '게으르게', 'word_root': '게으르', 'polarity': '-1'},
#  {'word': '게으르게 놀며', 'word_root': '게으르 놀', 'polarity': '-1'},
#  {'word': '게으르게 행동하는', 'word_root': '게으르 행동', 'polarity': '-1'},
#  {'word': '게으르게 행동하다', 'word_root': '게으르 행동', 'polarity': '-1'},
#  {'word': '게으르고', 'word_root': '게으르', 'polarity': '-1'},
#  {'word': '게으르다', 'word_root': '게으르', 'polarity': '-1'},
#  {'word': '게으름', 'word_root': '게으름', 'polarity': '-1'},
#  {'word': '게으름을', 'word_root': '게으름', 'polarity': '-1'},
#  {'word': '게으름을 피우며', 'word_root': '게으름 피우', 'polarity': '-1'},
#  {'word': '게으름이', 'word_root': '게으름', 'polarity': '-1'},
#  {'word': '게으름이 나는', 'word_root': '게으름 나', 'polarity': '-1'},
#  {'word': '게으름이나', 'word_root': '게으름', 'polarity': '-1'},
#  {'word': '게으름이나 싫증', 'word_root': '게으름 싫증', 'polarity': '-1'},
#  {'word': '게을러빠지다', 'word_root': '게을러빠지', 'polarity': '-2'},
#  {'word': '게을러터지다', 'word_root': '게을러터지', 'polarity': '-2'},
#  {'word': '게을리하지 않고', 'word_root': '게을리 않', 'polarity': '2'},
#  {'word': '겐트위한', 'word_root': '겐트', 'polarity': '-1'},
#  {'word': '겨를이 없음', 'word_root': '겨를 없', 'polarity': '-1'},
#  {'word': '겨우 빠듯하게', 'word_root': '겹 빠듯', 'polarity': '-1'},
#  {'word': '겨우겨우', 'word_root': '겨우겨우', 'polarity': '-1'},
#  {'word': '겨우겨우 살기를', 'word_root': '겨우겨우 살기', 'polarity': '-1'},
#  {'word': '겨운', 'word_root': '겹', 'polarity': '-1'},
#  {'word': '겨운 일에', 'word_root': '겹 일', 'polarity': '-1'},
#  {'word': '격노', 'word_root': '격노', 'polarity': '-2'},
#  {'word': '격노하다', 'word_root': '격노', 'polarity': '-2'},
#  {'word': '격동시키다', 'word_root': '격동', 'polarity': '0'},
#  {'word': '격려되다', 'word_root': '격려', 'polarity': '1'},
#  {'word': '격려하다', 'word_root': '격려', 'polarity': '1'},
#  {'word': '격분', 'word_root': '격분', 'polarity': '-2'},
#  {'word': '격분하다', 'word_root': '격분', 'polarity': '-2'},
#  {'word': '격식에 맞아', 'word_root': '격식 맞', 'polarity': '1'},
#  {'word': '격식을 갖추지 않고', 'word_root': '격식 갖추 않', 'polarity': '-1'},
#  {'word': '격에 어울리지', 'word_root': '격 어울리', 'polarity': '-1'},
#  {'word': '격하게', 'word_root': '격하', 'polarity': '-2'},
#  {'word': '격하게 되다', 'word_root': '격하 되', 'polarity': '-2'},
#  {'word': '격하다', 'word_root': '격하', 'polarity': '0'},
#  {'word': '격하시키다', 'word_root': '격하', 'polarity': '-2'},
#  {'word': '격한', 'word_root': '격', 'polarity': '-2'},
#  {'word': '격한 감정이', 'word_root': '격 감정', 'polarity': '-2'},
#  {'word': '격한 기운이', 'word_root': '격 기운', 'polarity': '-2'},
#  {'word': '격한 느낌이', 'word_root': '격 느낌', 'polarity': '-2'},
#  {'word': '겪거나 불쌍한', 'word_root': '겪 불쌍', 'polarity': '-1'},
#  {'word': '견고하다', 'word_root': '견고', 'polarity': '1'},
#  {'word': '견디기 어렵게', 'word_root': '견디 어렵', 'polarity': '-2'},
#  {'word': '견디기가 어려울', 'word_root': '견디기 어렵', 'polarity': '-2'},
#  {'word': '견디어 내다', 'word_root': '견디 내달', 'polarity': '1'},
#  {'word': '견딜 수 없는', 'word_root': '견디 수 없', 'polarity': '-2'},
#  {'word': '견줄 수 없을 정도로', 'word_root': '견주 수 없 정도', 'polarity': '1'},
#  {'word': '결기가', 'word_root': '결기', 'polarity': '-1'},
#  {'word': '결기가 나다', 'word_root': '결기 나', 'polarity': '-1'},
#  {'word': '결단성 없다', 'word_root': '결단성 없', 'polarity': '-1'},
#  {'word': '결단성 없이', 'word_root': '결단성 없이', 'polarity': '-1'},
#  {'word': '결단성이 없고', 'word_root': '결단성 없', 'polarity': '-1'},
#  {'word': '결단성이 없다', 'word_root': '결단성 없', 'polarity': '-1'},
#  {'word': '결단을 못 내리는', 'word_root': '결단 못 내리', 'polarity': '-1'},
#  {'word': '결딴날', 'word_root': '결딴나', 'polarity': '-2'},
#  {'word': '결딴날 듯이', 'word_root': '결딴나 듯이', 'polarity': '-2'},
#  {'word': '결막염', 'word_root': '결막염', 'polarity': '-1'},
#  {'word': '결석', 'word_root': '결석', 'polarity': '-2'},
#  {'word': '결석하다', 'word_root': '결석', 'polarity': '-2'},
#  {'word': '결심 없이', 'word_root': '결심 없이', 'polarity': '-1'},
#  {'word': '결점', 'word_root': '결점', 'polarity': '-1'},
#  {'word': '결점이 없도록', 'word_root': '결점 없', 'polarity': '1'},
#  {'word': '결정을 못하고', 'word_root': '결정 못하', 'polarity': '-1'},
#  {'word': '결정하지 못하고', 'word_root': '결정 못하', 'polarity': '-1'},
#  {'word': '결정하지 못하는', 'word_root': '결정 못하', 'polarity': '-1'},
#  {'word': '결정하지 못하다', 'word_root': '결정 못하', 'polarity': '-1'},
#  {'word': '결정하지 못함', 'word_root': '결정 못하', 'polarity': '-1'},
#  {'word': '결핍', 'word_root': '결핍', 'polarity': '-2'},
#  {'word': '결핍증', 'word_root': '결핍증', 'polarity': '-2'},
#  {'word': '결함', 'word_root': '결함', 'polarity': '-1'},
#  {'word': '결함을', 'word_root': '결함', 'polarity': '-1'},
#  {'word': '결함을 드러내어', 'word_root': '결함 드', 'polarity': '-1'},
#  {'word': '결함을 들추어', 'word_root': '결함 들추', 'polarity': '-1'},
#  {'word': '결함을 풍자하였다', 'word_root': '결함 풍자', 'polarity': '-1'},
#  {'word': '결함이 없이', 'word_root': '결함 없이', 'polarity': '2'},
#  {'word': '결함이 있다', 'word_root': '결함 있', 'polarity': '-1'},
#  {'word': '결함이나', 'word_root': '결함', 'polarity': '-1'},
#  {'word': '결함이나 잘못', 'word_root': '결함 잘못', 'polarity': '-1'},
#  {'word': '결함이나 잘못에', 'word_root': '결함 잘못', 'polarity': '-1'},
#  {'word': '결핵', 'word_root': '결핵', 'polarity': '-1'},
#  {'word': '겸손하게', 'word_root': '겸손', 'polarity': '1'},
#  {'word': '겸손하게 이르는', 'word_root': '겸손 이르', 'polarity': '1'},
#  {'word': '겸손하고', 'word_root': '겸손', 'polarity': '1'},
#  {'word': '겸손하고 예의', 'word_root': '겸손 예의', 'polarity': '2'},
#  {'word': '겸손하고 예의 바른', 'word_root': '겸손 예의 바른', 'polarity': '2'},
#  {'word': '겸손하다', 'word_root': '겸손', 'polarity': '2'},
#  {'word': '겸손한', 'word_root': '겸손', 'polarity': '2'},
#  {'word': '겸연쩍고', 'word_root': '겸연쩍', 'polarity': '-1'},
#  {'word': '겸연쩍다', 'word_root': '겸연쩍', 'polarity': '-1'},
#  {'word': '겹거나', 'word_root': '겹', 'polarity': '-2'},
#  {'word': '겹게', 'word_root': '겹', 'polarity': '-2'},
#  {'word': '겹게 여기다', 'word_root': '겹 여기', 'polarity': '-2'},
#  {'word': '경건하다', 'word_root': '경건', 'polarity': '2'},
#  {'word': '경건한', 'word_root': '경건', 'polarity': '1'},
#  {'word': '경련', 'word_root': '경련', 'polarity': '-1'},
#  {'word': '경련을 일으키다', 'word_root': '경련 일으키', 'polarity': '-2'},
#  {'word': '경련이', 'word_root': '경련', 'polarity': '-1'},
#  {'word': '경련이 일어나', 'word_root': '경련 일어나', 'polarity': '-2'},
#  {'word': '경망스러우며', 'word_root': '경망', 'polarity': '-1'},
#  {'word': '경망스러우며 추잡하다', 'word_root': '경망 추잡', 'polarity': '-2'},
#  {'word': '경망스러운', 'word_root': '경망', 'polarity': '-1'},
#  {'word': '경망스러운 여자를', 'word_root': '경망 여자', 'polarity': '-1'},
#  {'word': '경망스럽게', 'word_root': '경망', 'polarity': '-1'},
#  {'word': '경망스럽게 까부는', 'word_root': '경망 까불', 'polarity': '-1'},
#  {'word': '경망스럽게 내어', 'word_root': '경망 내', 'polarity': '-1'},
#  {'word': '경망스럽게 내흔들거나', 'word_root': '경망 내흔들', 'polarity': '-2'},
#  {'word': '경망스럽게 놀려', 'word_root': '경망 놀리', 'polarity': '-1'},
#  {'word': '경망스럽게 덤비며', 'word_root': '경망 덤비', 'polarity': '-1'},
#  {'word': '경망스럽게 떠벌리는', 'word_root': '경망 떠벌리', 'polarity': '-1'},
#  {'word': '경망스럽게 이리저리', 'word_root': '경망 이리저리', 'polarity': '-1'},
#  {'word': '경망스럽게 추켰다', 'word_root': '경망 추키', 'polarity': '-1'},
#  {'word': '경망스럽게 행동하는', 'word_root': '경망 행동', 'polarity': '-1'},
#  {'word': '경망스럽게 행동하다', 'word_root': '경망 행동', 'polarity': '-1'},
#  {'word': '경망스럽고', 'word_root': '경망', 'polarity': '-1'},
#  {'word': '경망스럽고 가볍게', 'word_root': '경망 가볍', 'polarity': '-1'},
#  {'word': '경망스럽고 방정맞은', 'word_root': '경망 방정맞', 'polarity': '-1'},
#  {'word': '경망스럽다', 'word_root': '경망', 'polarity': '-2'},
#  {'word': '경망하게', 'word_root': '경망', 'polarity': '-1'},
#  {'word': '경망하게 행동하는', 'word_root': '경망 행동', 'polarity': '-1'},
#  {'word': '경망하게 행동하다', 'word_root': '경망 행동', 'polarity': '-1'},
#  {'word': '경망한', 'word_root': '경망', 'polarity': '-1'},
#  {'word': '경망한 짓', 'word_root': '경망 짓', 'polarity': '-1'},
#  {'word': '경멸', 'word_root': '경멸', 'polarity': '-2'},
#  {'word': '경멸하다', 'word_root': '경멸', 'polarity': '-2'},
#  {'word': '경멸히', 'word_root': '경멸', 'polarity': '-2'},
#  {'word': '경멸히 여겨', 'word_root': '경멸 여기', 'polarity': '-2'},
#  {'word': '경박스럽게', 'word_root': '경박', 'polarity': '-1'},
#  {'word': '경박스럽게 함부로', 'word_root': '경박 함부로', 'polarity': '-2'},
#  {'word': '경박하게', 'word_root': '경박', 'polarity': '-1'},
#  {'word': '경박하다', 'word_root': '경박', 'polarity': '-1'},
#  {'word': '경박한', 'word_root': '경박', 'polarity': '-1'},
#  {'word': '경박한 행동을', 'word_root': '경박 행동', 'polarity': '-1'},
#  {'word': '경사스러운', 'word_root': '경사', 'polarity': '2'},
#  {'word': '경사스러운 일을', 'word_root': '경사 일', 'polarity': '2'},
#  {'word': '경상', 'word_root': '경상', 'polarity': '-2'},
#  {'word': '경솔하게', 'word_root': '경솔', 'polarity': '-1'},
#  {'word': '경솔하게 까부는', 'word_root': '경솔 까불', 'polarity': '-1'},
#  {'word': '경솔하게 말하며', 'word_root': '경솔 말하', 'polarity': '-1'},
#  {'word': '경솔하게 행동하는', 'word_root': '경솔 행동', 'polarity': '-1'},
#  {'word': '경솔하게 행동하다', 'word_root': '경솔 행동', 'polarity': '-1'},
#  {'word': '경솔하게 행동하여', 'word_root': '경솔 행동', 'polarity': '-1'},
#  {'word': '경솔하고', 'word_root': '경솔', 'polarity': '-1'},
#  {'word': '경솔하고 방정맞게', 'word_root': '경솔 방정맞', 'polarity': '-2'},
#  {'word': '경솔하다', 'word_root': '경솔', 'polarity': '-1'},
#  {'word': '경솔한', 'word_root': '경솔', 'polarity': '-1'},
#  {'word': '경솔한 모양', 'word_root': '경솔 모양', 'polarity': '-1'},
#  {'word': '경이로운', 'word_root': '경이', 'polarity': '2'},
#  {'word': '경이롭다', 'word_root': '경이', 'polarity': '2'},
#  {'word': '경치 좋은', 'word_root': '경치 좋', 'polarity': '2'},
#  {'word': '경치가 뛰어나거나', 'word_root': '경치 뛰어나', 'polarity': '2'},
#  {'word': '경치가 맑고', 'word_root': '경치 맑', 'polarity': '2'},
#  {'word': '경치가 아름다움을', 'word_root': '경치 아름다움', 'polarity': '2'},
#  {'word': '경치가 아름답다', 'word_root': '경치 아름답', 'polarity': '2'},
#  {'word': '경치가 좋거나', 'word_root': '경치 좋', 'polarity': '2'},
#  {'word': '경치도 좋음', 'word_root': '경치 좋', 'polarity': '2'},
#  {'word': '경치를 즐기는', 'word_root': '경치 즐기', 'polarity': '2'},
#  {'word': '경쾌하다', 'word_root': '경쾌', 'polarity': '2'},
#  {'word': '경험이 많고', 'word_root': '경험 많', 'polarity': '1'},
#  {'word': '경험이 적거나', 'word_root': '경험 적거', 'polarity': '-1'},
#  {'word': '경황이 없어', 'word_root': '경황 없', 'polarity': '-1'},
#  {'word': '계급을 올림', 'word_root': '계급 올림', 'polarity': '2'},
#  {'word': '계급이 오름', 'word_root': '계급 오르', 'polarity': '2'},
#  {'word': '계속 게워', 'word_root': '계속 게우', 'polarity': '-1'},
#  {'word': '계속 공허하다', 'word_root': '계속 공허', 'polarity': '-1'},
#  {'word': '계속 공허한', 'word_root': '계속 공허', 'polarity': '-1'},
#  {'word': '계속 까부는', 'word_root': '계속 까불', 'polarity': '-1'},
#  {'word': '계속 까불다', 'word_root': '계속 까불', 'polarity': '-1'},
#  {'word': '계속 놀리다', 'word_root': '계속 놀리', 'polarity': '-1'},
#  {'word': '계속 다투다', 'word_root': '계속 다투', 'polarity': '-1'},
#  {'word': '계속 떠들어', 'word_root': '계속 떠들', 'polarity': '-1'},
#  {'word': '계속 밉살스럽게', 'word_root': '계속 밉살스럽', 'polarity': '-1'},
#  {'word': '계속 부정하다', 'word_root': '계속 부정', 'polarity': '-2'},
#  {'word': '계속 불평을', 'word_root': '계속 불평', 'polarity': '-2'},
#  {'word': '계속 서운하다', 'word_root': '계속 서운', 'polarity': '-1'},
#  {'word': '계속 서운한', 'word_root': '계속 서운', 'polarity': '-1'},
#  {'word': '계속 성을', 'word_root': '계속 성', 'polarity': '-1'},
#  {'word': '계속 아첨하는', 'word_root': '계속 아첨', 'polarity': '-1'},
#  {'word': '계속 어지럽고', 'word_root': '계속 어지럽', 'polarity': '-1'},
#  {'word': '계속 쩔쩔매거나', 'word_root': '계속 쩔쩔매', 'polarity': '-1'},
#  {'word': '계속 토할', 'word_root': '계속 토하', 'polarity': '-1'},
#  {'word': '계속 헤프게', 'word_root': '계속 헤프', 'polarity': '-1'},
#  {'word': '계속 흥겹게', 'word_root': '계속 흥겹', 'polarity': '2'},
#  {'word': '고결 함', 'word_root': '고결 함', 'polarity': '2'},
#  {'word': '고결한 풍채를', 'word_root': '고결 풍채', 'polarity': '2'},
#  {'word': '고귀한', 'word_root': '고귀', 'polarity': '2'},
#  {'word': '고귀한 사람', 'word_root': '고귀 사람', 'polarity': '2'},
#  {'word': '고급', 'word_root': '고급', 'polarity': '2'},
#  {'word': '고급스럽다', 'word_root': '고급', 'polarity': '2'},
#  {'word': '고급지다', 'word_root': '고급지', 'polarity': '2'},
#  {'word': '고까워하는', 'word_root': '고까워하', 'polarity': '-1'},
#  {'word': '고까워하는 데가', 'word_root': '고까워하 데', 'polarity': '-1'},
#  {'word': '고까워하는 태도가', 'word_root': '고까워하 태도', 'polarity': '-1'},
#  {'word': '고까워하는 태도를', 'word_root': '고까워하 태도', 'polarity': '-1'},
#  {'word': '고난', 'word_root': '고난', 'polarity': '-2'},
#  {'word': '고단하다', 'word_root': '고단', 'polarity': '-2'},
#  {'word': '고단하여', 'word_root': '고단', 'polarity': '-2'},
#  {'word': '고달프다', 'word_root': '고달프', 'polarity': '-2'},
#  {'word': '고도화', 'word_root': '고도화', 'polarity': '-2'},
#  {'word': '고도화되다', 'word_root': '고도화되', 'polarity': '-2'},
#  {'word': '고되다', 'word_root': '고되', 'polarity': '-2'},
#  {'word': '고르고', 'word_root': '고르', 'polarity': '2'},
#  {'word': '고르고 반듯하게', 'word_root': '고르 반듯', 'polarity': '2'},
#  {'word': '고르고 야무지다', 'word_root': '고르 야무지', 'polarity': '2'},
#  {'word': '고르다', 'word_root': '고르', 'polarity': '2'},
#  {'word': '고르지 못하거나', 'word_root': '고르 못하', 'polarity': '-1'},
#  {'word': '고르지 못한', 'word_root': '고르 못하', 'polarity': '-1'},
#  {'word': '고르지 아니하게', 'word_root': '고르 아니하', 'polarity': '-1'},
#  {'word': '고르지 아니하고', 'word_root': '고르 아니하', 'polarity': '-1'},
#  {'word': '고르지 않고', 'word_root': '고르 않', 'polarity': '-1'},
#  {'word': '고름', 'word_root': '고름', 'polarity': '-1'},
#  {'word': '고름이 나오는', 'word_root': '고름 나오', 'polarity': '-1'},
#  {'word': '고름이 생기는', 'word_root': '고름 생기', 'polarity': '-1'},
#  {'word': '고름이 생기다', 'word_root': '고름 생기', 'polarity': '-1'},
#  {'word': '고름집', 'word_root': '고름집', 'polarity': '-1'},
#  {'word': '고리게', 'word_root': '고리', 'polarity': '-1'},
#  {'word': '고마운', 'word_root': '고맙', 'polarity': '2'},
#  {'word': '고마운 마음', 'word_root': '고맙 마음', 'polarity': '2'},
#  {'word': '고마운 마음이', 'word_root': '고맙 마음', 'polarity': '2'},
#  {'word': '고마움', 'word_root': '고마움', 'polarity': '2'},
#  {'word': '고마움을', 'word_root': '고마움', 'polarity': '2'},
#  {'word': '고마움을 깊이', 'word_root': '고마움 깊이', 'polarity': '2'},
#  {'word': '고마움을 나타내거나', 'word_root': '고마움 나타내', 'polarity': '2'},
#  {'word': '고마움을 나타내는', 'word_root': '고마움 나타내', 'polarity': '2'},
#  {'word': '고마워하다', 'word_root': '고마워하', 'polarity': '2'},
#  {'word': '고맙게', 'word_root': '고맙', 'polarity': '2'},
#  {'word': '고맙게 베풀어', 'word_root': '고맙 베풀', 'polarity': '2'},
#  {'word': '고맙게 여기는', 'word_root': '고맙 여기', 'polarity': '2'},
#  {'word': '고맙게 여기다', 'word_root': '고맙 여기', 'polarity': '2'},
#  {'word': '고맙게 여김', 'word_root': '고맙 여기', 'polarity': '2'},
#  {'word': '고맙다', 'word_root': '고맙', 'polarity': '2'},
#  {'word': '고백', 'word_root': '고백', 'polarity': '2'},
#  {'word': '고부라지거나', 'word_root': '고부라지', 'polarity': '0'},
#  {'word': '고부라지거나 비틀어지며', 'word_root': '고부라지 비틀어지', 'polarity': '0'},
#  {'word': '고분고분하게', 'word_root': '고분', 'polarity': '2'},
#  {'word': '고분고분하고', 'word_root': '고분', 'polarity': '2'},
#  {'word': '고분고분하고 온순하게', 'word_root': '고분 온순', 'polarity': '2'},
#  {'word': '고분고분하고 온순하다', 'word_root': '고분 온순', 'polarity': '2'},
#  {'word': '고분고분하다', 'word_root': '고분', 'polarity': '2'},
#  {'word': '고분고분하지 못하고', 'word_root': '고분 못하', 'polarity': '-1'},
#  {'word': '고비를', 'word_root': '고비', 'polarity': '-1'},
#  {'word': '고상하고', 'word_root': '고상', 'polarity': '1'},
#  {'word': '고상하다', 'word_root': '고상', 'polarity': '2'},
#  {'word': '고상한', 'word_root': '고상', 'polarity': '2'},
#  {'word': '고상한 기질과', 'word_root': '고상 기질', 'polarity': '2'},
#  {'word': '고상한 남자', 'word_root': '고상 남자', 'polarity': '1'},
#  {'word': '고상한 이야기', 'word_root': '고상 이야기', 'polarity': '1'},
#  {'word': '고상한 인품을', 'word_root': '고상 인품', 'polarity': '2'},
#  {'word': '고상한 풍채', 'word_root': '고상 풍채', 'polarity': '2'},
#  {'word': '고생스러운', 'word_root': '고생', 'polarity': '-2'},
#  {'word': '고생을', 'word_root': '고생', 'polarity': '-1'},
#  {'word': '고생을 격다', 'word_root': '고생 격', 'polarity': '-1'},
#  {'word': '고생을 하다', 'word_root': '고생 하다', 'polarity': '-1'},
#  {'word': '고생이나', 'word_root': '고생', 'polarity': '-1'},
#  {'word': '고생하거나', 'word_root': '고생', 'polarity': '-1'},
#  {'word': '고생하거나 두려워하여', 'word_root': '고생 두려워하', 'polarity': '-2'},
#  {'word': '고생하다', 'word_root': '고생', 'polarity': '-1'},
#  {'word': '고성능', 'word_root': '고성능', 'polarity': '2'},
#  {'word': '고소 공포증', 'word_root': '고소 공포증', 'polarity': '-1'},
#  {'word': '고약하게', 'word_root': '고약', 'polarity': '-2'},
#  {'word': '고약하다', 'word_root': '고약', 'polarity': '-2'},
#  {'word': '고약함', 'word_root': '고약', 'polarity': '-2'},
#  ...]

# %%
# 리뷰에 대한 감정사전으로 평가한 점수표를 새로운 컬럼 score로 대입한다.
# 비교대상 word를 비교하여 평가를 수행, 점수는 누적합
# 비교대상이 없는 경우 일단 누락 및 따로 모아서 [ (), (), ] noncheck으로 추가

# %%
# 샘플 1개에 대해서 점수를 계산해본다.
df['classifier'][0][:2]
# Out:
# [('쿠키', 'Noun'), ('왜', 'Noun')]

# %%
polarity_=0
for word, tag in df['classifier'][0]:
    for dic in score_dic:
        if dic['word']==word:
                print( word, dic['polarity'])
                polarity_+= int(dic['polarity'])

polarity_, df['content'][0], df['star'][0]
# Out:
# 많다 2
# 좋다 2
# 이상하다 -1
# 좋다 2
# (5,
#  '쿠키 왜 안주세요 몇번째야 진짜 무료쿠키~ 이러면서 안주는게 한두번인가 내가 가입을 얼마나 많이했는데 방금 알바가입 머시했거든요?  개 빨리주세요;; 진짜 나말고도 많더만 이정도면 네이버 이거 고객기만이지 장난하나;;;; 그리고 작가님들 다 좋거든요? 근데 왜 자꾸 하위권짜르세요 장난하나 작가님들 작품이 장난이에요? 이상한 만화는 안 짜르고 스토리 탄탄에 작화 좋은데 하위권 다 짤라;;;',
#  1)

# %% [markdown]
# - 형태소를 어떻게 처리했느냐, 매칭이 얼마나 되느냐,
# - 사전의 표현은 얼마나 풍성하느냐에 따라 긍정과 부정이 계속 바뀐다.
# - ==> 사람이 인위적으로 계속해서 사전을 추가하는 것은 불가능하다
# - ==> 매칭이 안된 단어들은 유사도를 계산하여(백터화 거리계산법) 가장 근접한 표현으로 찾아서
# - 점수화 하면 많이 보완 될 것이고, 이것이 사전에 반영되면 계산없이 바로 찾을 수도 있을 것이다.
# - **궁극적으로 맥락이라는 것이 더 중요하므로, 머신러닝이나 딥러닝**으로 처리하는게 보다 효율적이다.
# - 챗복이라는 서비스, 번역 등등 머신러닝, 딥러닝기반구성

# %%
def scoreCalculator(x):
    polarity_=0
    for word, tag in x:
        for dic in score_dic:
            if dic['word']==word:
                    # print( word, dic['polarity'])
                    polarity_+= int(dic['polarity'])
    return polarity_

# %%
df['score'] = df['classifier'].apply( scoreCalculator )

# %%
df.loc[ :,['star','score']]
# Out:
#      star  score
# 0       1      5
# 1       1     -4
# 2       5      0
# 3       1     -1
# 4       1      0
# 5       5      5
# 6       2      1
# 7       3      0
# 8       1     -1
# 9       4      4
# 10      4      1
# 11      2     -2
# 12      3      7
# 13      1     -2
# 14      1      1
# 15      2      0
# 16      3     -2
# 17      3      0
# 18      1      2
# 19      1     -3
# 20      5      4
# 21      4      4
# 22      1     -7
# 23      5     -4
# 24      4      3
# 25      2    -11
# 26      4      2
# 27      1      0
# 28      1      0
# 29      1      2
# ..    ...    ...
# 290     1      2
# 291     5      0
# 292     2     -3
# 293     1     -4
# 294     5      0
# 295     3     -4
# 296     1     -2
# 297     3      4
# 298     4      5
# 299     1      0
# 300     5      0
# 301     1     -2
# 302     1     -2
# 303     1     -1
# 304     4      4
# 305     3     -6
# 306     1     -1
# 307     5      2
# 308     1      4
# 309     1     -1
# 310     1     -2
# 311     2      3
# 312     4      5
# 313     1      0
# 314     2     -2
# 315     5      0
# 316     4      1
# 317     1      1
# 318     3      0
# 319     1     -1
#
# [320 rows x 2 columns]
